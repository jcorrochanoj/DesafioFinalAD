# %% [markdown]
# # Análisis del Data set de Consejos

# %% [markdown]
# ## Índice
#
# <a href="#id1">1. Carga y descripción de los datos</a> <br>
# <a href="#id2">2. Análisis descriptivo <br>
# <a href="#id3">3. Análisis de los comentarios <br>
# <a href="#id3.1" style="padding-left:2em">3.1. Numero de comentarios por año <br>
# <a href="#id3.2" style="padding-left:2em">3.2. Numero de comentarios por mes <br>
# <a href="#id3.3" style="padding-left:2em">3.3. Numero de comentarios por dia <br>
# <a href="#id3.4" style="padding-left:2em">3.4. Numero de comentarios por hora <br>
# <a href="#id3.5" style="padding-left:2em">3.5. Numero de comentarios por minuto <br>
# <a href="#id3.6" style="padding-left:2em">3.6. Evolucion de los comentarios por año <br>
# <a href="#id4">4. Usuarios que hacen consejos <br>
# <a href="#id5">5. Negocios que reciben consejos <br>
# <a href="#id6">6. Análisis de Likes en Consejos <br>
# <a href="#id6.1" style="padding-left:2em">6.1. Numero de likes por año <br>
# <a href="#id6.2" style="padding-left:2em">6.2. Numero de likes por Mes <br>
# <a href="#id6.3" style="padding-left:2em">6.3. Numero de likes por Hora <br>
# <a href="#id7">7. Boxplots <br>
# <a href="#id8">8. Wordcloud en consejos <br>

# %% [markdown]
# <a id="id1"></a>
#
# ## 1. Carga y descripción de los datos

# %%
import pandas as pd

df_consejos = pd.read_csv('Dataset/datos_consejos_limpio.csv')

# %%
df_consejos.head(10)
# Out:
#                usuario_id              negocio_id  \
# 0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2  jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3  FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4  LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# 5  iAd8XaHxv05iXyEiZ62Ibw  kj1p6NwUGROOoqNySf0I1Q
# 6  w8p4JW6-ERsbg8aB5wjEAg  0hudPyuCBlKg79OwKBw-eQ
# 7  CaFbX7topxdLpBJ_SNDfGQ  r49iBfbnfoK7yt4rdsL_7g
# 8  VLy6l8L72adD7iTBNqiPXw  YCRCFBr6myPS49on2aS2pQ
# 9  zrvk0-B91ahJRSB-UcAmIA  RTBIiq-fJUXRsrzbL4MCqw
#
#                                                texto  num_likes  anyo  mes  \
# 0  Great for watching games, ufc, and whatever el...          0  2014    3
# 1  Happy Hour 2-4 daily with 1/2 price drinks and...          0  2013    5
# 2  Good chips and salsa. Loud at times. Good serv...          0  2011   12
# 3  The setting and decoration here is amazing. Co...          0  2014    3
# 4  Molly is definately taking a picture with Sant...          0  2012   10
# 5     It's true! The drunken noodles are outrageous!          0  2011   12
# 6  Only worth a visit in the summer time, to take...          0  2012   10
# 7             Hands down best AYCE in town! Love it!          0  2016    1
# 8  Sat in the drive thru this afternoon for 30 mi...          0  2017    3
# 9  Okay so I had a groupon for a nearby service c...          0  2013    2
#
#    dia  hora  minuto  sentimiento
# 0   27     3      51            1
# 1   25     6       0            0
# 2   26     1      46            0
# 3   23    21      32            1
# 4    6     0      19            0
# 5   31    18       2           -1
# 6   11    23       6            1
# 7    5     6      39            1
# 8   13     3      29           -1
# 9    8    20      55            1

# %% [markdown]
# ### Descripción de atributos
#
# - **usuario_id**: String que contiene un conjunto de números y letras que identifican unívocamente a un usuario que realiza una reseña.
# - **negocio_id**: String que contiene un conjunto de números y letras que identifican unívocamente a un negocio que es elemento valorado en la     reseña.
# - **texto**: Texto que contiene la reseña de un usuario acerca de un negocio.
# - **num_likes**: Numero de likes recibidos por la reseña. Valores de [0 a 15]
# - **anyo**: Año en el que se realizó la reseña. Valores de  [2009 a 2018]
# - **mes**: Mes en el que se realizó la reseña. Valores de [1 a 12]
# - **dia**: Día en el que se realizó la reseña. Valores de [0 a 31]
# - **hora**: Hora en la que se realizó la reseña. Valores de [0 a 23]
# - **minuto**: Minuto en el que se realizó la reseña. Valores de [0 a 59]
# - **Sentimiento**: Sentimiento del texto en -1: Negativo, 0: Neutral, 1: Positivo.

# %% [markdown]
# <a id="id2"></a>
#
# ## 2. Análisis descriptivo
#
# Inicialmente, lanzamos un describe para conocer cómo se distribuyen los datos y posibles incoherencias en los mismos, como número de likes negativos... etc.

# %%
# Lo ponemos de esta forma para quitar la notación científica
df_consejos.describe().apply(lambda s: s.apply(lambda x: format(x, 'g')))
# Out:
#          num_likes         anyo          mes          dia         hora  \
# count  1.22309e+06  1.22309e+06  1.22309e+06  1.22309e+06  1.22309e+06
# mean     0.0164738      2014.08      6.37506      15.7498      12.0047
# std        0.14564      2.29733       3.2916      8.80876      8.43059
# min              0         2009            1            1            0
# 25%              0         2012            4            8            3
# 50%              0         2014            6           16           15
# 75%              0         2016            9           23           20
# max             15         2018           12           31           23
#
#             minuto  sentimiento
# count  1.22309e+06  1.22309e+06
# mean       29.5622     0.463713
# std        17.3066     0.623019
# min              0           -1
# 25%             15            0
# 50%             30            1
# 75%             45            1
# max             59            1

# %% [markdown]
# - **num_likes:** La mayoría de comentarios sobre negocios no tienen likes como se puede observar. Hasta el 75% de los valores son de comentarios sin likes. Por lo que la media se acerca mucho a 0. El comentario con mayor puntuación llega a 15 likes y se puede ver que no hay puntuaciones negativas.
#
# - **año:** La media está bastante centrada y no tiene una desviación típica muy elevada por lo que la mayoría de los datos están relativamente cerca de la media. Observando los cuartiles se puede ver que los primeros 25% de los datos se distribuyen en 3 años mientras que los siguientes 50% se distribuyen en 4 esto puede ser porque en los primeros años de recogida no había suficientes comentarios.
#
# - **mes:** La media de los comentarios es de 6.37 esto puede significar que la mayoría de los datos se acumulan en este mes o si la desviación es alta es posible que los comentarios se produzcan a lo largo de todos los meses. Observando los cuartiles se puede observar como el 25% de los comentarios se acumulan en los 4 primeros meses, mientras que los siguientes 2 meses se acumula otro 25% por lo tanto cuanto más centrados los meses (que corresponden con el verano) más comentarios se producen.
#
# - **dia:** Observando la media de los días se puede ver bastante centrada aunque con una desviación típica elevada que indica que los valores no están concentrados cerca del valor medio. Además observando los cuartiles se puede apreciar una distribución bastante uniforme de los datos con lo cual no parece que el día del mes en principio influya para dejar comentarios
#
# - **hora:** Observando la media y la desviación típica se puede apreciar que la distribución de los comentarios por ahora no se acumula en los valores medios. Además observando como el 25% de los primeros datos se acumulan en las 3 primeras horas y como los 25% últimos datos se acumulan en las 3 últimas. Se puede sospechar que dependiendo de las horas la afluencia de comentarios puede variar.
#
# - **minuto:** Observando como la media de los minutos es 30 y como la desviación típica es bastante elevada se puede deducir que la distribución de los comentarios no se acumula en la media. Además  se puede ver una distribución uniforme ya que  los cuartiles coinciden perfectamente con los cuartos de una hora (15,30,45 y 60 que en este caso seria 59). Por lo tanto no hay minutos más significativos donde los usuarios traten de dejar más comentarios.
#
# - **sentimiento**: La media está en torno a 0.5, por lo que la mayoria de los comentarios/consejos son positivos. Existe menos de un 25% de negativos, menos o igual a un 25% de neutrales yel resto son positivas. Claramente la gran mayoría son comentarios positivos.

# %% [markdown]
# <a id="id3"></a>
#
#
# ## 3. Análisis de los comentarios
#
# Tras haber analizado mediente el describe las estidisticas basicas de los datos se van a graficar el numero de comentarios por año mes dia y minuto, para tratar

# %% [markdown]
# <a id="id3.1"></a>
#
# ### 3.1. Numero de comentarios por año

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig=plt.figure(figsize=(6,4))

ax = sns.countplot(x="anyo", data=df_consejos, palette="Blues_d")
plt.title("Numero de comentarios por año")
# Out:
# Text(0.5, 1.0, 'Numero de comentarios por año')

# %% [markdown]
# - Se puede ver un incremento de los registros de los comentarios en los primeros años hasta llegar a 2012, esta época podría ser del crecimiento de la plataforma.
#
# - A partir de ese punto el numero de comentarios decae lentamente.
#
# - Este gráfico se puede comparar con el de registros por año en el que se veía un crecimiento del número de registros hasta el 2015, año en el que los registros comienzan a disminuir. En este caso no se ve una disminución tan drástica, esto nos puede indicar que aunque dejaron de aparecer muchos nuevos usuarios, la plataforma se seguía utilizando al mismo nivel o decayendo un poco (sobre todo en 2018).
#
# - El primer comentario recogido es del 2009, y el primer registro de usuario en 2004, lo que indica que estos comentarios se añadieron más tarde a la plataforma o al menos que no tenemos información sobre ellos.

# %% [markdown]
# <a id="id3.2"></a>
#
# ### 3.2. Numero de comentarios por mes

# %%
ax = sns.countplot(x="mes", data=df_consejos, palette="Blues_d")
plt.title("Numero de registros por mes")
# Out:
# Text(0.5, 1.0, 'Numero de registros por mes')

# %% [markdown]
# - Los numeros del eje x representan los nombres de los meses y estan ordenados de enero (1) a diciembre (12).
#
# - Se puede observar como desde octubre a febrero el numero de comentarios es mas bajo de lo normal posiblemente porque en invierno la gente salga menos a distintos sitios y por lo tanto dejen menos comentarios.
#
# - Se puede observar que en julio y agosto hay un pico significativo en los comentarios posiblemente porque en verano la gente tiene mas tiempo libre y hace mejor clima para salir a distintos sitios y dejar mas comentarios.

# %% [markdown]
# <a id="id3.3"></a>
#
# ### 3.3. Numero de comentarios por dia

# %%
fig=plt.figure(figsize=(10,4))
ax = sns.countplot(x="dia", data=df_consejos, palette="Blues_d")
plt.title("Numero de registros por dia")
# Out:
# Text(0.5, 1.0, 'Numero de registros por dia')

# %% [markdown]
# -Se puede ver como los dias no influye en el numero de comentarios ya que no hay grandes variaciones.
#
# -Al final los valores de los comentarios por dia decaen ya que no todos los meses tienen 31 dias.

# %% [markdown]
# <a id="id3.4"></a>
#
# ### 3.4. Numero de comentarios por hora

# %%
fig=plt.figure(figsize=(6,4))
ax = sns.countplot(x="hora", data=df_consejos, palette="Blues_d")
plt.title("Numero de registros por hora")
# Out:
# Text(0.5, 1.0, 'Numero de registros por hora')

# %% [markdown]
# - Se puede ver claramente como hay una tendencia clara a dejar comentarios a ciertas horas. Esta tendencia corresponde con las horas de descanso en el país en el que se realiza el uso. La hora esta ajustada a UTC+0 por lo que no se corresponde con las horas reales de uso, pero sí la tendencia.
#
# - Este gráfrico tambien se puede comparar con el de registros por hora de usuarios. Se sigue la misma distribución, de nuevo, por la misma razón, el uso de la plataforma en las horas más normales.

# %% [markdown]
# <a id="id3.5"></a>
#
# ### 3.5. Numero de comentarios por minuto

# %%
gk=df_consejos.drop(['mes','anyo','num_likes','hora','negocio_id','usuario_id','dia'],axis=1)
gk.groupby('minuto').count().plot()

# %% [markdown]
# -Se puede apreciar una funcion con muchos altibajos que no varia mucho ya que el maximo es 20700 y el minimo 20100 esto supone solo una diferencia de 600 para valores de 20000. Por lo tanto los minutos no son relevantes a la hora de analizar los comentarios lo cual tiene sentido ya que las personas no se fijan en una medida de tiempo tan pequeña para dejar comentarios.

# %% [markdown]
# <a id="id3.6"></a>
#
# ### 3.6. Evolucion de los comentarios por año
# Seria interesante mostrar los comentarios a lo largo de los años de los negocios con mas consejos (ya que tenemos mas datos) y ver como evoluciona el numero de comentarios a lo largo de los años de los 30 primeros negocios con mas comentarios y si estos siguen una tendencia.

# %%
negocios=df_consejos.drop(['num_likes','mes','hora','minuto','usuario_id','dia'],axis=1)
aux=negocios.groupby(['negocio_id']).count().sort_values(by="texto",ascending=False).reset_index()
lista=[]
for i in range(30):
    lista.append(aux.iloc[i]['negocio_id'])
aux=negocios.groupby(['negocio_id','anyo']).count().reset_index().sort_values(by='negocio_id',ascending=False).pivot("anyo","negocio_id","texto")
listAux=list(aux.columns)
for i in range(30):
    listAux.remove(lista[i])
negocios_reducido=aux.drop(listAux,axis=1)

# %%
df100negocios=pd.DataFrame()
df100negocios=negocios_reducido
negocios_reducido
# Out:
# negocio_id  4JNXUYY8wbaaDmk3BPzlWw  5LNZ67Yw9RD6nf4_UhXOjw  \
# anyo
# 2009                           NaN                     NaN
# 2010                          48.0                    32.0
# 2011                         206.0                   563.0
# 2012                         246.0                   413.0
# 2013                         177.0                   183.0
# 2014                         128.0                   113.0
# 2015                          99.0                    54.0
# 2016                          82.0                    60.0
# 2017                          62.0                    35.0
# 2018                          73.0                    34.0
#
# negocio_id  7sPNbCx7vGAaH7SbNPZ6oA  DkYS3arLOhA8si5uUEmHOw  \
# anyo
# 2009                           NaN                     NaN
# 2010                          86.0                    77.0
# 2011                         165.0                   432.0
# 2012                         209.0                   519.0
# 2013                         169.0                   156.0
# 2014                         174.0                   139.0
# 2015                          66.0                    75.0
# 2016                          65.0                    54.0
# 2017                          60.0                    35.0
# 2018                          24.0                    16.0
#
# negocio_id  El4FC8jcawUVgw_0EIcbaQ  FaHADZARwnY4yvlvpnsfGA  \
# anyo
# 2009                           NaN                     NaN
# 2010                          53.0                   218.0
# 2011                         153.0                  1263.0
# 2012                         223.0                  1306.0
# 2013                          91.0                   296.0
# 2014                          85.0                   242.0
# 2015                          61.0                    90.0
# 2016                          53.0                    85.0
# 2017                          35.0                    68.0
# 2018                          29.0                    46.0
#
# negocio_id  JmI9nslLD7KZqRr__Bg6NQ  JyxHvtj-syke7m9rbza7mA  \
# anyo
# 2009                           NaN                     NaN
# 2010                         173.0                     NaN
# 2011                         818.0                   212.0
# 2012                         792.0                   283.0
# 2013                         239.0                   139.0
# 2014                         186.0                    99.0
# 2015                          63.0                    68.0
# 2016                          60.0                    52.0
# 2017                          67.0                    31.0
# 2018                          42.0                    19.0
#
# negocio_id  JzOp695tclcNCNMuBl7oxA  K7lWdNUhCbcnEvI0NhGewg  ...  \
# anyo                                                        ...
# 2009                           NaN                     NaN  ...
# 2010                          66.0                    10.0  ...
# 2011                         200.0                   377.0  ...
# 2012                         164.0                   446.0  ...
# 2013                          71.0                   172.0  ...
# 2014                          77.0                   186.0  ...
# 2015                          62.0                    62.0  ...
# 2016                          51.0                    50.0  ...
# 2017                          35.0                    58.0  ...
# 2018                          36.0                    25.0  ...
#
# negocio_id  cYwJA2A6I12KNkm2rtXd5g  eAc9Vd6loOgRQolMXQt6FA  \
# anyo
# 2009                           NaN                     NaN
# 2010                           NaN                    39.0
# 2011                           NaN                   226.0
# 2012                           7.0                   177.0
# 2013                         299.0                    80.0
# 2014                         209.0                    56.0
# 2015                         130.0                    31.0
# 2016                         105.0                    54.0
# 2017                          25.0                    33.0
# 2018                           1.0                    23.0
#
# negocio_id  eoHdUeQDNgQ6WYEnP2aiRw  f4x1YBxkLrZg652xt2KR5g  \
# anyo
# 2009                           2.0                     NaN
# 2010                         113.0                    36.0
# 2011                         269.0                   128.0
# 2012                         238.0                   122.0
# 2013                         131.0                   117.0
# 2014                          98.0                   128.0
# 2015                          60.0                   115.0
# 2016                          40.0                    82.0
# 2017                           3.0                    88.0
# 2018                           NaN                    44.0
#
# negocio_id  g8OnV26ywJlZpezdBnOWUQ  hihud--QRriCYZw1zZvW4g  \
# anyo
# 2009                           1.0                     NaN
# 2010                          79.0                     NaN
# 2011                         176.0                     NaN
# 2012                         154.0                     NaN
# 2013                          95.0                    21.0
# 2014                          91.0                    20.0
# 2015                          46.0                   408.0
# 2016                          29.0                   634.0
# 2017                          24.0                   157.0
# 2018                          16.0                   131.0
#
# negocio_id  iCQpiavjjPzJ5_3gPD5Ebg  na4Th5DrNauOv-c43QQFvA  \
# anyo
# 2009                           NaN                     1.0
# 2010                           1.0                    58.0
# 2011                         222.0                   208.0
# 2012                         292.0                   191.0
# 2013                         124.0                    96.0
# 2014                         148.0                    65.0
# 2015                         106.0                    46.0
# 2016                          76.0                    42.0
# 2017                          86.0                    30.0
# 2018                          50.0                    22.0
#
# negocio_id  yQab5dxZzgBLTEHCw9V7_w  yfxDa8RFOvJPQh0rNtakHA
# anyo
# 2009                           1.0                     2.0
# 2010                          62.0                    63.0
# 2011                         210.0                   253.0
# 2012                         221.0                   303.0
# 2013                         145.0                   137.0
# 2014                         113.0                   129.0
# 2015                          40.0                    69.0
# 2016                          66.0                    71.0
# 2017                          50.0                    54.0
# 2018                          30.0                    36.0
#
# [10 rows x 30 columns]

# %%
import math
for j in negocios_reducido:
    mylist=negocios_reducido[j].tolist()
    mylistaux=[0]*10
    contador=0
    for i in mylist:
        if not math.isnan(i):
            mylistaux[contador]=i
            contador+=1
    df100negocios[j]=mylistaux
df100negocios
# Out:
# negocio_id  4JNXUYY8wbaaDmk3BPzlWw  5LNZ67Yw9RD6nf4_UhXOjw  \
# anyo
# 2009                          48.0                    32.0
# 2010                         206.0                   563.0
# 2011                         246.0                   413.0
# 2012                         177.0                   183.0
# 2013                         128.0                   113.0
# 2014                          99.0                    54.0
# 2015                          82.0                    60.0
# 2016                          62.0                    35.0
# 2017                          73.0                    34.0
# 2018                           0.0                     0.0
#
# negocio_id  7sPNbCx7vGAaH7SbNPZ6oA  DkYS3arLOhA8si5uUEmHOw  \
# anyo
# 2009                          86.0                    77.0
# 2010                         165.0                   432.0
# 2011                         209.0                   519.0
# 2012                         169.0                   156.0
# 2013                         174.0                   139.0
# 2014                          66.0                    75.0
# 2015                          65.0                    54.0
# 2016                          60.0                    35.0
# 2017                          24.0                    16.0
# 2018                           0.0                     0.0
#
# negocio_id  El4FC8jcawUVgw_0EIcbaQ  FaHADZARwnY4yvlvpnsfGA  \
# anyo
# 2009                          53.0                   218.0
# 2010                         153.0                  1263.0
# 2011                         223.0                  1306.0
# 2012                          91.0                   296.0
# 2013                          85.0                   242.0
# 2014                          61.0                    90.0
# 2015                          53.0                    85.0
# 2016                          35.0                    68.0
# 2017                          29.0                    46.0
# 2018                           0.0                     0.0
#
# negocio_id  JmI9nslLD7KZqRr__Bg6NQ  JyxHvtj-syke7m9rbza7mA  \
# anyo
# 2009                         173.0                   212.0
# 2010                         818.0                   283.0
# 2011                         792.0                   139.0
# 2012                         239.0                    99.0
# 2013                         186.0                    68.0
# 2014                          63.0                    52.0
# 2015                          60.0                    31.0
# 2016                          67.0                    19.0
# 2017                          42.0                     0.0
# 2018                           0.0                     0.0
#
# negocio_id  JzOp695tclcNCNMuBl7oxA  K7lWdNUhCbcnEvI0NhGewg  ...  \
# anyo                                                        ...
# 2009                          66.0                    10.0  ...
# 2010                         200.0                   377.0  ...
# 2011                         164.0                   446.0  ...
# 2012                          71.0                   172.0  ...
# 2013                          77.0                   186.0  ...
# 2014                          62.0                    62.0  ...
# 2015                          51.0                    50.0  ...
# 2016                          35.0                    58.0  ...
# 2017                          36.0                    25.0  ...
# 2018                           0.0                     0.0  ...
#
# negocio_id  cYwJA2A6I12KNkm2rtXd5g  eAc9Vd6loOgRQolMXQt6FA  \
# anyo
# 2009                           7.0                    39.0
# 2010                         299.0                   226.0
# 2011                         209.0                   177.0
# 2012                         130.0                    80.0
# 2013                         105.0                    56.0
# 2014                          25.0                    31.0
# 2015                           1.0                    54.0
# 2016                           0.0                    33.0
# 2017                           0.0                    23.0
# 2018                           0.0                     0.0
#
# negocio_id  eoHdUeQDNgQ6WYEnP2aiRw  f4x1YBxkLrZg652xt2KR5g  \
# anyo
# 2009                           2.0                    36.0
# 2010                         113.0                   128.0
# 2011                         269.0                   122.0
# 2012                         238.0                   117.0
# 2013                         131.0                   128.0
# 2014                          98.0                   115.0
# 2015                          60.0                    82.0
# 2016                          40.0                    88.0
# 2017                           3.0                    44.0
# 2018                           0.0                     0.0
#
# negocio_id  g8OnV26ywJlZpezdBnOWUQ  hihud--QRriCYZw1zZvW4g  \
# anyo
# 2009                           1.0                    21.0
# 2010                          79.0                    20.0
# 2011                         176.0                   408.0
# 2012                         154.0                   634.0
# 2013                          95.0                   157.0
# 2014                          91.0                   131.0
# 2015                          46.0                     0.0
# 2016                          29.0                     0.0
# 2017                          24.0                     0.0
# 2018                          16.0                     0.0
#
# negocio_id  iCQpiavjjPzJ5_3gPD5Ebg  na4Th5DrNauOv-c43QQFvA  \
# anyo
# 2009                           1.0                     1.0
# 2010                         222.0                    58.0
# 2011                         292.0                   208.0
# 2012                         124.0                   191.0
# 2013                         148.0                    96.0
# 2014                         106.0                    65.0
# 2015                          76.0                    46.0
# 2016                          86.0                    42.0
# 2017                          50.0                    30.0
# 2018                           0.0                    22.0
#
# negocio_id  yQab5dxZzgBLTEHCw9V7_w  yfxDa8RFOvJPQh0rNtakHA
# anyo
# 2009                           1.0                     2.0
# 2010                          62.0                    63.0
# 2011                         210.0                   253.0
# 2012                         221.0                   303.0
# 2013                         145.0                   137.0
# 2014                         113.0                   129.0
# 2015                          40.0                    69.0
# 2016                          66.0                    71.0
# 2017                          50.0                    54.0
# 2018                          30.0                    36.0
#
# [10 rows x 30 columns]

# %% [markdown]
# Había ciertos negocios de los cuales no teníamos datos en los primeros años o en los ultimos años. Posiblemente porque los negocios cerraron antes del 2018 o porque abrieron en algun año posterior a 2009 por lo tanto para poder comparar todos los negocios, se han alineado en 2009 y si faltan datos para llegar a 2018 se han añadido 0. (ya que al no haber datos suponemos que los negocios no tienen comentarios)

# %%
df100negocios.plot(figsize=(25,25))

# %% [markdown]
# La explicación a la tendencia que se puede ver podría ser porque haya restaurantes que tuvieron su mejor época en los primeros años de la gráfica, 2009, 2010, 2011... etc, ya sea porque son negocios en tendencia en ese momento o porque la plataforma estaba de moda en esos momentos (o las dos opciones).
#
# Después de un tiempo se han dejado de comentar estos lugares, apoyándonos en la gráfica de comentarios por año que hemos obtenido antes, la cuál representa todos los comentarios de todos los negocios por año, se puede ver como hay una bajada del número de comentarios pero no tan grande como la que hemos visto ahora. Esto se puede deber a que **estos negocios, tuvieron su momento** en el que se comentaba mucho y hasta el momento son los mas comentados, pero puede ser que **en los últimos años se hayan comentado más otros negocios que hayan sido tendencia**.
#
# Esto nos podría servir para dar la posibilidad a nuestro cliente de crear alguna **forma llamativa para que no se deje de comentar** en los negocios y así evitar la disminución de comentarios. **Aunque** como ya decimos, esta disminución acompaña tambien el número de registros, numero de likes... etc, es decir, **el uso de la plataforma ha ido disminuyendo**.

# %% [markdown]
# <a id="id4"></a>
#
# ## 4. Usuarios que hacen consejos

# %% [markdown]
# En este momento esto no nos sirve para nada, pero si juntamos dataset de consejos y usuarios, podriamos ver las características de los usuarios que más comentan.

# %%
df_consejos.groupby('usuario_id').count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# usuario_id
# mkbx55W8B8aPLgDqex7qgg    2439
# CxDOIDnH8gp9KXzpBHJYXw    1598
# 6ZC-0LfOAGwaFc5XPke74w    1509
# 0tvCcnfJnSs55iB6mqPk3w    1376
# eZfHm0qI8A_HfvXScwIYsg    1352
# O8eDScRAg6ae0l9Bc24uMA    1255
# 8DGFWco9VeBAxjqsuh1aSw    1178
# WJKocp9RE0KatUwh3_DkGg    1161
# 2EuPAGalYnP7eSxPgFCNDg    1154
# QPJJohtGqkMkaN0Gt3TRIg    1017
# Name: texto, dtype: int64

# %% [markdown]
# Ahora vamos a obtener los usuarios que más comentarios negativos o positivos dejan, con estos datos también podríamos ver en el dataset de usuarios que tipo de usuarios son.

# %%
negativos = df_consejos[df_consejos['sentimiento'] == -1].groupby(['usuario_id']).count().sort_values(['texto'], ascending=False).head(10)['texto'].index
df_consejos[df_consejos['sentimiento'] == -1].groupby(['usuario_id']).count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# usuario_id
# mkbx55W8B8aPLgDqex7qgg    150
# 8DGFWco9VeBAxjqsuh1aSw    108
# sCbcImu1yyzncjWN7L9hXA    101
# 0ygWZ_gXF8qTm0bY95JJqA     94
# O8eDScRAg6ae0l9Bc24uMA     91
# 6ZC-0LfOAGwaFc5XPke74w     85
# eZfHm0qI8A_HfvXScwIYsg     81
# CxDOIDnH8gp9KXzpBHJYXw     81
# 5dKknvq65x-SaluuJjT0Kw     73
# 0tvCcnfJnSs55iB6mqPk3w     73
# Name: texto, dtype: int64

# %%
positivos = df_consejos[df_consejos['sentimiento'] == 1].groupby(['usuario_id']).count().sort_values(['texto'], ascending=False).head(10)['texto'].index
df_consejos[df_consejos['sentimiento'] == 1].groupby(['usuario_id']).count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# usuario_id
# mkbx55W8B8aPLgDqex7qgg    1008
# 6ZC-0LfOAGwaFc5XPke74w     632
# O8eDScRAg6ae0l9Bc24uMA     615
# WJKocp9RE0KatUwh3_DkGg     613
# QPJJohtGqkMkaN0Gt3TRIg     606
# CxDOIDnH8gp9KXzpBHJYXw     547
# eZfHm0qI8A_HfvXScwIYsg     546
# tQPk4JiBPsx7NSIDbW49Vg     462
# uG35h72BAMutvXAWdRpqCQ     446
# A0j21z2Q1HGic7jW6e9h7A     427
# Name: texto, dtype: int64

# %% [markdown]
# A primera vista no se puede obtener ninguna conclusión importante, pero sí será interesante ver quienes son estos usuarios, cuantos seguidores tienen, si han sido expertos... etc. Algo que si se puede ver en los datos anteriores es que algunos de los usuarios que más comentan son también los que más comentan de forma positiva y negativa, tiene sentido ya que comentarán aquello que se encuentren, pero si encontrasemos un usuario que solo comenta de forma negativa, podríamos detectar 'haters'. Hemos recogido los 10 usuarios con más comentarios negativos, los 10 con más positivos, la diferencia entre esas listas nos podría indicar posibles haters (o simplemente usuarios que suelen usar los comentarios para decir cosas negativas).

# %%
negativos = negativos.tolist()
positivos = positivos.tolist()

# %%
result = list(set(negativos) - set(positivos))
result
# Out:
# ['0ygWZ_gXF8qTm0bY95JJqA',
#  '5dKknvq65x-SaluuJjT0Kw',
#  '8DGFWco9VeBAxjqsuh1aSw',
#  '0tvCcnfJnSs55iB6mqPk3w',
#  'sCbcImu1yyzncjWN7L9hXA']

# %%
df_users = pd.read_csv('Dataset/datos_users_limpio.csv')

# %%
pd.set_option('display.max_columns', 500)

df_users[df_users['usuario_id'].isin(result)]
# Out:
#                     usuario_id  nombre  num_opiniones   util  gracioso  guay  \
# 10592   0tvCcnfJnSs55iB6mqPk3w  Daniel           1232  11432      6402  9669
# 28173   0ygWZ_gXF8qTm0bY95JJqA    Cris            541    950       489   222
# 165302  8DGFWco9VeBAxjqsuh1aSw   Kurdy            336   2164      1594  1747
# 191613  5dKknvq65x-SaluuJjT0Kw    John             10    107        52    51
# 192245  sCbcImu1yyzncjWN7L9hXA    Adam             50     63        20    14
#
#                                         experto  \
# 10592        2012,2013,2014,2015,2016,2017,2018
# 28173                                   Ninguno
# 165302  2010,2011,2012,2013,2014,2015,2016,2017
# 191613                                  Ninguno
# 192245                                  Ninguno
#
#                                                    amigos  num_amigos  \
# 10592   nCLrbxT009k8z3mQXZ1M9g, 5I6-yegWr4p1mtUMwNkVtg...        1170
# 28173   vv52_GpRV1sndRycoreLQg, XylT12exfdLiI_3uDLVIpw...          69
# 165302  JezC_omjXuXp2AE3QHxWZA, 3_Xrok7pV_MNBHhCPy2hgg...        1354
# 191613  l6_yUOxdIQDIP9qCkMNowQ, eA8WqJj_15lWURDwE6DsKQ...         115
# 192245  3xwdLRJRRAPZ7G-pFbG6Eg, H8ioT8d48-xsLa4GqIOG5g...         154
#
#         seguidores  media_puntuacion  like_moda  like_extras  like_perfil  \
# 10592          177              3.62        783          214          136
# 28173           23              2.66          2            5            0
# 165302          88              4.05        599           36           32
# 191613          21              2.75         27            5            3
# 192245           4              4.19          4            2            0
#
#         like_formato  like_lista  like_comentario  like_simple  like_guay  \
# 10592             46          10              744         1737       2066
# 28173              0           0               26           15         12
# 165302            12           9              222          718        600
# 191613             1           0               40           48         65
# 192245             0           0                7           13          9
#
#         like_divertido  like_textos  like_fotos  anyo_reg  mes_reg  dia_reg  \
# 10592             2066          995         895      2011        2        6
# 28173               12            4           2      2009        8       22
# 165302             600          166         134      2009        4        6
# 191613              65            8          83      2011        2       23
# 192245               9            5           0      2011        1        9
#
#         hora_reg
# 10592         16
# 28173         16
# 165302        23
# 191613        20
# 192245        21

# %% [markdown]
# No podemos obtener conclusiones muy grandes sobre este último análisis ya que no se hay hecho de forma profunda y el objetivo tampoco está muy bien definido. Pero en la impresión de usuarios de encima podemos ver algunos datos que llaman la atención, por ejmplo que 3 de los usuarios han dado de media una puntuación baja, que tiene sentido si pensamos que son usuarios con una cantidad grande de consejos negativos. Por otro lado, son usuarios extraños ya que tienen pocos seguidores pero dos de ellos han sido expertos bastantes años, probablmeente por tener una red de amigos grande.

# %% [markdown]
# <a id="id5"></a>
#
# ## 5. Negocios que reciben consejos

# %% [markdown]
# De nuevo, en este momento esto no nos sirve para nada, pero si juntamos dataset de consejos y negocios, podríamos ver las características de los negocios más comentados.
# Obtenemos los 10 negocios con una mayor cantidad de comentarios:

# %%
df_consejos.groupby('negocio_id').count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# negocio_id
# FaHADZARwnY4yvlvpnsfGA    3614
# JmI9nslLD7KZqRr__Bg6NQ    2440
# DkYS3arLOhA8si5uUEmHOw    1503
# 5LNZ67Yw9RD6nf4_UhXOjw    1487
# K7lWdNUhCbcnEvI0NhGewg    1386
# hihud--QRriCYZw1zZvW4g    1371
# RESDUcs7fIiihp38-d6_6g    1264
# 4JNXUYY8wbaaDmk3BPzlWw    1121
# yfxDa8RFOvJPQh0rNtakHA    1117
# iCQpiavjjPzJ5_3gPD5Ebg    1105
# Name: texto, dtype: int64

# %% [markdown]
# Al igual que con los usuarios, sería interesante obtener los 10 negocios con mas comentarios negativos, los 10 negocios con más positivos y al hacer la diferencia obtener aquellos negocios que tienen muchos comentarios pero la mayoria son negativos. Tambien lo podemos hacer a la inversa para obtener aquellos con más comentarios pero la mayoria sean positivos.

# %%
# Se obtienen los negativos
negativos = df_consejos[df_consejos['sentimiento'] == -1].groupby(['negocio_id']).count().sort_values(['texto'], ascending=False).head(10)['texto'].index
df_consejos[df_consejos['sentimiento'] == -1].groupby(['negocio_id']).count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# negocio_id
# FaHADZARwnY4yvlvpnsfGA    296
# JmI9nslLD7KZqRr__Bg6NQ    181
# DkYS3arLOhA8si5uUEmHOw    121
# f4x1YBxkLrZg652xt2KR5g    120
# iCQpiavjjPzJ5_3gPD5Ebg    117
# g8OnV26ywJlZpezdBnOWUQ    106
# yfxDa8RFOvJPQh0rNtakHA    106
# K7lWdNUhCbcnEvI0NhGewg    104
# DN0b4Un8--Uf6SEWLeh0UA     89
# yQab5dxZzgBLTEHCw9V7_w     80
# Name: texto, dtype: int64

# %%
# Se obtienen los positivos
positivos = df_consejos[df_consejos['sentimiento'] == 1].groupby(['negocio_id']).count().sort_values(['texto'], ascending=False).head(10)['texto'].index
df_consejos[df_consejos['sentimiento'] == 1].groupby(['negocio_id']).count().sort_values(['texto'], ascending=False).head(10)['texto']
# Out:
# negocio_id
# hihud--QRriCYZw1zZvW4g    1215
# FaHADZARwnY4yvlvpnsfGA     963
# JmI9nslLD7KZqRr__Bg6NQ     747
# DkYS3arLOhA8si5uUEmHOw     674
# 5LNZ67Yw9RD6nf4_UhXOjw     665
# 4JNXUYY8wbaaDmk3BPzlWw     656
# K7lWdNUhCbcnEvI0NhGewg     623
# RESDUcs7fIiihp38-d6_6g     618
# eoHdUeQDNgQ6WYEnP2aiRw     551
# UPIYuRaZvknINOd1w8kqRQ     481
# Name: texto, dtype: int64

# %%
negativos = negativos.tolist()
positivos = positivos.tolist()

# %%
# Esta es la diferencia, es decir, los negocios con más comentarios negativos sin tener muchos positivos
result = list(set(negativos) - set(positivos))
result
# Out:
# ['iCQpiavjjPzJ5_3gPD5Ebg',
#  'g8OnV26ywJlZpezdBnOWUQ',
#  'yfxDa8RFOvJPQh0rNtakHA',
#  'f4x1YBxkLrZg652xt2KR5g',
#  'yQab5dxZzgBLTEHCw9V7_w',
#  'DN0b4Un8--Uf6SEWLeh0UA']

# %% [markdown]
# <a id="id6"></a>
#
# ## 6. Análisis de Likes en Consejos
#
# El numero de likes que tienen los comentarios sigue distribuciones muy similares a las de los comentarios por lo tanto a no ser que haya excepciones las explicaciones son las mismas.

# %% [markdown]
# <a id="id6.1"></a>
#
# ### 6.1. Numero de likes por año

# %%
glikes=df_consejos.drop(['mes','dia','hora','minuto','texto','negocio_id','usuario_id'],axis=1)
glikes.groupby('anyo').sum().plot()

# %% [markdown]
# - Al igual que con el número de comentarios, se puede ver que la mayor cantidad de likes se recibieron en los años 2012, 2013... etc.

# %% [markdown]
# <a id="id6.2"></a>
#
# ### 6.2. Numero de likes por Mes

# %%
glikes=df_consejos.drop(['anyo','dia','hora','minuto','texto','negocio_id','usuario_id'],axis=1)
glikes.groupby('mes').sum().plot()

# %% [markdown]
# - Al igual que con los comentarios, los meses de mayor uso de la plataforma son los meses de verano o de vacaciones.

# %% [markdown]
# <a id="id6.3"></a>
#
# ### 6.3. Numero de likes por Hora

# %%
glikes=df_consejos.drop(['mes','anyo','dia','minuto','texto','negocio_id','usuario_id'],axis=1)
glikes.groupby('hora').sum().plot()

# %% [markdown]
# Sin ninguna novedad, este grafico nos vuelve a indicar las horas de uso de la plataforma.

# %% [markdown]
# <a id="id7"></a>
#
# ## 7. Boxplots
# Acontinuacion se pasara a analizar las estadisticas del numero de likes de los comentarios en funcion de los distintos meses.

# %%
boxplot_consejos=df_consejos.drop(['texto','anyo','hora','negocio_id','usuario_id','dia','minuto'],axis=1)
boxplot_consejos.boxplot(by="mes", figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fac4b755128>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fac26caa6a0>],
#       dtype=object)

# %% [markdown]
# En el anterior boxplot que muestra la informacion de los likes que tienen los comentarios se puede ver que la mayoria de likes estan acumulados en 0 que es donde estan todos los boxplot. El resto de valores son puntos atipicos que se salen de la media y por lo tanto no se puede sacar informacion relevante de ellos.
#
# Para poder tratar de analizar los demas comentarios la distribucion que siguen vamos a eliminar de la base todos los comentarios que tienen 0 likes

# %%
boxplot_consejos=df_consejos.drop(df_consejos[df_consejos.num_likes <= 1].index)

boxplot_consejos=boxplot_consejos.drop(['texto','anyo','hora','negocio_id','usuario_id','dia','minuto'],axis=1)
print(boxplot_consejos.describe())
boxplot_consejos.boxplot(by='mes')
# Out:
#          num_likes          mes  sentimiento
# count  1715.000000  1715.000000  1715.000000
# mean      2.279883     6.449563     0.275802
# std       0.808955     3.439287     0.642952
# min       2.000000     1.000000    -1.000000
# 25%       2.000000     3.000000     0.000000
# 50%       2.000000     7.000000     0.000000
# 75%       2.000000     9.000000     1.000000
# max      15.000000    12.000000     1.000000
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fac2693a518>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fac269516d8>],
#       dtype=object)

# %% [markdown]
# Se puede ver como el problema persiste con comentarios superiores a 0 likes por lo que se tratara de filtrar los comentarios por un numero de likes mas elevado

# %%
boxplot_consejos=df_consejos.drop(df_consejos[df_consejos.num_likes <= 3].index)

boxplot_consejos=boxplot_consejos.drop(['texto','anyo','hora','negocio_id','usuario_id','dia','minuto'],axis=1)
print(boxplot_consejos.describe())
boxplot_consejos.boxplot(by='mes')
# Out:
#        num_likes        mes  sentimiento
# count   86.00000  86.000000    86.000000
# mean     4.94186   6.779070     0.186047
# std      1.83017   2.928164     0.694713
# min      4.00000   1.000000    -1.000000
# 25%      4.00000   5.000000     0.000000
# 50%      4.00000   7.000000     0.000000
# 75%      5.00000   9.000000     1.000000
# max     15.00000  12.000000     1.000000
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fac26646f98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fac2666f048>],
#       dtype=object)

# %% [markdown]
# -El numero de comentarios que tienen 3 o mas likes es solamente de 86 en comparacion con los 1.2 millones de comentarios por lo que no supone un gran numero.

# %%
gk=df_consejos.drop(['texto','mes','hora','minuto','usuario_id','dia'],axis=1)
gk[gk.negocio_id=='DkYS3arLOhA8si5uUEmHOw'].groupby(['anyo']).count().plot()

# %% [markdown]
# <a id="id8"></a>
#
# ## 8. Wordcloud en consejos

# %%
df_consejos
# Out:
#                      usuario_id              negocio_id  \
# 0        UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1        Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2        jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3        FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4        LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...                         ...                     ...
# 1223085  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223086  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223087  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223088  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223089  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                      texto  num_likes  anyo  \
# 0        Great for watching games, ufc, and whatever el...          0  2014
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...          0  2013
# 2        Good chips and salsa. Loud at times. Good serv...          0  2011
# 3        The setting and decoration here is amazing. Co...          0  2014
# 4        Molly is definately taking a picture with Sant...          0  2012
# ...                                                    ...        ...   ...
# 1223085                Very good class, great instructor!!          0  2018
# 1223086                                     Excellent food          0  2018
# 1223087     Jess is the best bartender!! Go check her out!          0  2018
# 1223088  Excellent food and AMAZING service by Anneliese!!          0  2018
# 1223089                                         Funnnnn!!!          0  2018
#
#          mes  dia  hora  minuto  sentimiento
# 0          3   27     3      51            1
# 1          5   25     6       0            0
# 2         12   26     1      46            0
# 3          3   23    21      32            1
# 4         10    6     0      19            0
# ...      ...  ...   ...     ...          ...
# 1223085    8    5    20      58            1
# 1223086    8   15    18       5            1
# 1223087   10    2     3      34            1
# 1223088   10   13    16      57            1
# 1223089   11   10     3      17            0
#
# [1223090 rows x 10 columns]

# %%
numConsejos = 1000

listBad = df_consejos[df_consejos['sentimiento'] == -1]['texto'].tolist()[:numConsejos]
listGood = df_consejos[df_consejos['sentimiento'] == 1]['texto'].tolist()[:numConsejos]

listBad = [linea + ' ' for linea in listBad]
listGood = [linea + ' ' for linea in listGood]

# %%
textBad = ''.join(listBad)
textGood = ''.join(listGood)

# %%
from PIL import Image
import numpy as np
from wordcloud import ImageColorGenerator

char_mask_bad = np.array(Image.open("Imagen/darthvader.jpg"))
image_colors_bad = ImageColorGenerator(char_mask_bad)

char_mask_good = np.array(Image.open("Imagen/yoda.jpg"))
image_colors_good = ImageColorGenerator(char_mask_good)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc = WordCloud(background_color = "white", max_words=500, width=100, height=100, mask=char_mask_bad, random_state=1).generate(textBad)

plt.figure(figsize=(15, 15))
plt.axis('off')

plt.imshow(wc.recolor(color_func=image_colors_bad),interpolation="bilinear")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc = WordCloud(background_color = "white", max_words=600, width=100, height=100, mask=char_mask_good, random_state=1).generate(textGood)

plt.figure(figsize=(15, 15))
plt.axis('off')

plt.imshow(wc.recolor(color_func=image_colors_good),interpolation="bilinear")

# %% [markdown]
# Para entender más correctamente cuál es el contenido de los consejos, los hemos separado en los que se supone que son malos y los que son buenos según el análisis de sentimiento hecho anteriormente. Para ello, hemos utilizado **Procesamiento de Lenguaje Natural** y **Text Mining** de forma muy **superficial**; no hemos aplicado Stopwords, no hemos filtrado caracteres especiales y tampoco hemos aplicado Stemming. Sin embargo, aun no habiendo aplicado estas técnicas, los resultados arrojados por los dos wordcloud son lo suficientemente buenos como para hacernos una idea del contenido de los consejos.
#
# Se pueden hacer algunas observaciones útiles a partir de los wordcloud:
#
# - En el **wordcloud negativo**, muchas de las **palabras más frecuentes son negativas**. Algunos ejemplos son **"worst"**, **"horrible"**, **"slow"**, **"bad"**, **"poor"**, etc... También hay algunas palabras que pueden ser errores del algoritmo como "Good", pero aparecen en menor medida. En el caso del **wordcloud positivo**, ocurre exactamente lo contrario, hay muchas **palabras positivas**. Algunos ejemplos son **"Great"**, **"free"**, **"good"**, etc... En este caso, los errores producidos por el algoritmo son menores.
#
#
# - Algo que llama la atención bastante es que en el **wordcloud negativo**, la palabra más frecuente es **chicken**. Esto puede ser un fallo en al preparación de los datos. Otra opción es que la mayoría de los restaurantes en los que se vende pollo sean malos y, por lo tanto, tengan una cantidad de consejos con connotaciones negativas muy altas. Esto produciría que la palabra chicken saliera numerosas veces catalogada como mala.
#
#
# - La palabra "food" aparece bastante grande en el wordcloud, por lo que podríamos deducir que normalmente estos negocios son los que consejos más positivos tienen.

# %% [markdown]
# Para averiguar por qué aparece "chicken" como palabra frecuente en consejos negativos, vamos a comprobar los consejos que contienen esta palabra.

# %%
df_consejosNegativos = df_consejos[df_consejos['sentimiento'] == -1][['negocio_id', 'texto']]
df_consejosNegativos
# Out:
#                      negocio_id  \
# 5        kj1p6NwUGROOoqNySf0I1Q
# 8        YCRCFBr6myPS49on2aS2pQ
# 24       7sPNbCx7vGAaH7SbNPZ6oA
# 51       6sKaAF8WhWyyCjfZr2Rfsg
# 59       E9aC5bLfXdQVZ5csvLuLJg
# ...                         ...
# 1223026  DVfCbJhJUDWRlUfrKzaKOA
# 1223042  Lmqj8Me1EiYljYj0N1W7JA
# 1223043  h7LFuLPpjPwJAxX3HHJY1w
# 1223052  TfcQhrjJco0C_x0KVK7LwA
# 1223059  hxe8xidZ04BfdqQ-oUADiQ
#
#                                                      texto
# 5           It's true! The drunken noodles are outrageous!
# 8        Sat in the drive thru this afternoon for 30 mi...
# 24                           Late night burger cravings...
# 51                                         Last time... =(
# 59       Green papaya salad not good.  Papaya sliced to...
# ...                                                    ...
# 1223026  Don't ever buy their charsiu/bbq pork or their...
# 1223042  Patio only open until 11 PM due to residences ...
# 1223043  This is the worst place to go to ever! Went he...
# 1223052  They have the pac 12 network so I never have t...
# 1223059  The steak was horrible. Worst I have eaten in ...
#
# [85292 rows x 2 columns]

# %%
# df_consejosNegativos[df_consejosNegativos['texto'].find('chicken')]

def preprocesa(x):
    if "chicken" in str(x):
        print(x)

consejosChicken = df_consejosNegativos['texto'].apply(lambda x: preprocesa(x))
# Out:
# Everything on the menu is fabulous! Never had a bad meal. Try the chicken enchiladas or rotisserie chicken salad.
# Mock chicken in the bowls is bomb!
# Try the Jidori chicken breast.
# Mmm tequila lime chicken pasta
# inexpensive and tasty! get the  Three Flavor Grill Salmon, pineapple fried rice, and orange chicken
# 99 cent chicken tacos on Wednesdays. Limit 12 per person.
# Still a raving fan of fried chicken and waffles after all these brunches!
# Fried chicken wings or bust.
# I cannot believe this. Everytime I get the chicken pasta salad they DO NOT include the dressing. WHY.
# Halal certified and DOES still serve Halal chicken
# Gaeng Kua Gai (curry chicken!)
# Chicken pad thai was quite yummy. Hubby had bbq chicken. Very greasy, but also yummy.
# 20 piece chicken nuggets before work. Nom nom nom.
# Made it in time for the lunch menu! BBQ chicken, spareribs and garlic short ribs! YUM and it's 6.25 each! That's a deal!
# A variety of fish, chicken, wings, and shrimp
# Get the egg white scramble with chicken, green chili's and salsa if you want to eat healthier.
# For $1.99 you can double meat with chicken or beef baby.
# The lemongrass chicken is deeelish
# Try the rolled chicken tacos.
# Had the Thai basil sauté with chicken. Flavorful and cooked well!
# Kids menu has chicken strips
# Fried chicken thigh, man.
# Ordered the fried chicken and okra.
# Buttered noodles with grilled chicken breast
# Pasta Carbonara and chicken mushroom soup are always favs.
# I love the sesame chicken wrap! Way yummy!
# One chicken and one beef enchilada with their mole sauce!
# Roasted chicken was moist and delish!
# Buffalo chicken burger
# they have chicken n' waffles
# Try the chicken pakora and the fried noodles and beef w/ broccoli! You won't be disappointed!
# Garlic naan and chicken tikka masala is to die for
# Gotta get the chicken queso burrito!
# Basil chicken rice
# Mediterranean chicken pita + side of tzatziki and a few squirts of siracha sauce. Mmmmmmmm!
# The chicken chop salad serves their chicken cold and its really awful that. Order the chop without the chicken.
# Apparently half a chicken is only 3 pieces here...Where's my wing?
# Savoury waffles with chicken turkey or pork!
# This chicken is addicting, like crack?
# Only dark meat chicken. All drumsticks.
# No time for the salad bar? Try the chipotle chicken salad pre-made! 6.99!
# Get the Manchurian chicken and corn soup lunch combination. You won't regret it!
# Green chile chicken pizza!!
# $2.00 chicken or beef tacos
# Blue Ribbon fried chicken!!
# Ordered a chicken bowl, of course they forgot the rice .
# drunken mushroom chicken.
# Horrible customer service!!!!! I ordered singapore noodles and they basically used the lo mein noodles with the dish. Then i ordered orange chicken and didnt even get it. When i called the place this woman argued me down that i didnt even order orange chicken. Then upon delivery the guy didnt even have change and offered to take my money and return with my change later. I must have stupid on my face. I will never order from this place again and please take this as a warning.
# Grilled chicken & carmelized onions, YUM!!
# Man vs food chicken and waffle.
# Buffalo "chicken" dip, tofu tacos, and the taco salad!
# I Like the retro decorations. The chicken sandwich is tasty and filling.
# Service and out of crispy chicken at 6:00pm and grease
# fried chicken and jalapeño corn waffles with maple syrup was out of this world.  this is a #yolo combination.  yup I just made that up.  so go get your #yolo on
# Try the off-menu chicken tenders.
# Chicken pasta salad was okay... Missed my woodfire chicken :( chicken was bomb and full of flavor but pasta was a lil bit overcooked and bland but extra dressing helped not too bad i guess
# I was served green chicken... Enough said
# Horrendous. The sauce was watery, chicken was cold, management was ornery.
# 99 cent chicken tacos on Wednesdays! Open 24 hours!
# All chicken bowls/plates except salads come with dark meat. You can sub white meat for a small charge. I like that you can also sub veggies on the plates if you don't want the kale or the orange slice.
# My cold chicken spinach salad rocks
# Tuesday specials ** 99cents for 2 pc chicken!!
# Taco Tuesday's! 99¢ chicken or beef tacos
# Smothered chicken is my go to....love the yams too!
# Taco Tuesdays and taco Thursdays. Go for the 2 for $3 chicken street tacos and 3 chicken soft tacos for $2.09!
# Went to this del taco and got the 3 chicken tacos for 2.09$ and this is what I got
# Winner winner chicken dinner.
# Try the lemon chicken!
# Prices for bbq chicken up $1 to $7.97
# Try chicken lettuce wraps.
# Kids menu has chicken strips
# Late night craving ordered the chicken wing salad
# Spicy BBQ chicken and fish Jun!
# Recommend: popcorn chicken & watermelon juice
# I'm allowed I went for a jog. Big line for the fried chicken.
# Went on a Friday night at 7:30 and they were all out of chicken except for the wings
# No more crispy chicken
# El pollo loco type of grill chicken for only $9.95 for a whole chicken.
# Don't order the chicken
# Best dishes I've had:
# Orange chicken
# Garlic chicken
# Orange beef
#
# Worst dishes:
# Crispy duck
# General Taos chicken
# Chicken tortilla soup and chicken burro enchilada style!  Delish!  Salsa is also full of flavor!
# the chicken and beef bacon are halal
# Southwest chicken flat bread rocks!
# Get the VIP card. You get half chicken when you buy the card too!
# Skip the chicken breast dish. Order the short ribs and Brussel sprouts.
# Don't buy the raw Springer Farms chicken. It already smells bad before you purchase.
# The fried chicken ramen was a fried drumstick and what tasted like canned chicken noodle soup
# Bbq chicken pizza and garlic fries are
# Must haves
# Lemon chicken
# Get the grilled chicken salad yum
# It takes at least 15 minutes to get your fried chicken, so be patient! And the cornbread pancakes are complimentary and unlimited!
# 2 words.. Garlic chicken
# Orange beef and Orange chicken with noodles instead of rice is the way to go!
# Jade red chicken!!
# the chicken burger doe
# Their Katsu chicken Burger ($10.50) was absolutely disgusting. Part of it was over cooked while the other part looked undercooked. I think I want to throw up. :( I wish I had ordered a hamburger instead.
# Skip the pomegranate chicken salad.  The chicken was bland and  overcooked...
# Walts champagne chicken salad is where its at!
# Call ahead if you want chicken noodle soup. They run out often.
# Love the buffalo chicken and chicken ranchero pizzas here.
# No more chicken fried chicken. Argh!
# Red bridge on deck!  GF avoid the chicken tortilla soup it has flour!
# Crunchy chicken tacos yum
# Tuesday is taco night! But they also have chicken paprika as a dinner tonight.
# Stick with their chicken!!
# Pretzels seared ahi tuna fried chicken
# Tried buffalo chicken span pizza!!
# Mac and cheese with fried chicken thigh. You won't regret it.
# The Stupid Fries are outrageous! Seasoned fries, white chicken meat, gravy, onions, bell peppers - all covered in cheese. Order this one only if you have several hungry people and you are not worried about your health!
# I had the Widow Maker burger, the wife had Roticery chicken. Both were yummy!
# Coupon $6.99 5 pc chicken bone in or tenders 2 sides and biscuits.  Just go to their website and click link to Henderson location.
# Trying the trax fried rice. Grilled shrimp & chicken.
# Do not order the Thai curry chicken . You will be disappointed
# Hawaiian chicken salad (sans bacon) with citrus vinegarette is yummy... And so is the Coconut Creme pie!
# Caterpillar roll, unagi, chicken teriyaki bento, Sapporo.
# The chicken biryani is a plus.
# Service, ambience and cleanliness is a minus.
# Carry out is recommended.
# If I can eat here everyday I would. I just tried their chicken fried rice and I was blown away. Add an egg and its total heaven on your taste buds!!!
# Dude! Chipotle chicken pita, try it!
# They advise that if you get chicken salad to go it lasts for 7 days after being made! Yum!
# Second chance lunch mmmm chicken bowl!
# Double chicken enchiladas were gross. Stick with the regular grilled chicken and sides.
# Get the butter chicken
# Get the chili mint chicken or basil beef/chicken.
# Never would have thought cheddar with waffles & syrup would mix so well...add the chicken with the Mac n cheese and you're set.
# The chicken and broccoli is served with dark meat (but you can substitute white at no charge).
# Try the Baja chicken burro.  Yum!!!!
# drunken chicken tenders!
# Every taco I had (chicken, beef cheek, and pork belly) had quite a bit of heat. Not sure if there was an option to lessen the intensity but the plus side is I drank a tall bottle of water.
# Applewood smoked ribs and chicken, enough said.
# Come here immediately. Eat Hawaiian chicken wrap!!!
# This chicken burger was so thin it was anger provoking !
# Thai stick add peanut butter, my friends. Thai chicken salad with peanut sauce
# Time for chicken and waffles!
# Love the grilled chicken salad!!
# Tuscan chicken sandwich and the chocolate chip cherry walnut cookie are a must
# I find the regular chicken spicier than the spicy chicken.
# Got the shredded chicken burro, chimi style. Yummy!
# Cashew chicken and chicken with mushrooms. Yummm!
# Wah! They don't have the jerk chicken burger on the menu anymore :-(
# chicken. crack. must stop eating chicken in car b4 I can get it home to family.
# Try the chicken wings!
# Local Plate Time: beef teriyaki, chicken teriyaki, 2 SPAM Musubi, rice and Macaroni Salad! $7.95 Cash Only Bruddah!!! Aloha!
# Arizona chicken rollllllls!
# Smoky chicken.... What not to like?
# Longest wait ever. I could have caught and cooked my chicken by now.  Note to self, call in your order for pick up.
# Black cod, cured bacon, french toast, beet salad, chicken sausage, salted peanut gelato!
# Try the small chicken and rice bowl  $6.
# If you're a chicken salad lover, put this stop on your list. Plenty of TVs for watching games too.
# Spinach chicken enchiladas and TX margarita! Will be back!
# Lunch time again 1/2 egg salad sandwich on rye and bowl of chicken noodle soup. Mmmmmmmm
# 8  pcs of chicken for $8.49 today! 40th anniversary deal.
# Spicy chicken Bokkeumtang!!!! Save room for crispy fried rice after.
# Too tired to cook... saved by the roasted rotisserie chicken!
# Pad Thai and chicken pineapple curry
# Grrrr. There is no dressing to pair with the Chinese chicken salad
# Spicy chicken is the bomb.
# They have a bar and dining room. I really really liked the chicken curry!!!
# Try the chicken curry sandwich!
# BBQ bacon cheddar chicken sandwich.
# No flavors in the grilled chicken.. The boyfriend said it tasted like Denny's chicken. FAKE! Thumbs down
# Ordered beef basil, yellow chicken curry, and pad Thai. Can't wait to try it!
# Hula pack w/BBQ chicken
# 10 piece chicken wings for $4!
# Skip today - that is unless you like a lot of burnt chicken and crunchy rice
# Get the chicken shwarma at the deli grill in back of store and babaganoush. It's delish!
# Out of clam chowder, chicken paprikash and bread at 4 pm on a Saturday!?!?!?
# Tried to go for dinner tonite...place is officially closed :( .got bought over by yummy chicken. .they renovating and opening soon...
# The chicken enchilada omelette is my new obsession.
# Avocado chicken salad feeds two!
# Grilled chicken on a bun combo with a small gravy on the side for the fries
# Well it's Tuesday all you can eat day!! Not sure about the change yet. I miss chicken bonz!
# I always get my chicken and waffles fix here, when I'm in town!!
# Six Dollar chicken fried rice make you holla!
# Chop green salad with grilled chicken,  vinaigrette  dressing on the side.
# Its new! Lets taste the chicken.
# Curry chicken- love the curry, hate the chicken! Gnarliest "white" meat I've had anywhere, every piece has fat and gristle, and rubbery
# Chili fried chicken is gooooooood!
# Two words. Fried chicken.
#
# Enough said.
# Back to my usual chicken katsu.
# Try the smoked chicken pizza with a side of the chipotle dressing.
# I recommend the garlic chicken and Ono chicken!
# New menu item
# Tonkatsu bento $8.99
# Udon $5.99
# With tuna roll $8.99
# Kara age chicken bento $6.99
# Katsu curry w rice and salad $8.99
# Winner winner chicken dinner!
# Came here twice , ordered ginseng chicken, both times there was NO STICKY RICE. So check the chicken for STICKY RICE , they will give you a side rice if the sticky rice isn't there.
# Fried chicken is so juicy!!! Worth it.
# taking a chance here.  Fried chicken.
# Pricing has already gone up after only a month. Surf & turf and chicken fried steak permanently 86 from menu
# 3 soft chicken tacos. Nuff said.
# My family ordered boneless wings. They came out as a set of perfect spheres in the wing sauce. How could it be?   Chicken formulated together like chicken nuggets. Shocked.
# You've been warned.
# Honey drizzles fried chicken FTW!
# Herb chicken
# Get the fried chicken, mac & cheese and greens.
# Crab cakes and chicken crepe
# Onion rings, hush puppies, chicken n fish all deep fried. Wtf? Heart attack on a plate. Not to mention tartar sauce!!
# Mmmmm Orange peel chicken
# Beef bowl, yellowtail tartar, agedashi tofu, shrimp fried rice, chicken skewers! All bomb!
# Hummus and teriyaki chicken!
# If you're thinking fried chicken, think Floyd's!
# All entrees come with pita bread, Armenian salad and your choice of rice or steak fries at no charge...I ordered a beef and chicken kabob plate and asked to substitute lamb in place of  chicken and our waiter honored it, no problem, no charge!
# Jade chicken and emerald chicken!
# Like: Goat cheese pizza. Thai chicken salad
#
# Don't like:  Chateau Ste. Michelle Riesling. Change the brand already!
# Spicy chicken bowl
# bbq chicken, rice, ox tail sauce, fried plantains and coleslaw on the side with a sip of pineapple and ginger juice !!!
# Sad. Terrible salsa w/chips. Lame mole. Boring grilled chicken burrito. Try something else?  Or NOT.
# Wow... a little heavy on the onions in the chicken pot pie!  #olfactoryassault
# The chicken Marsala is heaven on a plate!!
# Jamaican jerk chicken pizza and tomato basil spaghettini!
# Jade red chicken, huzzah!
# 99 cents chicken tacos on Wednesdays
# chicken parm sandwich  - dee-lish-us!
# Meeting a friend for some primo Portuguese BBQ chicken in mere minutes..... Drool
# Stuffed Avocado with pulled chicken.
# Try the draft beers along with some chicken wings.
# Get the Thai basil chicken and Tom yum soup!
# Got the chicken biryani, worst one I've had to date. I asked owner for refund; this restaurant said no refunds
# Came to have some rolls, but couldn't pass on lunch specials. $2.99 chicken bowl & $5.95 nigiri/ca roll plate! Different daily specials..
# Avoid the boneless wings. Too much breading and if you get it to-go, the sauce is on the side.  What you get is expensive chicken nuggets.
# Soy garlic sauce for the chicken and bulgogi fries are they way to go!
# Tender, juicy, marinated chicken...
# Gettin my Korean fried chicken feast on!
# The Italian sausage is always on point as well as the chicken. Venture out and try other things though, as I've never had a disappointing combination.
# Andys sage chicken benedict!!!!
# Try the chicken and waffles.  So yummy!
# coconut chicken soup
# Haven't been to Wendy's in months because my spicy chicken sandwich was hard and rubbery (uncooked I guess?).  Finally decided to go back today and it happened again . Not sure what's going on.
# Trying spam masubi and spicy Korean chicken bowl. Nom Nom Nom
# Pool, drink, chicken wings
# EaterAZ event - Matt Carter is cookin' up chicken tacos!
# Buy one chili chicken get the second order for $5
# You gotta try the chicken wings and jalapeno poppers
# Fried chicken!
# This place has only chicken fingers. Nom nom nom!
# Mechanically separated chicken.
# Curry chicken sandwich!
# I came today and found that it is their reopening.  I came for chicken and waffles which I saw in the picture.  Not available under new ownership.  Decided to stay and  give breakfast a shot even though they didn't have what I came for...review to follow post breakfast.
# The poutine gravy is made with chicken stock
# Came for lunch during the weekend. Pricey for the portion sizes you get. For example, the butter chicken came in a very tiny bowl for $15.99. Tandoori chicken was also dry. Would probably not return as nothing really stood out for me.
# The new buffalo chicken sub is nasty.  Avoid it.
# Winner winner chicken dinner!!! But this case dessert ;D
# Kung Pao chicken that actually has some kick to it.
# Catsu chicken heaven!!
# Garlic parm chicken fingers are delish
# Kung po chicken with no carrots or nuts on brown rice. Yummm
# Must try the grilled chicken panini
# IEA - red velvet pancake, fried chicken Benedict
# The chicken avocado wrap with the salad allows me to rationalize having two beers.
# Just get the chicken!
# Jalapeño chicken is a must
# The sushi has not been too bad, but the combination boxes have been disappointing lately. Chewy chicken, soggy tempura. I'd go somewhere else until they get their act together. Right now, Sushi on Rainbow is still go to for lunch/combo/bento boxes.
# Yummy chicken Shawarma. Small size $7.50 lots chicken
# Don't not eat here they forgot my chicken nuggets
# Half brisket sandwich on home rye and chicken noodle soup of course.
# Yes I knew organic does not mean its non GMO. but darn it I wanted non GMO organic chicken feed.  I may have Organic can I have small bags of non GMO.
# Love this place nothing negative to say ! Chicken nachos and fried chicken strips with mac and cheese  .  Can't wait to go back
# Gardein chicken rice bowl...trust me, try it!
# The chicken suiza enchiladas are delish. The green sauce is tasty, so ask for extra!
# Chicken friend chicken and hash brown casserole. Gonna go straight to my ass.
# Don't miss out on the semi-hidden back room. It has sushi, sticky rice, egg rolls, and chicken feet. BTW, bring your patience, there is no sense to the foot traffic patterns here.
# Must try the chicken cutlet with black pepper sauce!
# Ordered a spicy chicken bowl.  Got regular chicken teriyaki bowl.  Oh, and a strand of hair mixed in with my veggies.  Barf.
# On your chicken joys you can ask for both thighs or legs
# $7.20 now for steak, $6.50 for chicken. Prices getting up there! Ekk
# pecan chicken.
# Soy & garlic chicken with grape soju
# 2 for 1 chicken tacos on Thursdays.
# #1 chicken balls and weekends are busy
# Com ga ngu vi huong.  Five flavor chicken!
# 3 finger chicken combo with 2 sauces and a drink for $7
# For a restaurant named Satay, the chicken satay is extremely DISAPPOINTING as the chicken was DRY and BURNT. The cucumbers looked like they have been pickled too long and turned color. When I mentioned that chicken satay was dry, waitress says it's because they use white meat. I've had white meat chicken before, and it's definitely not dry if you know how to cook it.
# Summer specials start today!  They added a wood-grilled tri tip salad, a southwest BBQ chicken salad and a thai BBQ salmon salad.  And save room for strawberry shortcake!!! They only have it during the summer!
# Chili chicken and chili fish dry.!!!!!!!
# try the chicken
# chicken bryan
# This place never has chicken or you have to normally wait for 30 minutes. Wtf??
# 11 am! Time for lunch! 1 mcdouble and 4 pc chicken nuggets pls!!!
# Mmm chicken teriyaki plate with salad
# Teriyaki chicken bowl you can't go wrong !
# Check your receipts before you leave. They over charged me and were very rude when I called them out on it. Meal receipt and credit card receipt different by 40%!!!
#
# Terribly rude employees serving cold chicken and over charging.
# Juiciest rotisserie chicken I've ever had ! Beer n wine included in buffet!
# 3 chicken soft tacos for $2.09 on Thursdays!
# Try the chicken or beef tikka!
# Omg jade red chicken quesadilla!
# Yummy biscuits & gravy and chicken and waffles! Oh my!
# Rockin the spinach and shredded chicken for $7.49
# Got me some chicken and Tony Packo's pickles
# I ordered the chicken pesto. Next time I will ask for it to be warmed.
# baby garlic bok choy and mango chicken. #114 and #96!
# Brown stew chicken dinner!
# fried chicken wings with fries!
# Went here for the first time today and got the Mongolian chicken. Very disappointed.
# They do not sell chicken wings. The description is wrong.
# Won't eat at the Wynn again. Hair in my chicken and waffles! Super nasty.  Ruined my apatite for 4 days! They didn't offer to comp my meal! Acted like it was no big deal! While I paid 500$ a night to stay at their hotel! Barf! Plus the birds are out if control!
# Add everything to your #1 (egg, chicken broth, and Chinese sausage) .. I completely forgot the chicken skin too. Grr!
# Terrible service and their chicken salad is just dark meat and mayo. Yuck! Phx location pales in comparison to the ones in Vegas. I won't be back.
# Get the chicken pesto pizza!
# Chicken fried chicken.
# They don't have any chicken caesar wraps until after 9:30 am :(
# Lollipop chicken bites are tasty!
# Fresh guacamole, bean dip, salsa & grilled chicken salad, chicken enchilada+shredded beef taco combo plate MMmMmm
# Lemon grass curry chicken
# Food is declious!! I ordered the chicken enchiladas!! My boyfriend ordered the chimichangas!
# Get the deep fried chicken cartilage!
# I don't recommend getting the Thai chicken curry. The chicken was firm and didn't seem like it was chicken. It wasn't flavourful. =(
# Grilled chicken salad...Yum!
# Have to have the fish sauce fried chicken
# 20 pieces of chicken nuggets for $5, but not a contender to McDonald's in terms of taste and value.
# Water boiled chicken, sooo yummy!
# I think I might turn into a fried chicken taco.
# During brunch you can't choose anything from the entree menu, even though it is included in the menu they give you. You cannot even do any add-ons to the side salads (steak, chicken, etc).
# .99 chicken tacos on Wednesday.  Also in a plaza next to other food options to satisfy all members of the family (Starbucks, port of subs, pizza, uswirl, wings).
# The 'Mashup' is where its at! Mayo-free organic chicken salad on organic panino.
# Panang curry double chicken w/ brown rice level 8 is BOMB.COM
# Get the Bonafide $5 big box while it lasts! Comes with two pieces of chicken or 3 chicken tenders plus two sides of your choice. You can also add in a drink for a dollar!
# Holy rebrand. Fact: for 99 cents you can add lemon slush to your beer or get a chicken wing on your Bloody Caesar.
# 1/4 chicken with no skin is 200 calories, I call it cheating on a meal.
# Bulgarian Benedict so delish!!! With a side if fried chicken.
# Out of chicken for twenty minutes due to a big order. I'm stuck in drive-thru and no way to exit.
# Fried chicken!
# Normally I get the honey balsamic salad with chicken, but I wasn't super hungry tonight.  Instead I ordered the grilled chicken sandwich with no bun and a side salad with balsamic vinaigrette dressing.  Viola a smaller version of a salad with grilled chicken.
# Try the chicken fingers!!
# Getting my chicken on after a tough morning ;)
# Try the chicken finger sub!
# Mmm butter chicken!!!!
# Fresh chicken strips! And they check id for credit card charges
# Beer, burgers, buffalo chicken quesadillas.
# You can't go wrong with the steak or chicken breast
# Having a glass of Chardonnay and eating the BBQ chicken salad... Soooo yummy
# I can't recommend. The chilaquiles is with ground beef or chicken.  They countered with beef tips.
# Reagan highly suggests the hand fed chicken.
# Buffalo chicken biscuit!
# They now have cooked spicy chicken feet.
# Do not get the chicken fingers. I should've taken a picture, but my kids were hungry.
# Gotta have my CBP! Even if it's to go!! Greek pizza with spicy sauce and chicken sausage ! Lots of garlic. Yum!
# Wasted $11 here today, their chicken biryani was terrible spice flavor. I didn't eat the food. Mash up of random stuff. Go down the street to pasteries and chaat or somewhere else!
# Fried chicken an meatloaf!
# Jerk chicken
# That garlic chicken is a kick ass dish.
# Pulled chicken, chipotle mayo, BBQ sauce, roasted eggplant, chili roasted onions, heaven!
# Be warned, the fried chicken takes 25 minutes...
# Watch out and chew your food carefully! The "boneless" chicken roti isn't always boneless
# Try the chicken kabobs!
# Be prepared to wait 40 minutes for an a la carte order (chicken katsu)
# Make reservations! And order the lemon chicken!
# Don't get the chicken sandwich. I guess that's why they call it whopper bar
# Yummy lemon grass chicken!
# If you like slaw the ahi tuna has a lot! I'm not a huge fan of Cole slaw in general or the salad. I prefer the any of the burgers or chicken sandwich!
# Who can miss the gigantic chicken in front of the restaurant?!
# Always order hummus! Don't sleep on the lemon chicken soup.
# Saimin with chicken Is so ono!
# Had the carne asada and chicken tacos and they were YUMMY!! Not going anywhere else for tacos. They are twice the size of street tacos.
# Hunan chicken!
# Got the SW chicken sandwich
# Nuoc mam chicken wings !!!!
# Try adding pineapple to the Donny Special (ranch dressing and BBQ sauce base, grilled chicken Moz cheese)...it is delish!
# Get the fried chicken or gyro!!
# Couscous chicken wrap like eAting styrofoam
# Order the chicken tenders and make little sandwiches with the salad chicken and French fries in the bun they give you! So yummy
#
# ... Sadly new ownership has taken over this place and I'm afraid it's not as good as it used to be :(
# Try the orange chicken
# the squash curry with chicken is the curry of my dreams
# Taco Tuesday: $2 for pork, $2.5 for chicken or steak, $3 for fish
# Honey sesame chicken!!! Mmmmm
# Maple bbq chicken
# I've been a big fan of gallo blanco. But now Otro is closer! Try the chicken soup! They provide the herbs and vegetables for you to add in at your liking.
# This place has a bomb chicken burrito.
# Don't order the bun.  Eeck!  Hard to find bad Vietnamese but we found it!  Dry awful chicken, poor noodles. Terrible all the way around.
# Horrible food! I had the prime rib and it was overcooked and dry and I had the baked potato and it was hard! I could barely eat it. My wife had the country fried chicken which is a Vegas special and she said it was really chewy and gross. Never going there again. :(
# Thyme chicken every time
# Never too early for cajun chicken
# Wtf, no more chicken biscuits??
# I love the buffalo chicken sandwiche!!!
# Don't forget to call ahead for fried chicken!
# Try the chicken tikka masala, spring rolls, and garlic naan!
# The kick ass chicken sandwich and a cold beer will put a smile on your face!
# No flavor but the chicken is tender.
# Cheese ravioli yumminess & chicken parm...
# Mmm... chicken and walnut sandwich...
# buy one chili chicken get the second for $5
# Hummus, falafel, oysters, chicken kebab are a must have.
# Chicken is fantastic，so crispy，much spice inside. No blood left in the chicken like KFC and popeyes.
# Killer chicken, potatoes, salad, staff. Legit
# Lamb korma, chicken tiki masala, garlic naan, okra, and plain yogurt!!!
# The chicken fried steak is da bomb!!!!
# You can mix and match your stuffed chicken fingers!
# Mmmmmm chicken wings
# They no longer serve HK Egg Waffles with the chicken. Just a Belgian waffle
# To my fellow T-Rexes:  the steak is chunky, fibrous and ICE COLD (avoid!) and the so-called grilled chicken is surprisingly tasteless.  Bacon and hard-boiled eggs are part of the main salad fixins, so load up on that, I say.
# Bomb mango chicken!!!!
# Love the grilled chicken tips!!
# Anything with smoked chicken= beyond delish!
# Deep fried Cali roll for me & chicken teriyaki for Richard.
# Order the BBQ chicken salad and ask for a scoop of ranch and the chipotle dressing. Take home & add chipotle Tabasco on to your liking. OMG!
# Buffalo chicken pie on my mind
# Crispy honey chicken today!
# All you can eat brunch!!! Chicken fried chicken!!
# The HALAL chicken burger has the Lahori Salt n Pepper taste!!! Will drive all the way from Anthem anytime!
# Beyond starving today. Should get a salad with chicken, but I'm jonesing for a chicken club. Decisions.... Decisions...
# $1 fresh oysters on Thursdays and $17.99 half pound chicken with a blue ribbon pint on Tuesdays. How can you ever go wrong with oysters and fried chicken? You can't.
# chicken & waffles, BRO.
# They have Taco Tuesdays.  Tacos are $1.00. Choice of chicken, marinated chicken, pork, marinated pork.
# Please try their fried chicken - it'll bring a tear to your eye
# 4 chicken nuggets for .99 cents after 8 pm at McDs in walmart
# Grilled chicken and rice
# For a restaurant named Satay, the chicken satay is especially DISAPPOINTING as the chicken was DRY and BURNT. The cucumbers looked like they have been pickled too long and turned color.
# protein smoothie and chicken sandwich
# Nevada Chicken Cafe will take over this location. Expected opening date is October. Here is the link:  https://vegas.eater.com/2017/6/20/15835368/nevada-chicken-cafe-replaces-smashburger-spring-valley-restaurant
# chipotle chicken with avocado perf
# Omg! Never again! Salty chicken ..bad service.. Took over an hour .. The workers were so lit..    Wow...  This place is a 911 joke!
# Gross x 1000. Heirloom tomato salad sported one over ripe Safeway cherry tomato. Organic chicken entree was anemic and unedible and included no rice or sides...just chicken with a few planters peanuts thrown on top. Seriously. Had a Cliff bar for dessert...
# Chipotle chicken avocado. Small portions, one sandwich never fills me up. Do NOT come during the middle of the night. Their portions become even smaller.
# New menu. Try the friend chicken. It WILL change your life
# Orange chicken and string bean chicken are my favorites.
# Curry chicken pastries are gone and no sticky rice and mango this time...:(
# I recommend the tandoori chicken kebab dinner
# Grilled chicken ALWAYS tastes burnt. Worst service ever. Diner beware?
# I always enjoy having the Thai chicken pizza or the original BBQ chicken pizza on the honey welheat dough they make.
# Also the BBQ chicken salad with avacado is yummy.
# Try it with chicken!
# The Drunken Mongolian w/ brown rice and mock chicken.  YUM!
# Appetizers: samosas, malai boti, seekh kebabs. Entrees: fried fish, chicken karahi, daal, lamb chops. Dessert: gajar halwa, kulfi, kheer, gulab jamun. Masha'Allah - There goes my diet before Pakistan's trip!
# You can get the beef on the side by putting TR with your selection and get chicken soup instead of beef soup
# Adobo chicken
# Try their shrimp tacos with bacon and their chicken tortilla soup.
# Pork belly steamed buns, grilled chicken satay skewers and Laksa Lemak are must tastes!
# beware the chicken parm.. ur unwrapping a hot cheesy mess... but they offer unlv discount wooo!! yummy subs overall
# May 21, 2017: no waffles today! But if you want chicken & waffles, they make it as chicken and French toast!
# Low carb option: greek salad with chicken skewer. Mmmm!
# I always order the lamb and beef tendon skewers + spicy chicken knuckles. Warning! It's spicy
# Be careful! Another person in my party bit down on a huge chicken bone in the chicken sandwich.
# get the mango lassi and chicken tikka masala!
# They said the SHAWARMA chicken here is HALAL
# Greek salad and sub grilled chicken with chicken salad!
# No political statement, just need me some tasty chicken sammiches...
# Fries are yummy, chicken breast is moist and flavorful.
# Tamales!! Try the chicken and green chili
# I ordered a chicken salad sandwich at 7 pm. Unfortunately the bread was stale and I think that the chicken salad upset my stomach. I've never eaten at the Mall location before. I like Paradise Bakery but not impressed with this location.
# chicken Caesar pizza.
# Lunch soup: chicken enchilada !
# Delivery spinach & chicken pizza
# Thai chicken salad (add cucumbers) and Christmas ale.
# Love getting the chicken dinner deal at the deli when I don't have time to cook. Gives you 8 pieces of fried chicken and 2 sides.
# Bbq chicken is the way to go... Trust!
# To go chicken wannnngs! FYI its now .50 cents on Tuesdays!
# Give the chicken sand which a try and definitely order a large drink per the size of there small. Don't let the negative reviews steer you away!
# Try the new Georgia Gold chicken!
# Sample the meats they have to offer, they differ in types (beef, pork, chicken) and spiciness!
# Try the beef shawarma over the chicken!
# If you're not crazy about tons of parsley in your Mediterranean chicken salad, ask for the taboule on the side!
# Had the chicken and garlic link sandwich with a side of jalapeño corn bread, YUM!!
# They got rid of the green chicken chile soup
# Wow!  BBQ chicken ranch wrap out of this world.
# Yummy chicken soup
# If I don't wake up tomorrow talk to the colonel. This chicken was terrible.
# Beef pad see-eu and chicken larb salad!
# To cut down on time, I always call ahead so that I can pick up the food and bounce if its takeout! It can get busy in there. Small jerk chicken lunch is plenty for me. Pineapple soda goes well with the meal!
# Large portions. Ordered the teriyaki chicken and it was so gooood!
# Curry chicken is the bomb!
# A lot of choices for bibimbap & ginseng chicken soup
# I kinda like everything here... Breakfast, salads, or chicken sandwiches!
# Thai chopped chicken salad is nom!
# Can't get chicken here, it's crossed off the menu ..hopefully it's temporary, even though I rather get ribs and brisket at a BBQ place
# Don't order chicken Marsala
# Buffalo wings and chicken burger....
# French bread pizza and fried chicken yes sir!
# Shredded chicken on spinach for 7.49.
# Tiramisu was tiny. Bronx Bomber was salty. I'd stick with one of the chicken based pizzas.
# Just tried chicken feet. Im digging it!
# Smoke chicken legs. I cannot eat here without having those.
# Check your order. Included in photos my small piece included with order of whole chicken. 1 of 8 pieces.
# Try the gardien boneless chicken strips....chicken substitute
# Yummy chicken time!!
# The worst food and service!
# Ran out of mahi mahi, and French fries!
# They prefer you pay cash!
# The cashier is clueless!
# When they give you your change they mention their tip cup! (Guess that's why they want you to pay cash)
# First and last time coming!
# The picture is of my chicken katsu $8.59
# Not sure why their chicken is orange. I've never seen that before.
# Mmmm...Wednesday is chicken taco day. Only 99 cents!!
# Get chicken shawarma laffa, ask them to cut it in half.
# Worst restaurant in the history of mankind. This place is not for Lahori food lover (whatta shame their name is Lahore Tikka) . They are only famous for butter chicken which shouldn't be the caliber to rank ANY restaurant sooo high. BTW butter chicken is not authentic Pakistani food any ways.   Overhyped and over-rated by non-desi ppl. PERIOD.
# signature large fried chicken is not boneless. :(
# Barbecue chicken flatbread
# My go-to: Broken rice with shrimp tofu curds and pork chop. Comes with slices of cucumber, tomatoes, pickled vegetables and a small side of chicken (?) broth
# Try the chicken chili
# Halal fried chicken!
# Post workout chicken teriyaki sub!
# Tequila lime chicken sausage, grilled!
# If you order Medium Garlic Grilled Wings you will never look at another chicken wing the same. Mouthgasm
# The Honey Garlic chicken saved my life. Seriously.
# Awful - dried out chicken, gummy rice and "thai" curry that tastes only of salt and blandness (even after I loaded it up with sriacha)
# The last 3 times I've stopped in after work to grab a BBQ chicken, this store had an empty deli case.  6:00-6:30.  Superstore from now on.
# Oh no. The menu has changed. No more Baby Back Ribs on menu! So sad. Just brisket, pulled pork and smoked chicken. No ribs!
# $1 chicken and beef tacos on tuesdays!
# chicken tortilla soup (replacement for the beer when your sick) & chicago bears game although Im torn here they're playing my NY Jets!
# I found a worn in my shiitake kale chicken! Never again...
# Get chicken souvlaki for take out! Dine in has shitty service....ew
# I wanted some eel, but I also wanted some chicken Katsu!
# You have a choice of Beef, chicken or beans with the Mexican Pizza, the chicken or beef with no beans are my favorites!
# Tandoori chicken tikka. TO DIE FOR
# Taco Tuesday tacos are now $1.25 each. Choose from shredded chicken, grilled chicken, ground beef, carnitas, steak, chorizo, al Pastor, shrimp, or tilapia with a soft or hard shell. (Seafood tacos are $1.99) Previously $.99 at the old location, but there's now a taco toppings bar that includes Pico de gallo, assorted salsas, tomatoes, lettuce, cilantro, and sour cream.
# Try the chicken. It's to die for!!!!!!
# $5 off $25 with Yelp check-in. Get the SoCal chicken club!
# Tarragon chicken sandwich is hella expensive for a sandwich
# This restaurant didn't participate in chicken wing day that was listed on their website. The day was also created by Hooters!
# Add the bacon to the chicken cheddar sandwich. You won't be sorry!
# When I asked for veggies to be added to lettuce wraps instead of meat/chicken, server simply answered "No." So I had lettuce wraps & mushrooms. :(
# No more chicken fried steak?
# Fixed the chicken tenders.
# Paht Kee Mao noodles with chicken and mango with sticky rice are a couple favorites.
# Fried chicken, darts and World Cup
# Spicy jack chicken sandwich with cheddar
# Trying this chicken avocado club
# Can't go wrong with a 2pc chicken (leg and a thigh)and a biscuit for $2.00 on Tuesdays.
# Get the half chicken meal 7.99 yum
# Try the fried chicken!
# Grilled chicken fajita salad bowl. Si señor!
# Order the cashew chicken !
# Yummy enchilada rancheros and chicken taco. My margarita is especialle.
# furikake chicken!!! enough said!
# Shrimp fried rice and orange chicken
# They have chicken chorizo here!!
# Drip the Pad Thai with soy chicken it the Buddha delight.
# Get the fried chicken, dark meat. Protein and 2 sides for $8 cash
# Huli Huli chicken is da bomb!
# The chicken class isn't actually a cooking class. Instead they teach you how to part a chicken and debone it.
# I definitely recommend the chicken fingers with BBQ sauce!
# Out of almost everything I wanted. Steak, grilled vegis, chicken.
# Go for lunch on weekdays. The portions are big and for $10 you get the lamb or chicken, rice or fries, salad and drink. Cannot be beat.
# Yes, I can actually say that I care a lot for the chicken.
# Smoked chicken has been added as well as carne asada.
# Pineapple chicken, give it a shot
# Got the food and man took forever. Even getting water and pita. Plus the chicken was undercooked. So she gave us 10% off. Rather than wait.
# Fried zucchini with ranch...you can't beat this as a side, no matter what you pair it with...turkey, chicken, fish, or burger.
# California burrito...you can't go wrong with this choice. Also every Wednesday is 99 cent chicken taco day.
# Do wait until they get the canvas for their enclosed patio before visiting as you will be cramped in a tight space or cold outside. Don't leave without trying the chicken parmeasean sandwich.
# Fried chicken and waffles are da bomb whoed dunk! Stay hood homie!
# Tomato & mozzarella panini with chicken and wild rice soup. Mmmm
# Post #TechPHX noms. Emerald chicken FTW!
# I love their breakfast chicken biscuits with cheese! My all time fave!
# Jade red chicken and the black bean paste is yummy
# The worst drive-thru EVERRRR! 25 minutes for a chicken nugget and lemonade order...
# Just ordered some chicken chow mein!
# Greek salad with chicken breast. Awwwwwwwwwwwww ya.
# Try the chicken sharmola sub!
# the butter chicken wrap is my favourite
# Try the chicken and waffles
# Fried chicken doesn't start until 10:30 :(
# Sammy hagar's band chicken foot
# Yay! They're finally open! Now I don't have to go all the way to Charleston and Decatur for chicken fingers.
# Try the buffalo chicken wrap
# Try the fiesta chopped chicken salad
# When your in the mood for some chicken fingers and burgers this is the spot!
# Stay away from the chicken bites, they're half fat and gristle.
# Stuffed chicken wings and egg rolls!!
# Must order the roti canai... avoid the chili chicken.
# Yummy grilled chicken salad
# Spicy chicken bowl. Veggies only!
# Thai chicken pita is the MFing truth!
# chicken nachos... were horrible....can i get some chicken with these chicken nachos!?
# Butter chicken with garlic naan
# Fried chicken Benedict
# Hate, hate, HATE the cashew chicken - not like anywhere else! Has no sauce. Chicken is crispy. Hardly any cashews. Blech.
# KFC again? Grilled baby!! Tastes like Huli-huli chicken
# No more BURRITOS or 3kinds fries! Tacos-beef,chicken,pork, tofu&egg, jumbo "nate" dog, (not so)fries-flavored/seasoned, crazy dough.
# The chicken sandwiches are big enough for two. Seriously.
# They have chicken and waffles now ???
# Cheapest eats in Tower City! $4.99 for chicken and two sides.
# Go for the grilled chicken!
# Try their combo spicy and crunchy fried chicken! Pre-made at the hot food section for $7.98
# Pork egg roll, stuffed chicken wings and Thai ice tea
# Unfortunately doesn't offer tandoori chicken as an appetizer- half or full chicken
# Curry chicken salad ftw!
# I could eat this chicken everyday.
# New shiitake kale chicken Nom!
# Soft chicken tacos are always a winner.
# Don't go after 11pm or get cold meat, cold food and horrible service.
#
# If you go before 7pm or when gordon himself visits, then everything expect the chicken burger is amazing!!!! If your craving a chicken burger, get the appetizer chicken burgers( 3 mini burgers) they are very good!
# They don't have the chicken salad sandwich anymore :(
# Don't order the Chinese chicken salad!  Soggy and nasty.  I sent it back and got the Cobb salad instead.  They still charged me for  the salad even though everyone else in my party was halfway done with their food when my salad came.  Not to mention it took 25 minutes for the food to come!
# Skip the curly fries and chicken tender, but if you do want to get fries, then opt for the smaller size since they don't fill up the fries like other locations. (So a medium is less than a small.)
# It is KFC over priced half decent chicken when it is fresh otherwise it is extremely over priced bad chicken
# $5-6 lunch specials until 3pm (Dishes like ma-po tofu, General Tsao chicken, corn/fish on rice)
# Get the smothered chicken!
# Love the chicken soup!!
# 99 cent chicken taco Wednesday's
# Can't go wrong with their chicken!
# Fried chicken and waffle sandwich & chilaquiles with the bored and the beautiful & hunting season bloody mary's
# Roasted chicken sandwich is where it's at!
# Chipotle chicken sandwich is bomb!
# If you are picking up takeout there is a door at the side of the building for the "General Store" so you don't have to walk thru the restaurant to the takeout counter at the back.  Get the Mac and cheese!  If you like a LOT of sage in your fried chicken this is your place - I don't.  ( Sad face)
# I would only recommend chicken fried rice and pork chop!!! Other than that, other food has not much flavor...
# $6.99 for 2 small chicken shawarmas OR 1 shawarma with fries and a drink.
# chicken supreme quisadilla!
# Need to try the chicken fried steak.
# We were told that all the soups are made from chicken stock so avoid if you're vegetarian.
# 10 chicken nuggets for $1.49
# Try the orange chicken!
# 99 cent Taco Thursdays!
# - Hard or soft shell with ground beef or shredded chicken, topped with cheese and lettuce.
# If you're getting the quarter chicken leg, might as well get the surprise box. It's cheaper and it's 99% of the time a leg.
# just picked up the earl's club, chicken chipotle and cheese &broccoli soup!
# Spicy chicken teriyaki... Lunch witt hubby!
# Beef tataki, garlic chicken gizzards, and honey toast FTW. :0)
# Sage fried chicken!
# Get the Mongolian chicken or beef.
# 16 dollars for a chicken wrap and some fruit juice? !
# Pizzas was Yummy today!  4 cheeses & chicken pizza
# Crispy asparagus okaki and chicken teba wing is a must!
# Beware of chicken with marbling
# They now serve chicken noodle soup
# Crispy basil chicken & duck curry!
# Yummy orange chicken and broccoli
# chicken ginger broccoli extra spicy = yum!!
# Chicken larb, Thai beef salad, chicken pad see ew, lucky buddha beer & 33 export beer~
# Spicy chicken bowl no rice!
# Brannon calls turkey bacon-- chicken steak.
# Get the chicken tempura!
# Trying the jerk chicken and steak
# Can't go wrong with the yellow chicken curry dish & Thai tea!
# Lunch combo $7.95 ( butter chicken, naan, mix veg, samosa, rice, pakora)
# People rave about this place. I found bad fries bad cole slaw and ok chicken.
# Hortobagyi palacsinta!!! In English chicken stew...Hungarian heaven
# chicken wings and rice
# Ask for Extra jerk sauce as the chicken itself has no heat it's all in the sauce
# The chicken skewers and pork skewers grilled outside were delish
# Trying their lemongrass burger with veggie chicken patty. No baked fries today?!?! Bummer :(
# Mmmmmm spicy chicken and criss cross fries..
# The chicken burger and chili cheese fries are bawm
# New Orleans chicken wings are flavourful and juicy! Skip the drinks and get this instead
# Try the chicken tacos with pico and lots of salsa! Heaven
# Santa Fe chicken wraps!
# Spicy chicken ramen and Tonkatsu Black ramen
# There is not a ton of variety, but the chicken noodle soup is to die for!
# Raw chicken! Showed staff, they did nothing about it. Look before you bite.
# KyoChon chicken esque ingredients for tonight's dinner
# Try the chicken donair pizza!
# Aww yeh..garlic chicken bento with kim chee fried rice...yeh!!
# Order the chicken sandwich... Then apply the spicy dipping sauce from the french fries to your sandwich.
# Awesomeness
# Fried chicken baby
# Try the pomegranate chicken entree.
# Trying the lemon chicken!
# Was sorta hard to find from the Venetian entrance.  By Barney's New York. Can sub beef burgers with chicken. Wasabi fries not during lunch.
# Fried chicken and chocolate cream pies!
# Order the honey chicken
# Try the buffalo chicken pizza!
# A Vegas brunch revelation = French toast and chicken w/ biscuits.
# Definitely try the rotisserie chicken!
# Get the spicy chicken pizza!!
# chicken fried steak and eggs!
# Jade red chicken and emerald chicken is my go to and the jerk fried rice!!!
# Lots of chicken and tofu in this pad thai
# Chicken Shack Wednesdays= a salad, fried chicken or catfish and 1 side for $22!
# Trying the flatbread grilled chicken.
# $1 extra if you request for chicken or duck thigh
# Try the fried chicken skins! So yummy!
# Seriously though! Have the crispy chicken honey sriracha sandwich! Life changing!
# Mangoberry salad with extra dressing and add chicken.
# 4.95 graveyard specials include shrimp cocktail, wings, chicken fingers, or a burger
# Try the Vietnamese chicken ravioli.
# Fried chicken FTW
# Tonight's sample: vegan mandarin chicken and dark French roast coffee. Yum!
# Got to sample their catering tonight. Yummy, especially the butter chicken and naan.
# The buffalo chicken grill wrap thing isn't too bad.
# My tip is DO NOT EAT HERE!  Undercooked soggy greasy chicken with stale bread yuck
# chicken shwarma
# Veggie cow mien & orange chicken
# Shrimp with chicken pan fried noodle is yummy
# Carne asada fries and chicken quesadilla were on point.
# The chicken is always the same,  but the service at this location is bad every time
# You don't want the honey bbq boneless chicken wings. You probably could skip the shrimp cocktail and chicken-fried steak as well.
# I've gone here twice now? Always end up with the fried chicken. I don't even like chicken that much... silly drunk me. Anyway it's expensive.  But from the food I eat the next day, it's top quality!
# Pulled chicken sandwich with a rib salad. Yummy.
# Red curry shrimp, Bangkok street style pad Thai, chicken satay w/peanut sauce
# I heart Chick-Fil-A. Yummy chicken strips.
# Go to a diff location. My lord. For a drinks and 3 pieces of chicken. 18 min. Workers were LOST. Review to come. Ugh. Never again.
# Try the buffalo chicken sandwich. Really different.
# Frozen lemonade and BBQ chicken flatbread!
# The menu for take out crepes is limited to ham, chicken or veggie. Not sure if the dine in menu is different, but found the choices really disappointing.
# They serve yummy chicken tikka masala.. but gotta order in advance as thats not one of the grab n go items!
# Went this evening inside to order a chicken strip basket and cheese bacon burger combo to go. Good thing I looked inside before leaving. The chicken basket had very little fries. The cheese bacon burger combo had no fries! The kids working today lack work ethics and how to communicate with people in a customer service oriented position!
# Get the buffalo chicken bites appetizer!
# Songyi and I are cooking chicken Madeira for dinner tonight~
# Fire chicken is back!  Guilty guilty guilty pleasure.....
# Get the grilled chicken!
# ...
# So close to eating the yummiest chicken wings ever!
# try the chicken wings!!! ughhh
# I order a black n chicken salad and it came with bugs in it. Gross
# Is one chicken wing 40 grams? R u f^kin kidding me? Anyway being the last time an
# General chicken rocks.
# The chicken is very under cooked an the waiting line is awful
# Mmmmm butter chicken!
# Junior chicken with extra lettuce mayo, tomato and sesame seed bread and you have yourself a McChicken for $1.39
# Jerk chicken dish with rice, salad and plantain.
# Terrible. The chicken looked like hot chips.
# The meat was so dry.
# Hmm sarap! Foods bomb, spicy chicken all the way!
# The fiesta chicken nachos are everything!!!!!
# Food was cold,chicken was cold ,food is horrible! I never come back!
# So disappointed at this place, read all the reviews online and decided to give this place a try, but ended up finding a piece of steel ( maybe partial of the cleaning tool, 鋼絲） in the chicken feet , almost swallowed it!!!  Talked to the server, they didn't seem surprise, only asked if we want to exchange to another item, of course no! We asked to remove the item from the bill, I hope they can make this as a serious issue. Will not go there again !!
# Elote, chicken fried bacon, fried Twinkies, pot roast sandwich
# Gotta get my chicken fix!!!!!!
# The Mediterranean chicken is a party in your mouth!
# Maryln's had given me raw chicken no thanks
# Them chicken fingers tho
# Don't waste your money on the chicken wrap
# The "pulled chicken" is actually just chunks of chicken.
# Santa fe chicken sandwich
# According to the only rated review I was afraid of wasting my money there but hey, you can go eat sushi knowing your investment WILL be worth it
# Try both of the chicken dishes and didn't like it though...
# Stick to sushi!!
# Jerk chicken sandwich. Key.
# get your unlimited friend chicken skin and chicaron bulaklak.. 26 filipino dishes are here! they got it!
# My fav... Princess chicken w/Mara
# Fried chicken b4 drinks
# Double entree orange chicken and chow mein!
# The service was awful
# Food was below average
# Grilled chicken tasted like plastic
# Get the spicy chicken
# This was the absolute worst sushi I have ever tasted. We ordered take out tonight and just finished. I want to drive back there and demand a $50.00 refund. Absolutely disgusting. We Ordered chicken teriyaki .... It is chicken that has been soaking in soy sauce all day! Way too salty.... Mesa Roll that everyone says is to die for Is BLAND the jalepeno is non existant and no eel sauce. Spicy tuna roll bland..... Nothing was fresh.... Do not spend your money there. Im sure I'll be sick tomorrow!
# My chicken legs
# Non nom pomegranate chicken gyros yum
# Every piece of the fried chicken I ate had chopped up bone and gristle in it.
# For the Winterlicious menu pick the salmon not the chicken it was very dry
# Get the buttermilk chicken or animal burger
# Lunchtime - chicken katsu, spam musubi & a Passion Orange Hawaiian Sun!
# Poor service,great chicken, and popcorn shrimp very spicy
# Red curry chicken here is yummy!
# Yo yo yo yo yo yo this place has mad healthy chicken bowls.
# The chicken and waffle is bomb
# Combo plate beef and chicken slong with Jerusalem salad. Minimum carbs.
# If I could eat one thing everyday for the rest of my life it would be there smoked chicken no barbecue sauce its to die for
# Mock BBQ chicken!
# Get the chicken and waffles!!!
# They never have bread to make chicken parmesan
# there buffalo chicken sliders are to die for!!!
# Taco Tuesday $1 each for chicken or chorizo ...
# The chicken cordon bleu skillet was to die for!!
# 3 pc chicken tenders, lunchie time snack !
# Got a chicken shawarma, meat was raw and tasted so bad . Not coming back here
# Cajun chicken anything from here is the bomb.com! There's also a secret Asian style extra spicy Ruben. Ask about it!
# Chinois chicken salad!!
# Fried chicken and jo Jo's to.... Almost die for!
# Satay chicken!
# I don't generally like chicken fingers but this place...
# Two chicken two Beef to go
# Yumm!  Goat cheese salad and buttermilk fried chicken
# Lemongrass chicken spicy (?) ... someone forgot the chili sauce in the kitchen. Very plain until Yu-go jazzed it up. Included several slices  of cucumbers. A little expensive for $11.00.
# Mmmmm salad, cause Todd didn't grill chicken.
# $8 for four Filipino style chicken siopao.  Oyster sause and soy bean pasty filler with shredded chicken. Too sweet
# Get the chili chicken!
# Came here to satisfy a friend's wishes for a Boba drink. Ordered saimin & cake noodle with grilled chicken. Saimin noodles were the textbook example of assuming the customer is too dumb to notice the differences of real thing and their con job.
# Fried chicken salad. My fav !
# If you are vegetarian its a spicy selection. If looking  for goat and chicken it is cooked well done
# Sucks. The absolute worst service ever, completely ignored every time I go and the menu is so boring - the same boiled chicken for years and years. Maybe service better at other locations but Shea is a joke
# Try the buttermilk fried chicken! 5 stars.
# On today's menu: chicken, dry salad, a banana, and coffee.
# For the longest time I had this wing ding shack on my radar.  Today's memorial service brings me to Boulder City and so, it's meant for me to try this five star rated chicken outlet.  Bug wings
# Scale of 1 to 5.. portion 3 , macaroni 3, bbq'd chicken 4,theme of place 4, cleanliness 5, menu 3, no loco moco :( overall 3. Is come back..
# Order Andy's sage fried chicken!
# Terribly greasy chicken. No m.potatoes. !
# 5 chicken tenders and a side of fries with a Pepsi $14.56!
# Lemon chicken!
# Had a teriyaki chicken. Was not a fan.
# Can't break away from their nachos with chicken (half order)
# Fried chicken salad
# Peri peri chicken has the kick, moist throughout.
# Chicken is tough. Bit into the chicken sandwich and got a bite of grissel. Menu is very limited and food is overpriced.....and not good. Skip this place and head over to chick -fil-a or kfc.....they know how to do chicken right.
# 1 gyro, chicken parm sandwich and a dozen wings #Lunch
# Order chicken and waffles I don't need to say anymore just do it!
# Seasame chicken ... fried chicken breast
# Just finished a chicken salad sandwich yummy
# Hooked to their Vinegar Pepper Pork Chops with potatoes.  Shared one chop and the other went home. Chose chicken noodle soup as a side dish.
# Get the caking chicken fillet biscuit with dirty rice and sweet potatoe pie. Their fries are soggy and lack flavor.
# This Asian grill sucks. The orange chicken sauce was heavily spiced.
# The chicken is "off the chain!!".
# Had pecan chicken salad and some of the truffle oil fries!
# Will never go back, chicken Francese was awful and the spinach was horrible.
# Chili chicken is the bomb
# Cole turkey and chicken cheese steak. And capistrami. And....
# Six chicken tenders with spicy buffalo and ranch dipping sauces
# Sunday Lunch:  Chef Rudy's "Concoction" (not a menu item) of chicken breast, pepperoccinis, red peppers, lettuce as a sandwich with a jalapeño cream spread. Molto Bene !!
# Buffalo chicken sandwich.
# Bento box with teriyaki beef and garlic chicken.
# Pulled chicken sandwich is a must!
# Skip this place. Spoiled fish in sushi, room temperature crab, cold food in the hot trays, and hard chicken that had been under the lights too long. Siz of us went and none of us ate a third bite.
# khoa soi with chicken!! fried garlic pawns and sea bass drunken noodles!
# Little dab of the soft garlic butter to the chicken and shrimp pinched together by the green lettuce is Opa
# Chinois chicken salad
# Their coconut chicken soup is not as good as it used to be :-(
# Get the chicken satay!
# Order the Cajun chicken! It's the bees knees!
# My 3rd visit ... prime rib was very tender; ox tail soup wasn't bad, cucumber salad plus kimchi was refreshing; rice noodle salad was awful; fried chicken was moist but I didn't care for the fried batter.
# Order the garlic feta fries. Freaking insane. And pair it with the chicken gyro fantastic.
# Buffalo chicken rolls!
# Chicken Prosciutto, tasty  prosciutto and chicken, kalamata olives and artichoke hearts, served with marinara sauce, puts a smile on your face.
# Our Weiss Deli chicken salad sandwich was the envious meal on our Air Canada flight to Montreal. Hee hee.
# Grilled chicken sandwich was tasty!
# The chicken soup is on point
# Stuffed chicken... Buon appetito!
# Lettuce wraps, crab wontons and Kung pow chicken - kabam!!!
# Food sucks! Got chicken sandwich burnt; will not come back
# chicken & waffles is a must. the quesadilla is addicting!
# Not the same as what we are a custom to.  No honey lamb l, no lemon chicken.   Bastilla is a poor dessert version.
# Braised parmesan chicken sandwich: do it!
# Caesar salad with chicken and gyro meat!!
# Kung pao soy chicken is a must
# Try the BBQ chicken quesadilla
# Six pc chicken mix without rolls ... talk about bang for the bucks.
# The chicken bowl is a must have this chip and guacamole
# Large chicken teriyaki is the bomb!
# Split the beef and chicken Koobideh Kabobs between us.  They look and tasted so yummy.
# BBQ chicken ＼(^o^)／
# My wife and I decided to give it another try after getting lousy service last year.  Well nothing's changed.  My wife ordered the chicken salad and there was a rotten cucumber on top and stale croutons.  I had the burrito and it came with black beans surrounding the burrito.    Never again.
# Fried chicken eggs Benedict rock!
# Every item ala carte... Filipino spaghetti; two pork entrees and one chicken.  My taster approved 200%
# Orange chicken is what I get every time..
# This is the place to go for chicken and waffles.
# Ordered yellow curry with chicken, beef pad se ew and shrimp pad Thai from their lunch menu. So Thai-licious, everything was to 'thai' for! Yum.
# Combination #5 chicken taco, green pork and guacamole burrito and cheese enchilada. Eating here reminded me of what real Mexican food and service was meant to be. I extended my experience by taking half of it home with me.
# They really don't skimp out on that chicken. Also had the salad bowl. Yum!
# Don't ever get the chicken parm!
# Try the chicken Phoenix. Yummy!
# Atul's reccos
#
# Apps:
#
# Dry chilli chicken
# Chicken sampler
#
# Main:
#
# Lamb korma
# Chicken tikka masala
#
# Plain Naan
#
# Ras Malai
# Crispy Pork Belly squeeze some fresh lemon on it and the verdict is it is very dry dry, crunchy and somewhat tasteless, enhanced the taste when dipped into the garlic greens sauce from the chicken gizzards,-4/5.
# BBQ style chicken tacos. Oh yeah.
# Enjoyed the mahi mahi tacos and fried chicken dinners!!! Cold beer too. 4 1/2 star
# Unbelievable chicken and waffles.  Just do it.
# Orchard chicken salad sandwhich is HEAVENLY!
# It's my 1st time here & the entire staff is welcoming. Their shouyu chicken is one of the nest shoe chicken i had in Vegas so far.
# Club sandwich and chicken roti were dry af. Otherwise the patio is lit.
# Fried chicken wings were inedible.   Rightfully so our server removed it from our bill.
# Dirty low upkeep undercooked chicken still pick hard rice
# 5 stars for the chicken and home style honey
# Strawberry chicken salad for lunch!
# Skip this place! They charge nearly $13 for romaine salads! Throw some freaking spring mix in there guys, do you realize you're running a vegan restaurant? You can't just batter & deep-fry a mock chicken burger and call it a night. Or I guess you can, going off some of these reviews. PASS
# I'm having the Luca Brasi chicken parm sub - badda bing!
# Don't order Chicken wing Bowl B. The chicken wing here sucks... We left half bowl here.
# Ordered Avani Chili Fried Prawn appetizer, Man Chow soup with chicken to start
# Jamaican broiled breast of chicken salad with their ranch and house made roll is a solid choice
# Nom nom the spicy chicken sandwich
# Chicken Curry Noodle Soup reminded me of Malaysian or Cambodian cuisine. Not crazy about the chicken breast meat which was dry and tasteless. Still a solid 5/5. Comes with bean sprouts and sliced green chilli peppers
# Bomb chicken veggies & rice dinner!! Highly recommended
# Butter chicken is
# This place sucks. Ordered a pizza  and chicken wings from my hotel room and the food never came. I even called to check up on the order and they said that it would be another 20 min. After an hour I decided to eat something else and after I was done eating they decided to call me and say it would take another 20 min. I told them FORGET IT! I can't tell anyone how the food taste from this place because I didn't try it. But I must say customer service SUCKS!
# Please bring the chicken back!!
# Spicy Chicken Sandwich meal compared to the #1 chicken restaurant spicy chicken meal ...  tonight's meal takes the Blue Ribbon by a landslide.
# Wednesday night we closed the restaurant with owners while viewing the Dubs playing the Lakers. Snacked on 12 fried chicken wings with hot sauce and blue cheese dressing on the side. It was chicken divine!
# My family had dinner at Hodges last Saturday. Here is what we recommend: the lamb dish was rated a 5, the scallops, chicken, and salmon entrees was rated 4. However, the Mac and Cheese side dish was blah. The tuna snack was so-so. The crust under the tuna was cold and tough.
# Bang 4 the bucks shrimp, chicken wings, crinkle fries plus salad for dinner.
# chicken & waffles and griddle French toast!
# Fried chicken!
# Ummm, chicken was tasty but there were a few oopses on the service side. Perhaps a group of 21 was too much to handle...
# Do NOT order the rotisserie chicken salad. It taste like they had a 3 day old rotisserie Directly from the fridge, cold. Chicken skin left on, gristle in chicken too. Very unappetizing.
# Two lunch specials for this late Wednesday afternoon.  Wanted chicken adobo but had to settle for pork. I made the switch from skewered pork to chicken. They were out of the the pork. Yu-go ordered the lechon kawali and kare-kare. Between the four options, i would only retry the lechon. As for the halo-halo. They were out of the ube.  Ho hum !
# Hunters chicken!
# Yummy Mango chicken tacos!!
# sage fried chicken & bacon waffles, biscuits with homemade jam!
# Not impressed with with paying $14 for a salad, and have had a lot tastier shawarma chicken as well...
# Belly Bombz of Paramount CA should have stayed home. Spicy parmesan boneless chicken nuggets was overcooked dry and tasteless. Don't waste your hard earned money. SO NASTY ... WE THREW IT AWAY !
# Someone decided to make the place a drive thru a few weeks ago. They are rebuilding now and should be open again in a few days. Can't wait for my orange chicken.
# Work on my chicken legs!
# Small chicken nachos
# I inhaled chicken enchiladas ... the sauce was new to me ... how about a 4/5 rating
# The wonton crusted prawns and the chicken pappardelle soup are delicious...must order
# Gonna try the spicy chicken with noodles
# Not good Mexican .  My husband found a chicken bone.  Would not go here again.
# Their meat department sucks. Got 4 whole chicken and 1 out of 4 was rotten and smelling that made me sick..called the store and tried to get a manager. Who ever the person on the phone was couldn't give his name (he said he was the manager) . I told him just stop selling rotten products and he said 'you are lying, come tomrw with the chicken when owner is there ' and hung up the phone on me .. hence this review !!
# My two friends shared an order of noodle cake & grilled chicken ... Hawaiian style. Yu-go also shared an order of the same. Without the cornstarch soy sauce gravy, the eating experience would had been terribly dry and tasteless. However there's a price to be paid ... the ugly dry mouth syndrome.
# Three item combo of Beef meat jun, spicy chicken, spicy pork, 2 scoops rice and mac salad
# Avocado salad + grilled chicken yum
# Get the chicken wings!!!!
# The taste of food is not consistent. My husband and I were here 2 weeks ago. The fried chicken was not as salty as it is today.
# Come on one piece of lettuce and a tiny piece of flat chicken.  Not good.
# IMHO ... Undisputed king of fried chicken east of HWY 95
# Greek Salad Wrap with chicken Score it 5/5

# %% [markdown]
# Como podemos observar en los consejos, parece ser que existe un error con la palabra "chicken" puesto que la mayoría de los consejos que la contienen parece que tienen una connotación positiva. De esto podemos deducir que NO podemos decir que las tiendas que venden pollo sean las peores. Aun teniendo estos errores, los resultados arrojados por los wordcloud siguen siendo lo **suficientemente buenos y representativos**.
