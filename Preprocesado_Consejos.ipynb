# %% [markdown]
# ## Dataset consejos
# ### Limpieza Inicial

# %%
import pandas as pd

df_consejos = pd.read_json('Dataset/datos_consejos.json', lines=True, chunksize=100)

df_consejos

# %% [markdown]
# ### Carga del fichero
#
# Este fichero, al contrario que el resto, está en formato JSON por lo que no podemos hacer la carga directamente.
# Para cargarlo, lo abrimos como un fichero regular y con la librería de JSON lo leemos. Al leerlo obtenemos un diccionario (por la sintaxis de JSON) y lo transformamos a Dataframe con una función de Pandas.

# %%
import pandas as pd
import json

with open('Dataset/datos_consejos.json') as f:
   json_consejos = json.load(f)

# %%
json_consejos["data"]
# Out:
# [{'index': 0,
#   'usuario_id': 'UPw5DWs_b-e2JRBS-t37Ag',
#   'negocio_id': 'VaKXUpmWTTWDKbpJ3aQdMw',
#   'texto': 'Great for watching games, ufc, and whatever else tickles yer fancy',
#   'fecha': '2014-03-27 03:51:24',
#   'num_likes': 0},
#  {'index': 1,
#   'usuario_id': 'Ocha4kZBHb4JK0lOWvE0sg',
#   'negocio_id': 'OPiPeoJiv92rENwbq76orA',
#   'texto': 'Happy Hour 2-4 daily with 1/2 price drinks and slushes AND after 8 half price shakes.  They actually have a peanut butter and bacon shake.',
#   'fecha': '2013-05-25 06:00:56',
#   'num_likes': 0},
#  {'index': 2,
#   'usuario_id': 'jRyO2V1pA4CdVVqCIOPc1Q',
#   'negocio_id': '5KheTjYPu1HcQzQFtm4_vw',
#   'texto': 'Good chips and salsa. Loud at times. Good service. Bathrooms AWFUL. So that tanks my view on this place.',
#   'fecha': '2011-12-26 01:46:17',
#   'num_likes': 0},
#  {'index': 3,
#   'usuario_id': 'FuTJWFYm4UKqewaosss1KA',
#   'negocio_id': 'TkoyGi8J7YFjA6SbaRzrxg',
#   'texto': 'The setting and decoration here is amazing. Come check out the waterfall fountain in the middle!',
#   'fecha': '2014-03-23 21:32:49',
#   'num_likes': 0},
#  {'index': 4,
#   'usuario_id': 'LUlKtaM3nXd-E4N4uOk_fQ',
#   'negocio_id': 'AkL6Ous6A1atZejfZXn1Bg',
#   'texto': 'Molly is definately taking a picture with Santa lols',
#   'fecha': '2012-10-06 00:19:27',
#   'num_likes': 0},
#  {'index': 5,
#   'usuario_id': 'iAd8XaHxv05iXyEiZ62Ibw',
#   'negocio_id': 'kj1p6NwUGROOoqNySf0I1Q',
#   'texto': "It's true! The drunken noodles are outrageous!",
#   'fecha': '2011-12-31 18:02:42',
#   'num_likes': 0},
#  {'index': 6,
#   'usuario_id': 'w8p4JW6-ERsbg8aB5wjEAg',
#   'negocio_id': '0hudPyuCBlKg79OwKBw-eQ',
#   'texto': 'Only worth a visit in the summer time, to take advantage of the huge sun soaked patio.',
#   'fecha': '2012-10-11 23:06:21',
#   'num_likes': 0},
#  {'index': 7,
#   'usuario_id': 'CaFbX7topxdLpBJ_SNDfGQ',
#   'negocio_id': 'r49iBfbnfoK7yt4rdsL_7g',
#   'texto': 'Hands down best AYCE in town! Love it!',
#   'fecha': '2016-01-05 06:39:33',
#   'num_likes': 0},
#  {'index': 8,
#   'usuario_id': 'VLy6l8L72adD7iTBNqiPXw',
#   'negocio_id': 'YCRCFBr6myPS49on2aS2pQ',
#   'texto': "Sat in the drive thru this afternoon for 30 minutes and then was handed the wrong coffee. Booooo, I'm seriously here every day and this was the first bad experience",
#   'fecha': '2017-03-13 03:29:40',
#   'num_likes': 0},
#  {'index': 9,
#   'usuario_id': 'zrvk0-B91ahJRSB-UcAmIA',
#   'negocio_id': 'RTBIiq-fJUXRsrzbL4MCqw',
#   'texto': 'Okay so I had a groupon for a nearby service center, but their wait time was 3 hours! Once again, I find myself back at this Brake Masters. Idk why I bother with anywhere else; This place is great!',
#   'fecha': '2013-02-08 20:55:15',
#   'num_likes': 0},
#  {'index': 10,
#   'usuario_id': '8zXgNCkusOHMwh5Tj_8yCQ',
#   'negocio_id': 'qrSsS0pk7SL67MP5nN8tlg',
#   'texto': 'More parking in the back of the restaurant',
#   'fecha': '2013-12-22 05:10:12',
#   'num_likes': 0},
#  {'index': 11,
#   'usuario_id': 'NXXC2iU0o3tDVu6YNaW3Ww',
#   'negocio_id': 'oGASRzKGpuiP12ilQH_nKg',
#   'texto': 'Best pretzels this side of the Rhein. Wash down with the Franziskaner Weissbier.',
#   'fecha': '2010-03-04 15:41:16',
#   'num_likes': 0},
#  {'index': 12,
#   'usuario_id': 'DfvT4F5Eqx9Xr3Ei3GYWPg',
#   'negocio_id': '63bHLJUomC22Xdm3IjgBtw',
#   'texto': 'Having the yellow curry, summer rolls and a coke. I would recommend the rolls but the curry was incredible!',
#   'fecha': '2011-10-18 18:29:05',
#   'num_likes': 0},
#  {'index': 13,
#   'usuario_id': 'oIHhfloe5VQamDFDB2dr1Q',
#   'negocio_id': 'wZhB4U003eg2GQ-F7D2D4A',
#   'texto': "When you receive the bag of seafood tie it up and then mix it up that way all the flavours get into the seafood. As well for the owner play less Drake music please and thank you when I'm here. :D Congrats Guys",
#   'fecha': '2016-08-12 22:18:07',
#   'num_likes': 0},
#  {'index': 14,
#   'usuario_id': 'NEN5RFpZp7DE6K1PK2KZzg',
#   'negocio_id': 'Cni2l-VKG_pdospJ6xliXQ',
#   'texto': '2nd stop for the pub-crawl! Yay!',
#   'fecha': '2011-10-09 03:43:39',
#   'num_likes': 0},
#  {'index': 15,
#   'usuario_id': 'Fzz-0v1yHLaWuTV64b1miA',
#   'negocio_id': 'EZZjaiV8ik05NUepqdeP2A',
#   'texto': 'Really delicious food and amazing service.',
#   'fecha': '2018-02-14 21:35:49',
#   'num_likes': 0},
#  {'index': 16,
#   'usuario_id': 'CbmNBkKa9QKNxPiN_whFUw',
#   'negocio_id': 'xZfPdAYeimiruXuGR4nSUA',
#   'texto': 'Dinner!!',
#   'fecha': '2011-04-21 22:43:28',
#   'num_likes': 0},
#  {'index': 17,
#   'usuario_id': '3KkT6SmPFLGvBS1pnDBr8g',
#   'negocio_id': 'D2nfOrnJ2OBlX_428sKyMg',
#   'texto': 'Long lines at lunch!!',
#   'fecha': '2011-12-30 17:10:16',
#   'num_likes': 0},
#  {'index': 18,
#   'usuario_id': 'kMcz3zQgNjZYV65qY9ztGA',
#   'negocio_id': 'C7JaaErXLB3B3486LfWg5w',
#   'texto': 'Go somewhere else to buy a car or mini van.\nRude, assuming sales staff; they are not going to lower the price on a vehicle,  The black sales guy is unprofessional and barely knows his job; he is rude and insults customers.',
#   'fecha': '2013-02-17 06:22:49',
#   'num_likes': 0},
#  {'index': 19,
#   'usuario_id': 'JnHaPHkRO2_8V-DysmIBVw',
#   'negocio_id': 'j9I2YkFCOKyAEb_3FbFqUA',
#   'texto': '#poutinecrawl #yyc stop #1',
#   'fecha': '2011-04-09 18:58:36',
#   'num_likes': 0},
#  {'index': 20,
#   'usuario_id': 'EZbvMdvCA2D9vF6VjILYXA',
#   'negocio_id': 'LrO_Xy6lfpbTgFoJcOjY4w',
#   'texto': 'I love the gourmet veggie pizza!!',
#   'fecha': '2015-05-21 01:13:24',
#   'num_likes': 0},
#  {'index': 21,
#   'usuario_id': 'pDAqvfflIM4AM23VRpqAaw',
#   'negocio_id': '0PVxodALQu-soL5J8bjerQ',
#   'texto': "If there's a more authentic breakfast place in Pittsburgh, I haven't found it. Ritter's is comfort food at its best!",
#   'fecha': '2012-07-24 16:24:09',
#   'num_likes': 0},
#  {'index': 22,
#   'usuario_id': 'gGlFgp4nXNL5azpUtLK05w',
#   'negocio_id': 'cnfYugAYBFKgwDCTAVdViA',
#   'texto': 'No',
#   'fecha': '2015-05-29 04:25:09',
#   'num_likes': 0},
#  {'index': 23,
#   'usuario_id': 'HmILc-lgVKZS7mWNdYCSJw',
#   'negocio_id': '1l7gJx3BVWBZ8Wx1vPCkeA',
#   'texto': 'New Dr Who! He talks with an accent, " I\'m the Doctor" Oui Garcon!',
#   'fecha': '2013-11-30 04:03:27',
#   'num_likes': 0},
#  {'index': 24,
#   'usuario_id': 'lesnCKZUYH554j-EDZBlTw',
#   'negocio_id': '7sPNbCx7vGAaH7SbNPZ6oA',
#   'texto': 'Late night burger cravings...',
#   'fecha': '2012-08-02 06:25:54',
#   'num_likes': 0},
#  {'index': 25,
#   'usuario_id': 'alUuOskFSl1bODjnce2PpQ',
#   'negocio_id': 'PEb1Hm0kQ52cObjPAE6nFQ',
#   'texto': 'Cash only! ATM on site',
#   'fecha': '2014-09-06 23:29:08',
#   'num_likes': 0},
#  {'index': 26,
#   'usuario_id': 'hf27xTME3EiCp6NL6VtWZQ',
#   'negocio_id': 'i6G3zsEJIqpGktMWyffXjw',
#   'texto': 'Holiday party',
#   'fecha': '2013-12-19 21:29:53',
#   'num_likes': 0},
#  {'index': 27,
#   'usuario_id': 'TYCkjEHPSJSnFb6m6GDluw',
#   'negocio_id': 'XP0YZRa6Un25QaOH2g1ivA',
#   'texto': 'oh damn. run do not walk to circle-h. pulled pork.',
#   'fecha': '2011-12-30 22:00:46',
#   'num_likes': 0},
#  {'index': 28,
#   'usuario_id': 'r64WY53LOMRPowHDu2JIXw',
#   'negocio_id': 'p-8AMN9Q0qwym-3Pdle20Q',
#   'texto': 'Good mix of cuisine',
#   'fecha': '2017-03-10 19:32:16',
#   'num_likes': 0},
#  {'index': 29,
#   'usuario_id': 'r5ggPC6OccLk6dDl5yqsJQ',
#   'negocio_id': 'wyPkRQg3F5Yz2WqRFax7-g',
#   'texto': 'Burgers, salads, entrees of chili and even a ribeye steak.',
#   'fecha': '2010-12-18 02:00:22',
#   'num_likes': 0},
#  {'index': 30,
#   'usuario_id': '8aXyfFUFrypoE6PkUQBtmg',
#   'negocio_id': 'PtwW1Hwme8Y0wy54zNr8Xw',
#   'texto': 'Wonderful food and great service! I will definitely be back with my family!',
#   'fecha': '2014-06-07 17:04:01',
#   'num_likes': 0},
#  {'index': 31,
#   'usuario_id': 'O_GWZZfQx7qv-n-CN7hsIA',
#   'negocio_id': 'IzC1oXHT_TxYej_6YTfBnA',
#   'texto': 'Over 100 group fitness class a week!!!',
#   'fecha': '2012-10-16 18:25:20',
#   'num_likes': 0},
#  {'index': 32,
#   'usuario_id': 'lhPuskGXTRSjCwKOOOYeoA',
#   'negocio_id': 'e5Qw3r7mkwPLcdDzZzTeew',
#   'texto': 'good stuff!',
#   'fecha': '2011-07-12 20:41:17',
#   'num_likes': 0},
#  {'index': 33,
#   'usuario_id': 'ZXIOnRHvDUK-corzrUbqoA',
#   'negocio_id': '7jKDOB9b_nijq0-djwyUTw',
#   'texto': 'Tara did a great job. I will go back for another hair cut.',
#   'fecha': '2016-05-22 00:11:14',
#   'num_likes': 0},
#  {'index': 34,
#   'usuario_id': '2EuPAGalYnP7eSxPgFCNDg',
#   'negocio_id': 'NqCHqgF_FY0Aw9gD-Z3ABQ',
#   'texto': 'Its open! Lobby closes at 10pm.The drive-thru open till 11pm',
#   'fecha': '2014-06-03 04:23:22',
#   'num_likes': 1},
#  {'index': 35,
#   'usuario_id': 'ZK6aHHTiNlQWCCmv69OXnA',
#   'negocio_id': 'DkYS3arLOhA8si5uUEmHOw',
#   'texto': 'You know I had to come back first thing after checking into the hotel!! :]',
#   'fecha': '2012-11-04 03:58:17',
#   'num_likes': 0},
#  {'index': 36,
#   'usuario_id': '0FMte0z-repSVWSJ_BaQTg',
#   'negocio_id': '6pSwIh7gbTEpfxDlKEiB5A',
#   'texto': 'PTL time!',
#   'fecha': '2012-05-25 00:05:01',
#   'num_likes': 0},
#  {'index': 37,
#   'usuario_id': 'uu-gMsKDyKU_9MUItbNkHA',
#   'negocio_id': 'I0f12eU-xFn6Kd_4H57jrQ',
#   'texto': 'Soup was awesome!!',
#   'fecha': '2016-07-30 08:08:12',
#   'num_likes': 0},
#  {'index': 38,
#   'usuario_id': 'CcJQAZfk6QkaBjPnKepLcg',
#   'negocio_id': 'vYn0gishV27DpfM_loZITQ',
#   'texto': 'Southwestern egg rolls...yummy!',
#   'fecha': '2013-12-11 17:45:51',
#   'num_likes': 0},
#  {'index': 39,
#   'usuario_id': 'ge72-Ti-WqR3w0YENY5pRQ',
#   'negocio_id': 'Lzv68iVkRHstVvW3aXNWkA',
#   'texto': 'So far everything has been great',
#   'fecha': '2015-09-28 00:55:47',
#   'num_likes': 0},
#  {'index': 40,
#   'usuario_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'negocio_id': '19umlhmVB9O3njIBfRAe8g',
#   'texto': "Hey mom look at me! I'm Nancy friggen' Kerrigan!!",
#   'fecha': '2014-08-24 03:56:50',
#   'num_likes': 1},
#  {'index': 41,
#   'usuario_id': 't511fq0nFeppix5_MP-nxA',
#   'negocio_id': 'ZhLSAiRj9kANxf8m2SBfRA',
#   'texto': 'New Milk Tea Recipe! not as sweet, and nice tea flavor.',
#   'fecha': '2017-03-21 22:30:13',
#   'num_likes': 0},
#  {'index': 42,
#   'usuario_id': '29yBaTFMSh-l6wNwy9d_mA',
#   'negocio_id': 'jaJnPIX9VxsFyfV5zQwk0g',
#   'texto': 'Lots of people on the second floor!',
#   'fecha': '2011-01-01 23:54:04',
#   'num_likes': 0},
#  {'index': 43,
#   'usuario_id': 'qvvpeBLkV4Shx0Teh87lPA',
#   'negocio_id': 'XXGzCIcxzAZ6H98mxZbdqA',
#   'texto': 'Um. All kinds of awesome!  Big clean and all the Chinese and western groceries you can imagine.',
#   'fecha': '2010-04-26 15:34:54',
#   'num_likes': 0},
#  {'index': 44,
#   'usuario_id': 'R_wlZO-jKFGEVJnSfWISqQ',
#   'negocio_id': 'Z15a7_8FQ82_baSJiqMoIw',
#   'texto': 'Tons of wing flavors...',
#   'fecha': '2012-08-03 21:54:49',
#   'num_likes': 0},
#  {'index': 45,
#   'usuario_id': 'aoO6EXKupIDDDMMK4PG-iw',
#   'negocio_id': 'e7207sqC-pSn6GIf31ikhQ',
#   'texto': 'Birthday breakfast!',
#   'fecha': '2013-02-21 13:29:23',
#   'num_likes': 0},
#  {'index': 46,
#   'usuario_id': 'we_ONmXR0wP5-Ejx9AbIAA',
#   'negocio_id': 'JTl1nXrukJTScI0Uz0x2Fg',
#   'texto': 'Try the green gables IPA, it is delicious!!',
#   'fecha': '2016-11-18 20:23:00',
#   'num_likes': 0},
#  {'index': 47,
#   'usuario_id': 'akUC5qP68u0_frTwHLl61w',
#   'negocio_id': 'IBxD5xo8o3FDquF1dkA31g',
#   'texto': 'Save room for a yummy scone!',
#   'fecha': '2013-02-19 20:45:57',
#   'num_likes': 0},
#  {'index': 48,
#   'usuario_id': 'syA7uYoDjohc7gWBWaEZmw',
#   'negocio_id': 'V3U21fM0in_0qpKUMYPNOw',
#   'texto': '15 dollar credit card minimum, no AMEX',
#   'fecha': '2012-03-19 01:47:32',
#   'num_likes': 0},
#  {'index': 49,
#   'usuario_id': 'xceJT1G2Yhel3W2lRxRTDA',
#   'negocio_id': 'enzgrlkltK3PO-KGg1pkSQ',
#   'texto': 'Mani/Pedi for $15.',
#   'fecha': '2012-07-27 19:27:17',
#   'num_likes': 0},
#  {'index': 50,
#   'usuario_id': 'mEiQo6a56dtSXlZEl4F1rQ',
#   'negocio_id': '11fdZ98T5ddYgc12bp99PQ',
#   'texto': 'You can order custom rolls if you ask nicely ;)',
#   'fecha': '2017-09-22 06:21:10',
#   'num_likes': 0},
#  {'index': 51,
#   'usuario_id': '330erZ8TCzA2eoexQMATBg',
#   'negocio_id': '6sKaAF8WhWyyCjfZr2Rfsg',
#   'texto': 'Last time... =(',
#   'fecha': '2011-04-07 01:04:16',
#   'num_likes': 0},
#  {'index': 52,
#   'usuario_id': 'T1jicY-vxpCOTl5SIdVLxg',
#   'negocio_id': '_sOni_t0FvAQuUDBEGe3Gg',
#   'texto': 'Busy tonight',
#   'fecha': '2012-03-11 07:31:32',
#   'num_likes': 0},
#  {'index': 53,
#   'usuario_id': 'OGufU1fcIoHbnoo-ugWfDg',
#   'negocio_id': 'B1I54bu8w5MikyFr7IUD7A',
#   'texto': 'Dr. Spilotro is the best, awesome staff',
#   'fecha': '2017-06-28 18:06:39',
#   'num_likes': 0},
#  {'index': 54,
#   'usuario_id': '2sNEKxKcGaTVBJiokqp9Zg',
#   'negocio_id': 'Yk7fxB4-8MeFd6HkEF8wsA',
#   'texto': 'Super friendly! This is the ONLY Starbucks drive thru in Gilbert and it takes FOREVER!!',
#   'fecha': '2014-03-28 19:23:08',
#   'num_likes': 0},
#  {'index': 55,
#   'usuario_id': 'kkbZPTl9Q4KVwMMBxTCiUQ',
#   'negocio_id': 'fN_I3jP7RD2llubTvhXtKQ',
#   'texto': "Red velvet pancakes. Seriously..... can't take picture. They are devoured.",
#   'fecha': '2017-11-17 17:04:26',
#   'num_likes': 0},
#  {'index': 56,
#   'usuario_id': 'PIaq7y05SdYBqISlNEpagQ',
#   'negocio_id': 'FzY_eaGmRAOG1TvLKTrsnw',
#   'texto': 'Hurry!  My Hot Stone Massage Special is about to expire!',
#   'fecha': '2011-07-14 23:31:37',
#   'num_likes': 0},
#  {'index': 57,
#   'usuario_id': 'anHzk1C0oQRtfuDj74p2RQ',
#   'negocio_id': '9a3DrZvpYxVs3k_qwlCNSw',
#   'texto': 'Mama Mia!',
#   'fecha': '2011-07-15 01:26:26',
#   'num_likes': 0},
#  {'index': 58,
#   'usuario_id': 'N3ELg9zITVB5Ij1Cnr1wKA',
#   'negocio_id': 'urWkq22ug6ppT4a6aSPwhA',
#   'texto': 'My first time eating a bahn mi and pho. The food here is excellent!',
#   'fecha': '2016-01-14 00:22:34',
#   'num_likes': 0},
#  {'index': 59,
#   'usuario_id': '9uE0smG2bwgkI95RPj0lPQ',
#   'negocio_id': 'E9aC5bLfXdQVZ5csvLuLJg',
#   'texto': 'Green papaya salad not good.  Papaya sliced too thick and not enough fish sauce or flavoring. Portion small for price.',
#   'fecha': '2012-01-08 21:40:43',
#   'num_likes': 0},
#  {'index': 60,
#   'usuario_id': 'rNjgVKaBh1PlUA6dYB6EUw',
#   'negocio_id': 'zvQIEpJUmLLmMMffNntHXQ',
#   'texto': 'Gas price 3.49 regular',
#   'fecha': '2014-06-07 19:16:12',
#   'num_likes': 0},
#  {'index': 61,
#   'usuario_id': 'tAw16nAiAcAm8V7H1dQ2eg',
#   'negocio_id': 'OjnRf8yDGEBCoUDdchSViw',
#   'texto': 'Yay hushpuppies!',
#   'fecha': '2012-10-06 02:19:39',
#   'num_likes': 0},
#  {'index': 62,
#   'usuario_id': 'VqBSNxY9nbGdUGZ5fnhudA',
#   'negocio_id': 'fCq3AVUzWDarScN020AcjQ',
#   'texto': 'The iced kicker is a must, and if you have little ones a chocolate milk with whip cream.',
#   'fecha': '2016-04-17 18:26:57',
#   'num_likes': 0},
#  {'index': 63,
#   'usuario_id': '5wT0vDycEzgq95yVCZ60Aw',
#   'negocio_id': 'sDT7CvVLsPG1JizVddhxzg',
#   'texto': 'Grill marinated porkchop w julienned pork and steamed eggs...yum',
#   'fecha': '2011-04-15 03:38:54',
#   'num_likes': 0},
#  {'index': 64,
#   'usuario_id': 'Hc2tC2TDMD1wDjp8aCq7jA',
#   'negocio_id': 'FgPANtTwZqXB-edLkZTXQg',
#   'texto': 'Worst. Mexican. Ever.',
#   'fecha': '2010-03-13 20:52:19',
#   'num_likes': 0},
#  {'index': 65,
#   'usuario_id': 'AIHzJz0AvTq0FxCLtBhOZA',
#   'negocio_id': 'yNPh5SO-7wr8HPpVCDPbXQ',
#   'texto': 'Yet another Business Journal event.',
#   'fecha': '2012-03-23 00:07:55',
#   'num_likes': 0},
#  {'index': 66,
#   'usuario_id': 'evDmfYHbxqDAy8_27bAUNg',
#   'negocio_id': 'GHS1rVjO-RMcRB6WJLpCDQ',
#   'texto': 'Put lots of sunblock!',
#   'fecha': '2011-07-18 01:49:00',
#   'num_likes': 0},
#  {'index': 67,
#   'usuario_id': '_RvEDmpbQZulEdAV590QKg',
#   'negocio_id': 'xQLs0A2dzgXgJq6K2U_UUA',
#   'texto': "Annoying they don't offer baby and me movies throughout the week in a 'hood full of moms!!",
#   'fecha': '2012-01-09 19:46:53',
#   'num_likes': 0},
#  {'index': 68,
#   'usuario_id': 'FSJDnMPHNOpZrqR1wHp53A',
#   'negocio_id': 'xWcFzMj1ekDoP1pg3IHPMQ',
#   'texto': 'The toffee and the caramel cake are delicious!',
#   'fecha': '2015-01-12 17:57:03',
#   'num_likes': 0},
#  {'index': 69,
#   'usuario_id': 'Q6OjHSEwO55rGLo0Wczoug',
#   'negocio_id': 'aWVoSYc6LJLT2FrXfsFdHw',
#   'texto': 'Great service, on time, explained everything and very friendly.',
#   'fecha': '2017-09-19 15:36:33',
#   'num_likes': 0},
#  {'index': 70,
#   'usuario_id': 'DiGzInTxDfhDGZe2ulXiwQ',
#   'negocio_id': 'kVXyz0mYd7NaGuGdM_VMeQ',
#   'texto': 'Great bakery. Awesome tasty baked goods. Affordable  prices.',
#   'fecha': '2015-12-31 05:44:31',
#   'num_likes': 0},
#  {'index': 71,
#   'usuario_id': 'KGQZvfuthc12iq7p_VzX-w',
#   'negocio_id': 'EXMLrw5uxng5z-T9Z2X8oA',
#   'texto': 'Super nice staff in a busy shop',
#   'fecha': '2012-10-06 19:54:17',
#   'num_likes': 0},
#  {'index': 72,
#   'usuario_id': 'T9xfkjF1R0a_fIjZ-7Hofw',
#   'negocio_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'texto': 'Ohh !!!! This place is Awesome.. Their Lamb chops are dying for...love coming here...',
#   'fecha': '2013-06-05 01:00:37',
#   'num_likes': 0},
#  {'index': 73,
#   'usuario_id': '5G0RQ4kAsBOPSJsKwWnaSg',
#   'negocio_id': 'mlkVAm2DkGnKnNVR1AnQLA',
#   'texto': 'One of the best locations because the staff are always super nice, accommodating and hard working!',
#   'fecha': '2017-06-18 16:59:17',
#   'num_likes': 0},
#  {'index': 74,
#   'usuario_id': 'vIsEJsMbPGOVsSp04cc6EQ',
#   'negocio_id': 'Xwf022IffmZPq6V25iomDg',
#   'texto': 'We have 5 chairs left for face time networking.  Www.facetimenetworking.com',
#   'fecha': '2012-05-18 20:39:45',
#   'num_likes': 0},
#  {'index': 75,
#   'usuario_id': 'RieCsZdS5b_I3p7lB6mo0Q',
#   'negocio_id': '7nv7W2ZaY8BJ9KZ-xF5vYQ',
#   'texto': "Fuggit-about it it's cool learn a lot about the real Vegas!",
#   'fecha': '2012-07-25 03:35:40',
#   'num_likes': 0},
#  {'index': 76,
#   'usuario_id': 'AuSB69SSnaPNTwwbFk93MQ',
#   'negocio_id': 'bAHDSbpJE3kKJkW9OBgOyw',
#   'texto': 'Very nice, helpful and fast! Helped me every step along the way.',
#   'fecha': '2018-03-23 16:57:09',
#   'num_likes': 0},
#  {'index': 77,
#   'usuario_id': '40m0541Z_KexYkdvvqHJIQ',
#   'negocio_id': '7SJoMX5ti-VoEsEW6mJLRA',
#   'texto': 'Amazing talent, beautiful building, incredible orchestra but not enough estrogen in the world to make me suffer through another 3 hours.',
#   'fecha': '2012-10-08 17:44:35',
#   'num_likes': 0},
#  {'index': 78,
#   'usuario_id': 'pkpzIhX1mNzLLEEyj4syKQ',
#   'negocio_id': '-ME7F1xPHdtyje-SzQPnkw',
#   'texto': 'On their Sunday afternoon sessions - they provide the orange juice, you provide the champagne! Yay mimosas!',
#   'fecha': '2015-01-11 16:20:51',
#   'num_likes': 0},
#  {'index': 79,
#   'usuario_id': 'YB2SZbMgQHBOGOIsBK2Tkg',
#   'negocio_id': 'maIam6HyU4FB_sBIk9ippA',
#   'texto': 'If you hit "max bet" on one of the machines it will bet all the money you have in there.....the bartender will tell you after.....rip off',
#   'fecha': '2016-08-04 19:10:24',
#   'num_likes': 0},
#  {'index': 80,
#   'usuario_id': 'li7AtdY322dAqBGicsgL0g',
#   'negocio_id': '1HD5iUUfVJDbfEBIn9yVhw',
#   'texto': "They now have PUDDING here! For those who don't wanna make the drive to Yo & I, make your own house special here.",
#   'fecha': '2014-09-30 00:36:07',
#   'num_likes': 0},
#  {'index': 81,
#   'usuario_id': 'SxcN4e5SKNhZ4wfEUbAMRA',
#   'negocio_id': 'gY95Q7BVB636-tAcDqC9Ww',
#   'texto': 'Good Mexican food quick. Good prices and family oriented. The price is good and definitely will be back again. The tableside guacamole is cool too.',
#   'fecha': '2015-01-11 22:10:08',
#   'num_likes': 0},
#  {'index': 82,
#   'usuario_id': 'xTHoZ5p6P0SGr3Hh7PXQ_Q',
#   'negocio_id': 'GlRyWZMitKSTLufCPx6xkQ',
#   'texto': 'Tip in cash.',
#   'fecha': '2016-11-23 23:16:58',
#   'num_likes': 0},
#  {'index': 83,
#   'usuario_id': 'KQm9OgdujLZiMRTksmj83w',
#   'negocio_id': 'W9YgQFWP1PkhYq7NtGLMXA',
#   'texto': 'Remodeling time!',
#   'fecha': '2010-04-24 16:35:01',
#   'num_likes': 0},
#  {'index': 84,
#   'usuario_id': 'D6iI_B7BFRGrNgDcZcojmw',
#   'negocio_id': '9B1ivc2ztvI8XDJ5TeE5eA',
#   'texto': 'Terrible service and staff. Be careful if you are gonna complain about something. Manager or staff WILL LECTURE YOU. Stay away.',
#   'fecha': '2013-08-24 02:38:49',
#   'num_likes': 0},
#  {'index': 85,
#   'usuario_id': 'uPDo46xDK_DDqMChG-wYaw',
#   'negocio_id': '6oKZoCI_0ePyzfRqSFMBig',
#   'texto': 'One of my favorite places!!',
#   'fecha': '2014-06-08 02:20:51',
#   'num_likes': 0},
#  {'index': 86,
#   'usuario_id': 'wxeTtPILiMl1L-yBB-D2HA',
#   'negocio_id': '1hkksm102yQY1DyfTPSzmA',
#   'texto': 'Dinner time! Really just to make Katie happy. ;)',
#   'fecha': '2011-04-17 00:31:47',
#   'num_likes': 0},
#  {'index': 87,
#   'usuario_id': 'IMkif9yrPAxj-0-nrrgTBA',
#   'negocio_id': '7sb2FYLS2sejZKxRYF9mtg',
#   'texto': 'Be sure to try the pork belly, baked lobster roll, and jalapeño bombs. For desert, homemade black sesame blanc manger, and green tea panna cotta. (And mochi! Always mochi! )',
#   'fecha': '2014-03-15 04:35:13',
#   'num_likes': 0},
#  {'index': 88,
#   'usuario_id': 'PcBKCHMhV0pxmYjzGUKmYg',
#   'negocio_id': 'Ax2JxfCUjfBkRxcqfA4QLw',
#   'texto': 'No PB2 powdered peanut butter. Boo :(',
#   'fecha': '2012-03-12 22:34:09',
#   'num_likes': 0},
#  {'index': 89,
#   'usuario_id': '6GJQc7rRKi2AeS1j48LorA',
#   'negocio_id': 'DgnIqlqYXdeg0UtSRaKcLQ',
#   'texto': 'Totally AWESOME food, I was taken with the flavor and the presentation of it all!!!!',
#   'fecha': '2015-01-16 03:40:26',
#   'num_likes': 0},
#  {'index': 90,
#   'usuario_id': 'Ryxj0u0AW3mRsRypdYli2A',
#   'negocio_id': '2SfSzEd3B7WimeZac23zhg',
#   'texto': 'Delicious food and friendly service',
#   'fecha': '2017-06-19 04:13:21',
#   'num_likes': 0},
#  {'index': 91,
#   'usuario_id': 'T1jicY-vxpCOTl5SIdVLxg',
#   'negocio_id': 'sw3uJ-R5u8_VnJ_RrC15bg',
#   'texto': 'Better than the one last night..i like the cold beer room in this heat :)',
#   'fecha': '2012-08-05 23:25:05',
#   'num_likes': 1},
#  {'index': 92,
#   'usuario_id': 'DBTa2O0kM6MqwP6IOTp_og',
#   'negocio_id': 'CqVdLcbyZzfAjeCD1qEBZQ',
#   'texto': 'Permanantly closed...',
#   'fecha': '2014-03-16 20:45:34',
#   'num_likes': 2},
#  {'index': 93,
#   'usuario_id': 'BqAMAM9wkjUyOJzqYOHg5g',
#   'negocio_id': 'bNqBMZ00lnhhfxzV8OhLfQ',
#   'texto': 'Southern BBQ in Markham?! Whuuut?!',
#   'fecha': '2013-06-01 20:30:47',
#   'num_likes': 0},
#  {'index': 94,
#   'usuario_id': 'cCtB72I6FfLDcU7Zk67N9g',
#   'negocio_id': 'PVdy4harWpqcqQZH8mZXkg',
#   'texto': 'Closed for business',
#   'fecha': '2012-07-22 01:25:31',
#   'num_likes': 0},
#  {'index': 95,
#   'usuario_id': 'uS6-ArpRRwk768bRcU7Hrg',
#   'negocio_id': 'nwHd2MbIGz0SNG8GpFjekw',
#   'texto': 'Taco Tuesday, AGAIN!!!! $1 street tacos. Everything but carne asada. The best.',
#   'fecha': '2017-09-19 19:20:36',
#   'num_likes': 0},
#  {'index': 96,
#   'usuario_id': 'iyhqoE49PTX2VNITzpDw6w',
#   'negocio_id': '-UWSsdJMRYU7L2UpyusyMg',
#   'texto': 'They not only checked my tire for nails, but they checked everything else, including my battery.',
#   'fecha': '2012-01-03 18:09:12',
#   'num_likes': 0},
#  {'index': 97,
#   'usuario_id': 'PuCMCx8LvgUWgZhnt2PHJg',
#   'negocio_id': 'X-b4-QvZLENnf3yFwhpSXQ',
#   'texto': 'Sundays are so much fun for those of you with young kiddos. Stop by to find out why...',
#   'fecha': '2014-06-07 20:30:18',
#   'num_likes': 0},
#  {'index': 98,
#   'usuario_id': '_5uUOcTyKK1pQYwAL-Xrnw',
#   'negocio_id': '6qDRqHWqf0EeHupSUEBfKg',
#   'texto': 'Not open on Sunday. Great BBQ place and is worth the drive for those in surrounding areas.',
#   'fecha': '2014-08-25 18:23:14',
#   'num_likes': 0},
#  {'index': 99,
#   'usuario_id': 'X0dnuT43dT-EyKOGgwN04w',
#   'negocio_id': 'XsSgv3vBOyOBXn3Co8EVIg',
#   'texto': 'love it missingit',
#   'fecha': '2015-02-05 08:32:25',
#   'num_likes': 0},
#  {'index': 100,
#   'usuario_id': 'Rep7MccZrj-iHLS_hBHr1A',
#   'negocio_id': 'LsyW2kRAP0HYYP0Qov4Kng',
#   'texto': 'Free naan if you stay and eat',
#   'fecha': '2014-09-12 22:30:50',
#   'num_likes': 0},
#  {'index': 101,
#   'usuario_id': 'BceBAi4nnMWiUsKALGMg3A',
#   'negocio_id': 'mdUnUYQoXTouoziuLzaR0g',
#   'texto': "Ask for Sharon if you're getting a pedicure!",
#   'fecha': '2012-03-21 12:43:01',
#   'num_likes': 0},
#  {'index': 102,
#   'usuario_id': 'qPganFH_fTXrP9r3kXf6YQ',
#   'negocio_id': 'R9cM1tmBkQ03lnbE_a-U4Q',
#   'texto': 'Fast service. Cute staff. Great value.',
#   'fecha': '2016-12-09 17:51:53',
#   'num_likes': 0},
#  {'index': 103,
#   'usuario_id': 'k2boyvGyjpQ2PhWVCNM3CQ',
#   'negocio_id': 'dSEpkUP_RuR5gG_LhJ_INA',
#   'texto': 'Well lit for a nice evening walk',
#   'fecha': '2012-03-23 05:50:31',
#   'num_likes': 0},
#  {'index': 104,
#   'usuario_id': 'ouk36OGbx25nO23b10L5jw',
#   'negocio_id': 'THO77IL6DLob9Agt9QCjsw',
#   'texto': 'Still going to Anna! Schedule online!',
#   'fecha': '2018-03-22 04:56:17',
#   'num_likes': 0},
#  {'index': 105,
#   'usuario_id': '0uo7LHVMFaDf1PkcGZprNg',
#   'negocio_id': 'DC7IRSzdW-B3fkGgxFlmrA',
#   'texto': 'Great place for big dogs!  Lots of grass, doggie bags and water buckets placed about.  Love it here!',
#   'fecha': '2013-05-21 02:01:39',
#   'num_likes': 1},
#  {'index': 106,
#   'usuario_id': '6hz5iTb9afLU6HeTK7QnpQ',
#   'negocio_id': 'aozJXsHFqdK3Do09lEgMHA',
#   'texto': 'Start your night here and get the long island iced tea.',
#   'fecha': '2012-05-19 05:13:35',
#   'num_likes': 0},
#  {'index': 107,
#   'usuario_id': '3AhjaQkZABGmc0H_FrjJag',
#   'negocio_id': 'Ja_XdjkV1Tt3satbUUKjYQ',
#   'texto': 'Super nice staff! Love this place',
#   'fecha': '2013-09-06 00:11:46',
#   'num_likes': 0},
#  {'index': 108,
#   'usuario_id': '6ZC-0LfOAGwaFc5XPke74w',
#   'negocio_id': 'llZrbubcGWC-kXShnJLyQg',
#   'texto': 'Ice ice for me: )',
#   'fecha': '2013-02-05 01:51:37',
#   'num_likes': 0},
#  {'index': 109,
#   'usuario_id': 'rsmGwZ6MhctENKxxYwk4sg',
#   'negocio_id': 'cw8oFCL0BxCQCwwAr8DOOw',
#   'texto': "Rib tip dinner starving with yams and mac n cheese can't go wrong",
#   'fecha': '2012-04-05 00:47:49',
#   'num_likes': 0},
#  {'index': 110,
#   'usuario_id': 'A69QAmKSdW45kUIqd4FESg',
#   'negocio_id': '0NoHJtug9xefI2OnsANaMA',
#   'texto': 'Everything on the menu is fabulous! Never had a bad meal. Try the chicken enchiladas or rotisserie chicken salad.',
#   'fecha': '2012-11-02 02:23:20',
#   'num_likes': 0},
#  {'index': 111,
#   'usuario_id': '6ZC-0LfOAGwaFc5XPke74w',
#   'negocio_id': 'WHdmQ-zPYYTJUqaUOfNpkQ',
#   'texto': 'Very good very different!',
#   'fecha': '2012-10-20 18:50:13',
#   'num_likes': 0},
#  {'index': 112,
#   'usuario_id': 'XAja3Ed6Fa_lwZl_7tb9aw',
#   'negocio_id': '_esgtYSR_EFtDXTg8MXHgw',
#   'texto': 'No food here but they let u get delivery if you get hungry :)',
#   'fecha': '2014-09-18 01:44:45',
#   'num_likes': 0},
#  {'index': 113,
#   'usuario_id': 'MMxRLgkd-MgwowmggmR2Dg',
#   'negocio_id': '5xdKUuu4DbJ71KGbwRXfFg',
#   'texto': 'Hours had changed.  Check before coming.',
#   'fecha': '2017-09-08 05:19:29',
#   'num_likes': 0},
#  {'index': 114,
#   'usuario_id': 'dt9IHwfuZs9D9LOH7gjNew',
#   'negocio_id': 'UoRSHohdGuzfrpydZ9j0Lg',
#   'texto': '99 cent tacos on Tuesday. $2 enchilada Wednesday. Tortas on Thursdays for $4 I believe.',
#   'fecha': '2014-03-28 18:19:15',
#   'num_likes': 0},
#  {'index': 115,
#   'usuario_id': 'J7MsJKJDSA5OGo2-Hn7MbA',
#   'negocio_id': 'Q5sn7sP6v_lk3pxn0xVIlA',
#   'texto': 'Share fries! They give you a ton of fries then come around asking if you want more. GEEZE!',
#   'fecha': '2012-10-06 04:08:58',
#   'num_likes': 1},
#  {'index': 116,
#   'usuario_id': 'udpfGxriuoBdWRBdplJl-w',
#   'negocio_id': 'jobP3ywRd3QNZ_GCoPG2DQ',
#   'texto': 'Finally watching transformers 3d imax.',
#   'fecha': '2011-07-13 02:37:57',
#   'num_likes': 0},
#  {'index': 117,
#   'usuario_id': 'bzU8Cl6B9nqV1i5NReobvw',
#   'negocio_id': 'UUMAhgIAd0SPhsPV1RRFfQ',
#   'texto': "New vanilla flavor is pretty good; was skeptical at first because I've been using original for last 3 years. Good price at $24.99",
#   'fecha': '2013-08-30 17:30:28',
#   'num_likes': 0},
#  {'index': 118,
#   'usuario_id': 'wxeTtPILiMl1L-yBB-D2HA',
#   'negocio_id': 'P6iQA0bfU4USuzchR5wnKw',
#   'texto': "It's workout/pigout day!",
#   'fecha': '2012-05-22 17:32:01',
#   'num_likes': 0},
#  {'index': 119,
#   'usuario_id': 'qoS4nIc5MlfF_j8DkYHBgw',
#   'negocio_id': 'NQipNgmqouT2eJ7VtYm3_w',
#   'texto': 'Apparently reopening in December as "Sunrise Kosher Foods"',
#   'fecha': '2016-11-18 21:16:52',
#   'num_likes': 0},
#  {'index': 120,
#   'usuario_id': 'gwmyGLz4eBm9QiBU_Ze2KQ',
#   'negocio_id': 'RJOFGZZf3ho04ku0fcFRdA',
#   'texto': 'Some of the dishes lack flavour so definitely add some of the spices at the table! Still delicious overall',
#   'fecha': '2018-03-29 23:01:23',
#   'num_likes': 0},
#  {'index': 121,
#   'usuario_id': '94MGddLz0pj-Ob9m657Wuw',
#   'negocio_id': 'HiHfwu0c1k8m8aEJ9VwAQQ',
#   'texto': 'Best Portuguese chicken in town!',
#   'fecha': '2012-03-15 23:56:59',
#   'num_likes': 0},
#  {'index': 122,
#   'usuario_id': 'XWBlluAw866xtkrljou8sA',
#   'negocio_id': 'rn2uglsCXkHq5eWppZkjGQ',
#   'texto': 'A tad expensive',
#   'fecha': '2010-04-22 17:23:45',
#   'num_likes': 0},
#  {'index': 123,
#   'usuario_id': 'bxBR0vakC_OAU-5rCYCDsw',
#   'negocio_id': 'btQ1XQgCcRudMyJUUGvHKg',
#   'texto': 'Never going back here after the way the larger lady bartender acted.',
#   'fecha': '2012-10-08 03:34:05',
#   'num_likes': 0},
#  {'index': 124,
#   'usuario_id': 'AStTppA8-jqhDxF2kajwaw',
#   'negocio_id': 'WSVLZy-A3sznGSWyjnDbmg',
#   'texto': "it's a bar in ndg.",
#   'fecha': '2015-05-16 04:58:01',
#   'num_likes': 0},
#  {'index': 125,
#   'usuario_id': 'TnhTyk1qfJ8jL2bHpeTrhQ',
#   'negocio_id': 'FaHADZARwnY4yvlvpnsfGA',
#   'texto': "Just park in the lot at pickup and pay the $2.  It's not worth the hassle to drive through over and over. Plus, you get brownie points from whoever you pick up for meeting them in the terminal.",
#   'fecha': '2013-12-03 03:32:31',
#   'num_likes': 1},
#  {'index': 126,
#   'usuario_id': '93z51tzHUp4ycmC45puYRg',
#   'negocio_id': 'h6Y1-KfN2XBkcrV85CS8yg',
#   'texto': 'Seats were good. Food was ok. Decent drinks. Better than a regular movie.',
#   'fecha': '2014-08-29 15:14:09',
#   'num_likes': 0},
#  {'index': 127,
#   'usuario_id': 'E3OfYM72qgnzJKRmAW0Fdw',
#   'negocio_id': 'oj8qk3W7O9oq15VIs-vYJQ',
#   'texto': "Eat at the bar. It's awesome.",
#   'fecha': '2015-09-21 02:52:09',
#   'num_likes': 0},
#  {'index': 128,
#   'usuario_id': '81pTE_HsEauWEMSZVQElbQ',
#   'negocio_id': 'zidkKI_N1OPxsiddTOQH_Q',
#   'texto': 'Tasty & quick friendly service.',
#   'fecha': '2017-09-25 20:18:13',
#   'num_likes': 0},
#  {'index': 129,
#   'usuario_id': '1GCZfavvSEdqWhrcJQC-kA',
#   'negocio_id': 'YBLVD61RFdP5H-RGLSIPUw',
#   'texto': 'Nights are so busy! I prefer early mornings!',
#   'fecha': '2012-10-16 00:23:56',
#   'num_likes': 0},
#  {'index': 130,
#   'usuario_id': '-oHBgKNC6xGHIGdoZW3ReQ',
#   'negocio_id': 'J07TDs6qnTIaxm48EL1cKQ',
#   'texto': 'Bloody Mary is a bit too sweet, but has an ok bite.',
#   'fecha': '2010-05-09 20:33:01',
#   'num_likes': 0},
#  {'index': 131,
#   'usuario_id': 'I003WaxhVyk6rX7zmaZ-Sw',
#   'negocio_id': 'WtsxMPURczWQY7y6cNUy8Q',
#   'texto': 'The Green Goddess Sandwich is amazing along with their Raw tacos in cabbage leaf shells. The place is very peaceful full of friendly and helpful people it really does have a spiritual vibe I can explain. Plus you can find any herb or supplement in existence.',
#   'fecha': '2014-06-03 20:22:36',
#   'num_likes': 0},
#  {'index': 132,
#   'usuario_id': 'mRMoX1irrRhkd4w6na4dqg',
#   'negocio_id': 'VlDTUr3y-bdVZDKXEILKfQ',
#   'texto': 'Still one of our favorite local places to go!',
#   'fecha': '2016-01-02 00:41:17',
#   'num_likes': 0},
#  {'index': 133,
#   'usuario_id': 'V3EJsWicBRxIn0fs85THlw',
#   'negocio_id': '-hn7E7b3VwRjwhNEDgmGIQ',
#   'texto': "We've found a new breakfast spot! Corned beef hash was awesome as were the eggs and French Toast! Hubby got country fried steak and said it was very good too. Good, fast service as well.",
#   'fecha': '2012-10-26 16:44:44',
#   'num_likes': 0},
#  {'index': 134,
#   'usuario_id': 'gqpnDoFx42U5NdtejYfKOg',
#   'negocio_id': 'gO_z_5FQVHLCiJjOsfE1fg',
#   'texto': 'You can buy there different meats by the ounce, three ounce min!',
#   'fecha': '2012-10-23 02:57:06',
#   'num_likes': 0},
#  {'index': 135,
#   'usuario_id': 'EnkN58MPWLAydD1Q8d1LZQ',
#   'negocio_id': 'ugLqbAvBdRDc-gS4hpslXw',
#   'texto': 'Sushi does not mean "raw fish," but "vinegar[ed] rice."',
#   'fecha': '2013-02-07 02:28:43',
#   'num_likes': 0},
#  {'index': 136,
#   'usuario_id': '1BWCs7aXDg-EiLmv-U3qtw',
#   'negocio_id': '6OkjUz-I552moryf3qN1Gg',
#   'texto': 'The food is great the service to...the atmosphere is jumping',
#   'fecha': '2015-02-01 00:22:06',
#   'num_likes': 0},
#  {'index': 137,
#   'usuario_id': 'jtM-lajwSwW65wJRaMuFxg',
#   'negocio_id': 'piGQNN6ECbSC0agHhvoVeg',
#   'texto': 'LUXY Design!!  3 weeks still in perfect condition !!',
#   'fecha': '2013-05-22 00:16:38',
#   'num_likes': 0},
#  {'index': 138,
#   'usuario_id': 'uG35h72BAMutvXAWdRpqCQ',
#   'negocio_id': '0ldxjei8v4q95fApIei3Lg',
#   'texto': 'Ask for the biscuits and butter when you sit down.',
#   'fecha': '2012-01-11 20:14:32',
#   'num_likes': 0},
#  {'index': 139,
#   'usuario_id': 'mo-Xf9kSLvv9Qz8YGZRfqw',
#   'negocio_id': 'R3B_ibZvlrgzch_UkYQkrg',
#   'texto': "Horribly slow!!!!!!!!!!! It's just ridiculous how slow they are",
#   'fecha': '2016-07-30 06:47:46',
#   'num_likes': 0},
#  {'index': 140,
#   'usuario_id': 'FahXU1Sh3otKR9AR4qsqPg',
#   'negocio_id': 'NlNqsImMrzaZlE0xyo5XWA',
#   'texto': 'No cellphone service. At least not on a Verizon phone.',
#   'fecha': '2015-09-14 16:07:35',
#   'num_likes': 0},
#  {'index': 141,
#   'usuario_id': '_cLzb8A4lhYT9QcgcsJuVQ',
#   'negocio_id': 'SMPbvZLSMMb7KU76YNYMGg',
#   'texto': 'Don\'t bother with mobile check in. They "lost" our check in. We waited hours to hear if our room was ready, finally called, and they had given away the last king deluxe room even though we\'d made reservations months in advance.',
#   'fecha': '2016-10-10 04:42:54',
#   'num_likes': 0},
#  {'index': 142,
#   'usuario_id': 'N-pi-twvDI08ubRth9q0kw',
#   'negocio_id': '1jMtot685bxNT7oeSTNCaA',
#   'texto': 'Have tons of salvaged old wood moulding and stair case railings etc.',
#   'fecha': '2013-08-20 20:21:00',
#   'num_likes': 0},
#  {'index': 143,
#   'usuario_id': 'o6__ZWGttmlxG87FuHcF0w',
#   'negocio_id': 'F6Xyqyoi_RCTc3mf00ip2Q',
#   'texto': 'Call in your order for take out!',
#   'fecha': '2013-02-13 20:18:43',
#   'num_likes': 0},
#  {'index': 144,
#   'usuario_id': '9bcFzhy96znoZGpZnjChJw',
#   'negocio_id': '336_K7i9-jrEhvQleGUVQw',
#   'texto': 'Lunch service daily. No parking in front lot (all reserved)',
#   'fecha': '2012-05-25 01:18:05',
#   'num_likes': 0},
#  {'index': 145,
#   'usuario_id': 'T1jicY-vxpCOTl5SIdVLxg',
#   'negocio_id': '8LYul-0GwtmoYOoXX1fpwg',
#   'texto': 'Another bridesmaid dress fixed up! Thanks Valentina!',
#   'fecha': '2012-03-15 01:00:00',
#   'num_likes': 0},
#  {'index': 146,
#   'usuario_id': 'HuWEj615KvxRmjJq8JY7Ng',
#   'negocio_id': 'e9ReYEygFmRszaWKP9ndFg',
#   'texto': 'crazy busy location- chaotic and messy',
#   'fecha': '2012-10-25 06:08:57',
#   'num_likes': 0},
#  {'index': 147,
#   'usuario_id': 'a48HhwcmjFLApZhiax41IA',
#   'negocio_id': 'bcJmbFHVAkLFqhJbUTdbyQ',
#   'texto': "It's a crown bakery pastry kind of day ;)",
#   'fecha': '2012-03-16 22:56:08',
#   'num_likes': 0},
#  {'index': 148,
#   'usuario_id': 'iGG25CqWNpXbbACz7mbi7Q',
#   'negocio_id': 'f79mtjCKvrBtd5aEtaMTYQ',
#   'texto': 'Be sure to ask for dressing on the side. Got a side salad and it was drenched. The grilled chicken sandwich has a lot of grilled chicken. The canned Muzak is heinous. I mean 70\'s easy rock like "the rose" and Neil Diamond.',
#   'fecha': '2013-08-26 20:18:45',
#   'num_likes': 0},
#  {'index': 149,
#   'usuario_id': 'LNeUIkubMxRZxvOmzzg2tg',
#   'negocio_id': 'wZukjLaf1V2dLRQap_Zriw',
#   'texto': 'Parking can be tough, carpooling is advisable.',
#   'fecha': '2012-03-17 23:17:16',
#   'num_likes': 0},
#  {'index': 150,
#   'usuario_id': 'yHMNrMBSvzw_fxBAyPCo_A',
#   'negocio_id': 'zQlaDJqp3c_HAuYP5Ukk3w',
#   'texto': 'They open on Sundays even though it said they close on Sunday on Yelp. So call and double check before you go.',
#   'fecha': '2015-01-12 02:44:00',
#   'num_likes': 0},
#  {'index': 151,
#   'usuario_id': '0qMik3XhkXYENJ60500vtw',
#   'negocio_id': '-kWzbYfMA68JjV2M5os2FA',
#   'texto': 'Clean',
#   'fecha': '2013-02-03 01:49:47',
#   'num_likes': 0},
#  {'index': 152,
#   'usuario_id': 'GxkY7BqazkQu6I9HBDpbqQ',
#   'negocio_id': 't_yiQnxUDdPPCN2z4QyezA',
#   'texto': 'Yum!',
#   'fecha': '2010-12-11 02:32:13',
#   'num_likes': 0},
#  {'index': 153,
#   'usuario_id': 'Fuekh1vNrATMHlE5k2NFMg',
#   'negocio_id': 'uW6UHfONAmm8QttPkbMewQ',
#   'texto': "Don't eat musubis that have been sitting in the heat box on the counter unless they are made fresh. It was gray and spoiled already when they sold it to us.",
#   'fecha': '2017-07-12 21:29:29',
#   'num_likes': 0},
#  {'index': 154,
#   'usuario_id': 'bP1-iaqAuy4tEoviQaxJrA',
#   'negocio_id': 'sfzX4Ndds39mhS-Chr2lJw',
#   'texto': 'Thursday Draft Beer night $1 per glass, Friday and Saturday night an italian singer with keyboardust 7-10pm.',
#   'fecha': '2011-07-14 18:52:31',
#   'num_likes': 0},
#  {'index': 155,
#   'usuario_id': 'MbKSGBDhCrp-q_tzSkSENg',
#   'negocio_id': 'pomGBqfbxcqPv14c3XH-ZQ',
#   'texto': 'Our server, Earl, was very nice and helped us with some tasty recommendations!',
#   'fecha': '2012-10-19 22:38:47',
#   'num_likes': 0},
#  {'index': 156,
#   'usuario_id': 'zb7LquEgFXh6aKaXAALMqw',
#   'negocio_id': 'P8IsTiHq5Hesa6UPL604ww',
#   'texto': 'Closed for remodel until 1/28/2015',
#   'fecha': '2015-01-18 03:41:49',
#   'num_likes': 0},
#  {'index': 157,
#   'usuario_id': 'VVZyTpk6r4frT1LwlgddEg',
#   'negocio_id': 'kWyx--E6xf-R9Y-_pZ6WvQ',
#   'texto': 'My first official band practice.',
#   'fecha': '2011-10-19 03:22:48',
#   'num_likes': 0},
#  {'index': 158,
#   'usuario_id': 'F2IbnY4CpTfSxQijPtDKKg',
#   'negocio_id': 'SvHAczHxIJ00QlJ9ovQR8g',
#   'texto': 'This place is small, little windy tonight',
#   'fecha': '2011-04-24 08:05:01',
#   'num_likes': 0},
#  {'index': 159,
#   'usuario_id': 'QDvX9KJ53kt3O7M3k43Iew',
#   'negocio_id': 'VHZPbCbIPHEkKOotdCTiow',
#   'texto': 'Better than kuma. X10',
#   'fecha': '2014-03-16 01:40:23',
#   'num_likes': 0},
#  {'index': 160,
#   'usuario_id': 'P4ULVoqkCvHbJSv3_YKmuA',
#   'negocio_id': 'NF6di6YcQxN0rDAleE7SyQ',
#   'texto': 'Great specials. The creamy chicken soup is cornstarch based similar to hot and sour soups. Very good.',
#   'fecha': '2013-05-26 01:00:50',
#   'num_likes': 0},
#  {'index': 161,
#   'usuario_id': 'ucj0RT3ZsWHFXQssLq-wmQ',
#   'negocio_id': 'VcYpdJIoDgwBOdIJ_IvadA',
#   'texto': 'Van Gogh vroom vroom in my belly',
#   'fecha': '2012-05-25 20:37:20',
#   'num_likes': 0},
#  {'index': 162,
#   'usuario_id': '0V44Yx8pIOt_acaWixmW2Q',
#   'negocio_id': 'lznasLryfYdfXZXni-1XMA',
#   'texto': 'Fan',
#   'fecha': '2014-06-06 19:41:28',
#   'num_likes': 0},
#  {'index': 163,
#   'usuario_id': '8Az_JgEpXqAii_5EDkw2tw',
#   'negocio_id': '5Z-vw4_w-I1Z9XcbCkmCfA',
#   'texto': 'The cardio cinema is the best.. especially for those of you (like myself) who get bored easily while running or biking',
#   'fecha': '2014-03-31 15:12:39',
#   'num_likes': 0},
#  {'index': 164,
#   'usuario_id': 'S9Jw00eZHVj5_0sOM_C5Rg',
#   'negocio_id': 'WCUuQMK_W4hMU9dQWjCl0Q',
#   'texto': 'Avicii',
#   'fecha': '2012-01-16 04:03:40',
#   'num_likes': 0},
#  {'index': 165,
#   'usuario_id': 'YTxLorIFxbeBs5hJ2PvL9A',
#   'negocio_id': 'mDoLWEOFmxcQ5TAPqxoJLg',
#   'texto': "Another great meal at sago's but they still need to get some better horseradish!!",
#   'fecha': '2014-08-26 02:17:09',
#   'num_likes': 0},
#  {'index': 166,
#   'usuario_id': 'ewDNa_FRoG71UFm56eTGkw',
#   'negocio_id': 'iPM8BXV6vEVEci8ttsOObQ',
#   'texto': 'Need that bun bo hue hangover remedy, this has one of the tastiest...',
#   'fecha': '2012-05-20 22:23:30',
#   'num_likes': 0},
#  {'index': 167,
#   'usuario_id': '0tC5OOTuwvPGnnqhPCoRSw',
#   'negocio_id': '6xa3wKq9YyWe8joXvkVEUg',
#   'texto': 'Now 40% off!',
#   'fecha': '2016-11-22 00:31:40',
#   'num_likes': 0},
#  {'index': 168,
#   'usuario_id': 'ssOBsZudD7FXDrBfH4cvbw',
#   'negocio_id': 'D4BWyStFZzA7k8hqDmnyFw',
#   'texto': 'Food tasty and abundant. 7 side salads also tasty and fresh. Clean bathrooms.',
#   'fecha': '2017-06-14 20:55:03',
#   'num_likes': 0},
#  {'index': 169,
#   'usuario_id': '1PesLMAdY2soq2zD_3rAYw',
#   'negocio_id': 'as28EZmkxBoBymBMAkVQPw',
#   'texto': 'The hookah lounge in the back. Is HUGE!!!',
#   'fecha': '2014-06-08 19:16:44',
#   'num_likes': 0},
#  {'index': 170,
#   'usuario_id': 'x-3i0RMyuLRi8-7Xfc1KPA',
#   'negocio_id': 'HYY80G3XmJWine6IhHSkhg',
#   'texto': 'Trying this again with the kids, watching zoo keeper. The remodel was the best thing this place has done.1$ movie on tues.oh happy day :-)',
#   'fecha': '2011-10-04 21:30:04',
#   'num_likes': 0},
#  {'index': 171,
#   'usuario_id': 'sB9W6Tbr1A-ERfUXwJxirQ',
#   'negocio_id': '0bbFFcNhBSi0-z_JZhevwA',
#   'texto': 'First and third Tuesday of every month :)',
#   'fecha': '2013-02-20 03:56:08',
#   'num_likes': 1},
#  {'index': 172,
#   'usuario_id': '8ZryN_S-n48g6rsa3W3QtQ',
#   'negocio_id': 'FaHADZARwnY4yvlvpnsfGA',
#   'texto': 'Major construction going on avoid this shit hole',
#   'fecha': '2016-07-29 17:42:12',
#   'num_likes': 1},
#  {'index': 173,
#   'usuario_id': 'PweT8hEJbciB6CxTS1IDNA',
#   'negocio_id': 'RESDUcs7fIiihp38-d6_6g',
#   'texto': "Don't come here it's too expensive for the variety & price!",
#   'fecha': '2014-03-14 03:45:42',
#   'num_likes': 0},
#  {'index': 174,
#   'usuario_id': 'tcw41NjSGJ0Wgl_EdbcXBQ',
#   'negocio_id': 'orMyWvonOj55yswWf-k72Q',
#   'texto': 'Late nights are best for quick service and patio table',
#   'fecha': '2017-10-25 06:29:33',
#   'num_likes': 0},
#  {'index': 175,
#   'usuario_id': 'J1eLG-wXf4D_vcUhGvq2ZA',
#   'negocio_id': '1cGyzWtfOoDiE8V0OR85yA',
#   'texto': "Bring cash, they don't take cards.",
#   'fecha': '2014-04-06 19:24:11',
#   'num_likes': 0},
#  {'index': 176,
#   'usuario_id': 'lwPhlWLdDmxKB-xG_VOLeg',
#   'negocio_id': 'zQi4U-pJlJcztIW4G_HgUw',
#   'texto': 'They just received a new',
#   'fecha': '2010-12-09 21:34:48',
#   'num_likes': 0},
#  {'index': 177,
#   'usuario_id': 'HjcX1Sl1maE43zER1v9MPg',
#   'negocio_id': 'lsAe6PMRTVGtaBqw3zKlMQ',
#   'texto': 'Long lines, not very helpful. Nobody really wants to help you',
#   'fecha': '2014-03-16 16:18:08',
#   'num_likes': 0},
#  {'index': 178,
#   'usuario_id': 'WOOWamjSmE287IXliWvfVg',
#   'negocio_id': 'pOhX1XjbBdPoO2Fyy8RGJg',
#   'texto': "Doesn't sound good to get shrimp on your pizza, but it is *sooooooooooooo good!* \n\nBring Cash!",
#   'fecha': '2015-02-03 12:59:47',
#   'num_likes': 0},
#  {'index': 179,
#   'usuario_id': 's5F0viIdrelfeDtcMM65PQ',
#   'negocio_id': '6FGfOWph7YG1JUGl7B7ooA',
#   'texto': 'Today is the opening day! 1/20/15',
#   'fecha': '2015-01-20 22:23:05',
#   'num_likes': 0},
#  {'index': 180,
#   'usuario_id': 'KFZISl5mOUJ6bu3qCUrO-g',
#   'negocio_id': 'wWuGa3OOQJro_XGe-GKBXA',
#   'texto': 'Fantastic sushi experience sitting at the bar. Nigiri omakase a great deal, but if you want more it quickly adds up. Favorites were the medium/premium fatty tuna (toro) and uni.',
#   'fecha': '2013-05-12 06:04:45',
#   'num_likes': 0},
#  {'index': 181,
#   'usuario_id': '4GtSjibzgxOy3Gb9cRtKzA',
#   'negocio_id': 'g3g3dWFoVSYhXQTs4ctGyg',
#   'texto': 'Berry long island w/ gummy bear garnish :)',
#   'fecha': '2011-04-10 06:57:04',
#   'num_likes': 0},
#  {'index': 182,
#   'usuario_id': 'uufubBI9EcKwFW7x_o9j8w',
#   'negocio_id': 'vrFWQ7CDULCP87oTNC5sxA',
#   'texto': 'Well deserved carb cheat. Fuck yes. I will be scarfing pizza in full on Taz mode.',
#   'fecha': '2011-04-06 23:28:45',
#   'num_likes': 0},
#  {'index': 183,
#   'usuario_id': '1KbE1qHhVHIdDucYGtfaJA',
#   'negocio_id': 'CJ9ZY_b8WHDygndmq1g4zQ',
#   'texto': 'Still no word back from them!! Wow great customer service.',
#   'fecha': '2016-07-28 16:10:53',
#   'num_likes': 0},
#  {'index': 184,
#   'usuario_id': 'YORJi2JtQg5Mo4nmKOXzag',
#   'negocio_id': 'D42-sxkmZy2fn4BkZaEkbA',
#   'texto': 'Veggie no special sauce with fries as meat - V E G A N!!!',
#   'fecha': '2010-03-17 07:19:02',
#   'num_likes': 0},
#  {'index': 185,
#   'usuario_id': 'QQtoHnP0cP7nzNnUob_1CQ',
#   'negocio_id': 'kwMJ4KfhEcrk9jiMe-S6wQ',
#   'texto': 'Terrific little restaurant with wood fired pizza, gelato.  I really like the salad and antipasti.',
#   'fecha': '2012-05-22 00:03:41',
#   'num_likes': 0},
#  {'index': 186,
#   'usuario_id': 'nGoKau64-PtetuzfcRW3jA',
#   'negocio_id': 'gek4ySiFtQX53g_AqdONDQ',
#   'texto': 'This place is open for breakfast on the weekends even though the yelp page says its closed. Nice relaxed atmosphere pleasant service this morning.',
#   'fecha': '2012-10-14 16:15:31',
#   'num_likes': 0},
#  {'index': 187,
#   'usuario_id': 'RTtdsBlyFcpeKI8MMD-A3Q',
#   'negocio_id': 'rTZVcJZ8G80i6NjLw0SW8Q',
#   'texto': 'Lots of private areas that are accessible to the general public, like this cozy room to watch NCAA basketball in.',
#   'fecha': '2014-03-22 20:39:47',
#   'num_likes': 0},
#  {'index': 188,
#   'usuario_id': 'oJ0DxrOvW5EhclB57WhdZw',
#   'negocio_id': '82A4J-aOSxTUpuaSV2WVfg',
#   'texto': 'Great selection. Friendly and helpful staff!',
#   'fecha': '2015-09-05 01:38:25',
#   'num_likes': 0},
#  {'index': 189,
#   'usuario_id': 'D-ZyQ4iT1XRFkcOAWXnxCQ',
#   'negocio_id': '19umlhmVB9O3njIBfRAe8g',
#   'texto': 'Drinks galore for Latin Night',
#   'fecha': '2011-07-23 09:20:46',
#   'num_likes': 0},
#  {'index': 190,
#   'usuario_id': 'D2ljL5ejuqpa4f8fnZ1qjw',
#   'negocio_id': 'pt7p4klGicvPZe04mhhVGQ',
#   'texto': 'Baked ziti. Hands down the bestttt!',
#   'fecha': '2014-03-30 03:04:25',
#   'num_likes': 0},
#  {'index': 191,
#   'usuario_id': 'j_j4DLfvNkhCRNWC0VBS9g',
#   'negocio_id': 'tT0rnI7TTbkcazKyehfutw',
#   'texto': 'Business owner contacted me via yelp 2 weeks ago asking me for my contact info in regards to my recent visit.  Then... No call was received and no follow up email....OK.',
#   'fecha': '2016-07-30 13:54:46',
#   'num_likes': 0},
#  {'index': 192,
#   'usuario_id': 'ix5OWpO3BeHW_Nkg0J-iyg',
#   'negocio_id': 'HsrEbWCg8K06pUhx469uSw',
#   'texto': 'Cruellers on the Weekends',
#   'fecha': '2014-03-29 06:54:43',
#   'num_likes': 0},
#  {'index': 193,
#   'usuario_id': 'h0wxG2EiDLhgKjIzI8j2Mg',
#   'negocio_id': 'DkZuVzYuylBanEsWK7mNGw',
#   'texto': "Chef Eric's Omakase tonght!  Thanks for preparing all the fresh dishes for my Yelp friends :-)",
#   'fecha': '2012-07-29 02:25:59',
#   'num_likes': 0},
#  {'index': 194,
#   'usuario_id': 'uLVIhe4rW-s81ey5qL7Geg',
#   'negocio_id': 'q1EJ1BT_xoorCoWarXiwuw',
#   'texto': 'Dont do valet they suck slower then shit and ran by retarded hippy piece of shit',
#   'fecha': '2012-07-22 04:39:17',
#   'num_likes': 0},
#  {'index': 195,
#   'usuario_id': 'A5A34ixb-yy6nwL42iZsnw',
#   'negocio_id': 'OiqDNSdnchr8zQhiMSInLQ',
#   'texto': "Best soba noodles in town! Definitely come in if you like soba noodles or haven't tried FRESH soba noodles cooked perfectly al dente before.",
#   'fecha': '2015-02-07 07:22:13',
#   'num_likes': 0},
#  {'index': 196,
#   'usuario_id': 'oknzpMgHOnbijayveG-PKQ',
#   'negocio_id': 'R05ZRXWkYuEcvRGok5fiDA',
#   'texto': '@ the car wash !',
#   'fecha': '2012-03-23 18:00:14',
#   'num_likes': 0},
#  {'index': 197,
#   'usuario_id': '2cJ8qo5kyqzDQSwWA9MDww',
#   'negocio_id': '7dKIMvsTQI6zO-NYdRmrwA',
#   'texto': 'Lunch with the boys!',
#   'fecha': '2011-07-28 18:33:41',
#   'num_likes': 0},
#  {'index': 198,
#   'usuario_id': 'CNaaizAUc2c4WIb1M3BBPw',
#   'negocio_id': 'QNM7f0i2lW8cuJDQmqF9QQ',
#   'texto': 'Downing some brewskis',
#   'fecha': '2012-03-21 04:37:31',
#   'num_likes': 0},
#  {'index': 199,
#   'usuario_id': '6ehZ3X1gaHe-fxzndNRweA',
#   'negocio_id': 'zEOfVGv6DeprEzmFYMFhXA',
#   'texto': 'Still the best salad ever (for a chain)...',
#   'fecha': '2012-10-13 00:50:04',
#   'num_likes': 0},
#  {'index': 200,
#   'usuario_id': 'cTABik0Qu7WrPTElRSYmjA',
#   'negocio_id': '70Bti9GmBOv9jN_peapD7w',
#   'texto': 'SF bound',
#   'fecha': '2011-05-05 21:04:13',
#   'num_likes': 0},
#  {'index': 201,
#   'usuario_id': '3m190IWHASheEZ-j9zOqCQ',
#   'negocio_id': 'atVh8viqTj-sqDJ35tAYVg',
#   'texto': 'Gotta love this place...',
#   'fecha': '2015-01-24 20:22:04',
#   'num_likes': 0},
#  {'index': 202,
#   'usuario_id': 'OueXAik2P-eUcXbd1qGXKw',
#   'negocio_id': 'UXFLCGw1yOCajlMONYQM1w',
#   'texto': "Basic buffet. Clean, good service. Don't bother with steak night (Thursdays) - so tough I couldn't eat any of it.",
#   'fecha': '2012-10-05 02:45:16',
#   'num_likes': 0},
#  {'index': 203,
#   'usuario_id': '4CWCIaZl-ceMmDuVLjDxUQ',
#   'negocio_id': 'rYq0k33eJxISVP1ufx6Kmw',
#   'texto': "Don't fear the bulldog",
#   'fecha': '2015-01-19 02:07:21',
#   'num_likes': 0},
#  {'index': 204,
#   'usuario_id': 'JoBJCE-ac2AOZW9GXevy6w',
#   'negocio_id': 'HhB7qcsrjNAVVRtbYEg5Pg',
#   'texto': "We've been here for 90 mins & still waiting...",
#   'fecha': '2016-04-20 02:07:30',
#   'num_likes': 0},
#  {'index': 205,
#   'usuario_id': 'fRboRtLxTHFORPVdtpOTsw',
#   'negocio_id': 'F-bdXFkJwwENiNpMTG2ntQ',
#   'texto': 'Nice spot. Popped in for lunch, good IPA and decent food. Notable for great and friendly service. Thanks !!',
#   'fecha': '2015-05-16 19:31:39',
#   'num_likes': 0},
#  {'index': 206,
#   'usuario_id': 'Ye80JpIGZEx1R1RrJLfkYg',
#   'negocio_id': 'Y6ERro4P_wmneOWj07n94A',
#   'texto': 'Great patio during summer. They have heated lamps for cold days.',
#   'fecha': '2013-05-30 23:24:35',
#   'num_likes': 0},
#  {'index': 207,
#   'usuario_id': 'r1n_0dI5JKPz9bRzWDEf6Q',
#   'negocio_id': 'fgpAYr-kAhXT6oB6lCC4qA',
# ...
#   'negocio_id': 'Ta4GRuHyZvU5H_l5IAG1PQ',
#   'texto': 'Buffet style ayce Filipino food $7.50 per person',
#   'fecha': '2011-05-07 22:28:30',
#   'num_likes': 0},
#  {'index': 930,
#   'usuario_id': 'dUkE4OCqGCig5xLK3oOFsA',
#   'negocio_id': 'cB-oem_jaove_3hLCII5-A',
#   'texto': 'Come early, drink loads of water. None of the BBQ blew me away.',
#   'fecha': '2012-05-19 21:06:45',
#   'num_likes': 0},
#  {'index': 931,
#   'usuario_id': 'CmPjoba7N2ZSa3goSsSN6Q',
#   'negocio_id': 'rTZVcJZ8G80i6NjLw0SW8Q',
#   'texto': 'Helping Simply Hawaiian set up their booth for Pure Aloha!!!! Happening this weekend October 6-9!',
#   'fecha': '2011-10-05 20:53:56',
#   'num_likes': 0},
#  {'index': 932,
#   'usuario_id': '-2gOxVWcnBr5DclrrsWXCA',
#   'negocio_id': 'Gen0ei06dGq13OJ8DRXUjg',
#   'texto': "Don't get to full on the fresh baked bread. Leave room for you pizza and their amazing Gelato.",
#   'fecha': '2013-06-24 02:36:29',
#   'num_likes': 0},
#  {'index': 933,
#   'usuario_id': 'jJKirx_OVZCFL-wHw43Y2w',
#   'negocio_id': 'JIETwXSEGIHMNyxZVEnNKQ',
#   'texto': 'Love!',
#   'fecha': '2015-01-14 18:04:08',
#   'num_likes': 0},
#  {'index': 934,
#   'usuario_id': '2LLO9HbhgUULhctJpFSqJg',
#   'negocio_id': 'lqCJiHlxzRpuYt-u_XQUvg',
#   'texto': 'They regularly screen old movies,  came and saw dazed and confused on 4/20 lol',
#   'fecha': '2016-04-21 01:53:28',
#   'num_likes': 0},
#  {'index': 935,
#   'usuario_id': 'yis0tDX83YnFLzUbKZ_KFg',
#   'negocio_id': 'VCxjKhb84T_pbQ7mqEYvLQ',
#   'texto': 'Clean, fresh, fully-stocked salad bar & 1/2 sandwich my favorite Managers Special.',
#   'fecha': '2012-10-12 04:09:14',
#   'num_likes': 0},
#  {'index': 936,
#   'usuario_id': '7sNE58P4AvsX6QHE8ypCiA',
#   'negocio_id': 'OC8Anu5Shh10TUUQegy8rQ',
#   'texto': 'Vintage gaming night! Rick the atari',
#   'fecha': '2011-07-22 03:12:47',
#   'num_likes': 0},
#  {'index': 937,
#   'usuario_id': '2gu5B_JbJlfZLhihSr-apQ',
#   'negocio_id': 'xiNJk32NYbXdL-T3PzE3lQ',
#   'texto': 'I have a few openings today!',
#   'fecha': '2012-03-20 16:32:28',
#   'num_likes': 0},
#  {'index': 938,
#   'usuario_id': 'BRkfT1_6dVouyUVfN4R-Pw',
#   'negocio_id': 'V9st1APIh04cP1WUfnvxmA',
#   'texto': "It's hot....damn hot!",
#   'fecha': '2012-07-21 22:29:54',
#   'num_likes': 0},
#  {'index': 939,
#   'usuario_id': 'UZgYI5HEamlQunGmejLltA',
#   'negocio_id': 'YNHvFEvp9VDNwX5VhRanYQ',
#   'texto': 'Nice looking place in a nice looking plaza.',
#   'fecha': '2011-12-25 01:00:13',
#   'num_likes': 0},
#  {'index': 940,
#   'usuario_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'negocio_id': 'd_L-rfS1vT3JMzgCUGtiow',
#   'texto': 'Sign up for their locals rewards card for discounts. Also sign up for their e-newsletter for discounts and coupon.',
#   'fecha': '2013-12-18 05:41:46',
#   'num_likes': 1},
#  {'index': 941,
#   'usuario_id': 'wAqiSluTMo_2T-dTN4Bozg',
#   'negocio_id': '6PwKC0dqP9uI85FEP86iPQ',
#   'texto': 'For some reason this maps wrong the address is right but it is at power and Ray rd',
#   'fecha': '2010-02-28 21:53:07',
#   'num_likes': 0},
#  {'index': 942,
#   'usuario_id': 'djP46l4v0TQTqhLa-ZB1xw',
#   'negocio_id': 'gDjHnPJDx9ZVse0i9mp5hQ',
#   'texto': 'Great Thai',
#   'fecha': '2014-09-01 22:21:42',
#   'num_likes': 0},
#  {'index': 943,
#   'usuario_id': 'd9a0JCq3VAFceiiv3jH_CA',
#   'negocio_id': '-d8gt_XhhUQh2CxlWJe-xw',
#   'texto': 'Love this place!!! Food is amazing. Lobster Mac & Cheese to die for!!!!',
#   'fecha': '2012-10-11 23:17:05',
#   'num_likes': 0},
#  {'index': 944,
#   'usuario_id': 'B423jsaQkyodGbGyiIGLXA',
#   'negocio_id': 'dJnF_GUWdoX3tUucpKbYMg',
#   'texto': 'Shit service. Made dinner reservations but 15 mins in and still not seated! In fact, they let in another group who came after us and took our table! Extremely embarrassing and disappointed to have brought relatives here. DO NOT GO HERE.',
#   'fecha': '2013-09-01 19:33:11',
#   'num_likes': 0},
#  {'index': 945,
#   'usuario_id': 'VCUCCGfjUFtN8PXDoqY-Xg',
#   'negocio_id': '6W3hdaCjx_n1kADEuORduA',
#   'texto': 'Was a great visit.  Good comfort food!',
#   'fecha': '2017-03-26 04:22:54',
#   'num_likes': 0},
#  {'index': 946,
#   'usuario_id': 'P2sQVHyHmy4WA0I7NI5hWg',
#   'negocio_id': 'NpgOB1s1qnWBfVykqe5zpQ',
#   'texto': 'Quiet, idyllic adult pool with dazzling views of the mountains behind the busy main family pool. Sit in a cabana, order from ROQ, and enjoy!',
#   'fecha': '2010-04-03 23:03:37',
#   'num_likes': 0},
#  {'index': 947,
#   'usuario_id': 'q9jCDNZDRUYl2Pwlgxocig',
#   'negocio_id': 'sUXs9ATmb423TcxgtMalzQ',
#   'texto': 'Picking up some pad Thai & papaya salad. Craving spicy!!',
#   'fecha': '2012-07-30 02:24:08',
#   'num_likes': 0},
#  {'index': 948,
#   'usuario_id': 'mD5_v03iY_sFK2B3Wc0hSA',
#   'negocio_id': 'aPwWn5KBNMOEYjlYwXRORw',
#   'texto': "They have a nice little patio that's full of sun at midday. Great for a pint of beer and some fish tacos!",
#   'fecha': '2015-06-07 16:05:03',
#   'num_likes': 0},
#  {'index': 949,
#   'usuario_id': '65SEHUlVAaRs-y82IJHcAg',
#   'negocio_id': 'X1twjafYxMCpKt2MqvY5Tw',
#   'texto': 'Great service, good price, nice size portions, and great home cooked food with lots of flavor.',
#   'fecha': '2011-07-11 19:37:10',
#   'num_likes': 0},
#  {'index': 950,
#   'usuario_id': 'Q776mRUid4fEFT6hslBVTg',
#   'negocio_id': 'WUA2Rhlb43HBw9sT2R0wmg',
#   'texto': 'Lunch time 2 for $20 deal is a good choice',
#   'fecha': '2013-12-21 19:37:38',
#   'num_likes': 0},
#  {'index': 951,
#   'usuario_id': 'KQm9OgdujLZiMRTksmj83w',
#   'negocio_id': '5EIJCSrXLHvM2HEoKCejpw',
#   'texto': 'Old stomping grounds... Lots of memories...',
#   'fecha': '2011-04-22 03:07:41',
#   'num_likes': 0},
#  {'index': 952,
#   'usuario_id': '1fTWTsM9G1f5hS6ZvE4nuQ',
#   'negocio_id': 'QPq7OiHqyONN9relgqwFZA',
#   'texto': 'Sweet spot...great vibe and beers! Legit hangout joint.',
#   'fecha': '2017-03-08 23:35:33',
#   'num_likes': 0},
#  {'index': 953,
#   'usuario_id': '_VTEyUzzH92X3w-IpGaXVA',
#   'negocio_id': 'LNAI2hGXzAFq_9KFwpdshg',
#   'texto': "Bring your earplugs, it's insanely loud",
#   'fecha': '2014-08-28 22:56:51',
#   'num_likes': 0},
#  {'index': 954,
#   'usuario_id': 'OEuoDD8PboD_wKTU2HYUhg',
#   'negocio_id': 'fi-cvgNbAWUwyeJwM7fwgA',
#   'texto': 'Average cafe.  Small not much seating but great lemon meringue pie!',
#   'fecha': '2014-06-08 19:44:55',
#   'num_likes': 0},
#  {'index': 955,
#   'usuario_id': 'rp007n5XVLGJwIOTh9U0-g',
#   'negocio_id': 'XNWXyFgCGaAwvg9QML2Ypw',
#   'texto': 'Beans dip, guacamole, and salsa is all top notch. It would be hard to find better in the city.',
#   'fecha': '2016-01-18 04:18:11',
#   'num_likes': 0},
#  {'index': 956,
#   'usuario_id': 'UXZDRVdx8eJqdqb13Bcfcg',
#   'negocio_id': 'UHlHCV8chJYLHA-C4YeLnA',
#   'texto': 'Ugh...severely understaffed today',
#   'fecha': '2012-01-02 19:57:38',
#   'num_likes': 0},
#  {'index': 957,
#   'usuario_id': 'vWUj8ed8ojO8CctKP-mwxQ',
#   'negocio_id': 'qfj5Ih8-6RPF2ccvNGvCcg',
#   'texto': 'Thanks Richard, Robbi, Armondo, & Matthew!!!',
#   'fecha': '2011-10-18 17:16:47',
#   'num_likes': 0},
#  {'index': 958,
#   'usuario_id': 'bUf8JDAJElBMduwNOYIXSQ',
#   'negocio_id': 'j4x0keDCJGgkcIdnMtbgzQ',
#   'texto': 'Print it!',
#   'fecha': '2011-04-28 14:59:43',
#   'num_likes': 0},
#  {'index': 959,
#   'usuario_id': 'oBgay1e7NMgeV4MDjYe5gA',
#   'negocio_id': 'SBNucLXc9dQP6VBj__XOmQ',
#   'texto': 'Love this place! The black orchid ahi app is the best in town!',
#   'fecha': '2016-08-08 02:23:57',
#   'num_likes': 0},
#  {'index': 960,
#   'usuario_id': 'nghr8RCzDW7Yx22SFWFA9A',
#   'negocio_id': 'pt-lpbRPiOBQlk_IWIn6iQ',
#   'texto': "Hot fudge is not Hot fudge. It is plain chocolate syrup.  Don't waste you money.",
#   'fecha': '2013-05-16 20:31:27',
#   'num_likes': 0},
#  {'index': 961,
#   'usuario_id': '2gu5B_JbJlfZLhihSr-apQ',
#   'negocio_id': 'dimv16yFu0JXR1n1SAqedQ',
#   'texto': 'Picking up din din',
#   'fecha': '2011-07-27 02:38:36',
#   'num_likes': 0},
#  {'index': 962,
#   'usuario_id': 'D2inhShyddiXrbNnVhd-SA',
#   'negocio_id': '5WKit5vmPKRCgxFLDwKLYg',
#   'texto': 'Food is good but the service was terrible... We can never find our server',
#   'fecha': '2014-03-15 18:06:16',
#   'num_likes': 0},
#  {'index': 963,
#   'usuario_id': 'hs62gPJo3HXeKwC8_DBRAg',
#   'negocio_id': '-FcZY7a7qgxTUlTvwuyJnQ',
#   'texto': 'excellent food with excellent service',
#   'fecha': '2017-03-11 04:16:41',
#   'num_likes': 0},
#  {'index': 964,
#   'usuario_id': 'NfkWrVe_J2dcQbXa0sUujA',
#   'negocio_id': '2tfMXjOotr1r168mVttUmQ',
#   'texto': 'We r eating outside on patio. Beautiful day!',
#   'fecha': '2016-04-17 23:00:13',
#   'num_likes': 0},
#  {'index': 965,
#   'usuario_id': '5cxk_eDtMKHU7YOnZHzzsQ',
#   'negocio_id': 'qgng2rCxAPJr2YQZZp2mdg',
#   'texto': 'Winter hours 11am-9pm. Food & drink specials during all football games to go along with their 6-8 pm happy hour.',
#   'fecha': '2014-09-09 13:23:57',
#   'num_likes': 0},
#  {'index': 966,
#   'usuario_id': 'eXC9pqaD21oSet31ZeRG_A',
#   'negocio_id': '1oxMj71XiKQjCbRxECzB7w',
#   'texto': 'Walking the stairs with friends.',
#   'fecha': '2016-01-24 20:33:27',
#   'num_likes': 0},
#  {'index': 967,
#   'usuario_id': 'xWpI52PuDd0yIE0lc_lPlg',
#   'negocio_id': 'n_K2xa_nqzUqaUJa0S_5tQ',
#   'texto': 'The soup is tea flavored too! Yum! =)',
#   'fecha': '2011-08-08 00:20:40',
#   'num_likes': 0},
#  {'index': 968,
#   'usuario_id': 'huXqrSaGyNO1aZKiM55EUg',
#   'negocio_id': 'uW6UHfONAmm8QttPkbMewQ',
#   'texto': 'Beef Stew Special is unbelievable! Served on Friday or Saturday only.\nNice live music on weekends.',
#   'fecha': '2013-02-06 22:01:46',
#   'num_likes': 0},
#  {'index': 969,
#   'usuario_id': 'ok1c0Kn_0jWyphu5LU9JdA',
#   'negocio_id': 'SmkEMQzz5C0aIVvR-DXDhQ',
#   'texto': 'Buy tickets online or call in advance to make reservations to guarantee a seat, this place can get busy!',
#   'fecha': '2015-05-17 01:18:32',
#   'num_likes': 0},
#  {'index': 970,
#   'usuario_id': 'FQUe6VPj-uo85bktpjDYmQ',
#   'negocio_id': 'vth5woM3WJnNYRKrwTI2zg',
#   'texto': 'Awesome deals on workout clothes and shoes! I love it!!',
#   'fecha': '2017-03-24 19:52:03',
#   'num_likes': 0},
#  {'index': 971,
#   'usuario_id': 'XImR8FdsuTMorIXcmBN4Qg',
#   'negocio_id': 'zxSfGIhK3hH3vVz_pS5eaA',
#   'texto': "I've only been here once but the non-veg Thali\nis amazing.",
#   'fecha': '2017-06-12 04:08:32',
#   'num_likes': 0},
#  {'index': 972,
#   'usuario_id': 'L3DxG0n3lRq5N2lv1QNrrA',
#   'negocio_id': 'iTCH7y2KLRMKMxdEkgUK1g',
#   'texto': 'The hours posted on yelp are wrong! Check the pics.  The correct hours are posted through pics.  :)',
#   'fecha': '2015-01-28 19:05:27',
#   'num_likes': 0},
#  {'index': 973,
#   'usuario_id': 'DYFXCoWpMAkTey_kCQZUYg',
#   'negocio_id': 'N2M0WyGCyTV5jMOYPH7odA',
#   'texto': 'Great food',
#   'fecha': '2014-09-02 22:58:25',
#   'num_likes': 0},
#  {'index': 974,
#   'usuario_id': 'FFv0W5YQrROPyjZiRfyrHw',
#   'negocio_id': 'pDewiJY6KCcZgLxxgxg13Q',
#   'texto': 'Chilequiles n tecate',
#   'fecha': '2013-12-04 18:25:20',
#   'num_likes': 0},
#  {'index': 975,
#   'usuario_id': 'Mo7i9Mf9B33SveAIChMFNw',
#   'negocio_id': 'FB2zcyp_z1XEM5WngoO5Lg',
#   'texto': 'Excellent food, fresh fish, good service, with a cozy ambiance.',
#   'fecha': '2015-01-17 20:44:03',
#   'num_likes': 0},
#  {'index': 976,
#   'usuario_id': '5wT0vDycEzgq95yVCZ60Aw',
#   'negocio_id': 'YiEj85uB1UcDJeK8StoX9Q',
#   'texto': 'Friendly service. Clean',
#   'fecha': '2010-11-28 23:39:00',
#   'num_likes': 0},
#  {'index': 977,
#   'usuario_id': 'uufubBI9EcKwFW7x_o9j8w',
#   'negocio_id': 'Rg4FHrDOD2DJeDY_khy-0w',
#   'texto': 'The coke freestyle machine makes it better.',
#   'fecha': '2011-04-10 20:44:46',
#   'num_likes': 0},
#  {'index': 978,
#   'usuario_id': 'M9TjYmTgHayJ22cNkyvW_g',
#   'negocio_id': 'j3IEZP4nQAt7fkxmerLMbA',
#   'texto': 'Split an order of wings with a friend! The wings here are enormous and delicious!',
#   'fecha': '2016-04-17 22:15:53',
#   'num_likes': 0},
#  {'index': 979,
#   'usuario_id': 'pNn_DcM3TyBxSqSv5S7P_g',
#   'negocio_id': 'Lsy_RA1xk9qHFLzLNWKBww',
#   'texto': 'Love their special hummus',
#   'fecha': '2011-07-23 02:34:48',
#   'num_likes': 0},
#  {'index': 980,
#   'usuario_id': 'RSLTG7N0wYJhRTW5CGEm5Q',
#   'negocio_id': 'hgWMxKhrnOUd3m5nOUBIkA',
#   'texto': 'Losing all the weight I gained this past week!',
#   'fecha': '2011-07-23 18:53:20',
#   'num_likes': 0},
#  {'index': 981,
#   'usuario_id': 'uEvusDwoSymbJJ0auR3muQ',
#   'negocio_id': 'QJR4qBUHegWEozSQrGmBPw',
#   'texto': 'Happy Anniversary dinner at Olives!',
#   'fecha': '2012-03-17 01:44:01',
#   'num_likes': 0},
#  {'index': 982,
#   'usuario_id': 'e3c6w6sM8sJ_g0IlF6CSog',
#   'negocio_id': 'u-3exVNGKE0iJ7nnxS3BbA',
#   'texto': 'Try the mango milk tea!!',
#   'fecha': '2018-01-29 00:34:50',
#   'num_likes': 0},
#  {'index': 983,
#   'usuario_id': 'Ov-0pRQxz5fTTElFE-WtTQ',
#   'negocio_id': 'm7Pr86BWoqbSsLo4e0TERw',
#   'texto': "Plates on fire!! Haven't seen that before. And we are here a LOT!",
#   'fecha': '2013-02-08 00:55:45',
#   'num_likes': 0},
#  {'index': 984,
#   'usuario_id': 'WdZXKWoC9OC72kkvHZhUgA',
#   'negocio_id': 'kxzS-zh5nUNvBzYz2Q47pg',
#   'texto': 'The banana tres leeches cake is ridiculously good!',
#   'fecha': '2012-08-04 05:00:16',
#   'num_likes': 0},
#  {'index': 985,
#   'usuario_id': 'SK1uBD9pY2kVzz9-wppu4Q',
#   'negocio_id': '0FMKDOU8TJT1x87OKYGDTg',
#   'texto': 'Everything is amazing!!!!',
#   'fecha': '2015-10-02 00:01:00',
#   'num_likes': 0},
#  {'index': 986,
#   'usuario_id': 'Hh14vKFR1a88i50flcLeow',
#   'negocio_id': '9Jli60umnBUfrWwZwSJYtw',
#   'texto': 'Yaaayyyyy!  Jamba Juice is opening a store at UNCC this year. Whoop Whoop!',
#   'fecha': '2014-08-25 15:10:48',
#   'num_likes': 0},
#  {'index': 987,
#   'usuario_id': 'Reuq65EOFI938Yg8xgff9g',
#   'negocio_id': 'W2ScuLROqFh6dhW_jZ3-lw',
#   'texto': 'Donation drop off behind store.',
#   'fecha': '2012-03-17 16:37:19',
#   'num_likes': 0},
#  {'index': 988,
#   'usuario_id': 'M-xJMhi-HphpWaD2992K3A',
#   'negocio_id': 'k1INAr34-slOv0LUiUJcSA',
#   'texto': 'Free wifi helps kill time!',
#   'fecha': '2013-07-28 21:33:08',
#   'num_likes': 0},
#  {'index': 989,
#   'usuario_id': 'eLxR9WkbmMfRKLOKDabr_w',
#   'negocio_id': 'y-ytZFbfRWvYma9P4g7AYA',
#   'texto': 'There is a $5 minimum for credit cards!',
#   'fecha': '2014-03-23 06:56:41',
#   'num_likes': 0},
#  {'index': 990,
#   'usuario_id': 'B2HDoWNIzLlon0IhS1cmDw',
#   'negocio_id': '_uMRu3765QYo0Qg1z1LKqw',
#   'texto': 'If you like Blue Sky soda the have it on the fountain (Root Beer, Orange Mango and Black Cherry all with cane sugar)',
#   'fecha': '2016-04-23 03:47:21',
#   'num_likes': 0},
#  {'index': 991,
#   'usuario_id': 'T1jicY-vxpCOTl5SIdVLxg',
#   'negocio_id': '8TEm2BpwJuqsSTKPmxxdgg',
#   'texto': 'mani/pedi shellac',
#   'fecha': '2011-10-01 16:04:02',
#   'num_likes': 0},
#  {'index': 992,
#   'usuario_id': 'W7ugM1NqQeB1Wj0DYE8TYw',
#   'negocio_id': '3OcNWCV7VrJu1qRGWEPBsg',
#   'texto': 'Free cup of noodles in the back!',
#   'fecha': '2016-12-20 21:37:15',
#   'num_likes': 0},
#  {'index': 993,
#   'usuario_id': 'mpHBEhkoTdfX1G96Wfhmtg',
#   'negocio_id': 'bQ8ndy52Rcdv3uYvoJWQ_w',
#   'texto': "I've only had the mac and cheese but it is really good.",
#   'fecha': '2015-01-27 04:17:44',
#   'num_likes': 0},
#  {'index': 994,
#   'usuario_id': 'CCv59yCnCgr-KNZwIi-ixQ',
#   'negocio_id': 'Y4SxtwM0Vbixomer3lqSiw',
#   'texto': 'parking in the back',
#   'fecha': '2012-08-10 22:18:51',
#   'num_likes': 0},
#  {'index': 995,
#   'usuario_id': 'kWBISsSWkDAj7EeCrJvsEg',
#   'negocio_id': 'FtI-LMW5d2bvZGF34nDDpQ',
#   'texto': 'Awesome. Come check it out!',
#   'fecha': '2011-04-22 21:16:52',
#   'num_likes': 0},
#  {'index': 996,
#   'usuario_id': 'HqArcGli2YESf7OeCqmZhw',
#   'negocio_id': 'Gh-qmVwvibLnNdqEZXcQHw',
#   'texto': 'Awesome extensive menu, great selections, interesting combinations',
#   'fecha': '2012-03-19 02:08:23',
#   'num_likes': 0},
#  {'index': 997,
#   'usuario_id': 'KU6T8KNZV9ev-PsyJZR0Hw',
#   'negocio_id': 'kBJfBVaXJtPEKLTov1hJdQ',
#   'texto': 'The Bai Cha with steak is AMAZING!!',
#   'fecha': '2016-11-18 00:55:06',
#   'num_likes': 0},
#  {'index': 998,
#   'usuario_id': 'n4TZSTUWKfKNsFHMxpAtOQ',
#   'negocio_id': 'OLVu9kNIosQnISfkZvhrtA',
#   'texto': 'Do not use car wash. Totally ripped the chrome off my passenger side and the rubber off my roof.  Standard SUV. Nothing custom or crazy.',
#   'fecha': '2015-09-22 01:13:33',
#   'num_likes': 0},
#  {'index': 999,
#   'usuario_id': 'FVfGXRIQ6Trnx5cKayU-Cg',
#   'negocio_id': 'Zzl4ffV9kFY3yOSSgyRUBQ',
#   'texto': 'Just made a small withdrawal :)))))',
#   'fecha': '2012-05-29 07:53:45',
#   'num_likes': 0},
#  ...]

# %%
# Pasamos el diccionario generador por JSON READER a Dataframe
df_consejos = pd.DataFrame.from_dict(json_consejos["data"])
df_consejos
# Out:
#            index              usuario_id              negocio_id  \
# 0              0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1              1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2              2  jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3              3  FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4              4  LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...          ...                     ...                     ...
# 1223089  1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                      texto  \
# 0        Great for watching games, ufc, and whatever el...
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...
# 2        Good chips and salsa. Loud at times. Good serv...
# 3        The setting and decoration here is amazing. Co...
# 4        Molly is definately taking a picture with Sant...
# ...                                                    ...
# 1223089                Very good class, great instructor!!
# 1223090                                     Excellent food
# 1223091     Jess is the best bartender!! Go check her out!
# 1223092  Excellent food and AMAZING service by Anneliese!!
# 1223093                                         Funnnnn!!!
#
#                        fecha  num_likes
# 0        2014-03-27 03:51:24          0
# 1        2013-05-25 06:00:56          0
# 2        2011-12-26 01:46:17          0
# 3        2014-03-23 21:32:49          0
# 4        2012-10-06 00:19:27          0
# ...                      ...        ...
# 1223089  2018-08-05 20:58:09          0
# 1223090  2018-08-15 18:05:22          0
# 1223091  2018-10-02 03:34:58          0
# 1223092  2018-10-13 16:57:50          0
# 1223093  2018-11-10 03:17:18          0
#
# [1223094 rows x 6 columns]

# %% [markdown]
# ### Búsqueda de valores nulos

# %%
print("¿Hay valores nulos?\n", pd.isnull(df_consejos).any(), "\n")
print("¿Cuantos?\n", pd.isnull(df_consejos).sum(), "\n")
# Out:
# ¿Hay valores nulos?
#  index         False
# usuario_id    False
# negocio_id    False
# texto          True
# fecha         False
# num_likes     False
# dtype: bool
#
# ¿Cuantos?
#  index         0
# usuario_id    0
# negocio_id    0
# texto         4
# fecha         0
# num_likes     0
# dtype: int64

# %% [markdown]
# Encontramos 4 instancias que tienen el texto de la opinion nulos, visualizamos estas instancias para confirmar lo que hemos detectado.

# %%
import numpy as np

# Buscamos las filas en las que hay nulos para comprobar la anomalía y encontrar explicaciones
filas, _ = np.where(df_consejos.isnull().values == True)

for fila in filas:
    print(str(df_consejos.iloc[fila]) + "\n")
# Out:
# index                         463764
# usuario_id    GJJPGC3m5EGJHRDYW5HyZw
# negocio_id    _J-nDE8uzOs4dW7FOVN54A
# texto                           None
# fecha            2018-06-22 02:58:52
# num_likes                          0
# Name: 463764, dtype: object
#
# index                         581548
# usuario_id    42GskOrO9tRGvt2OrC1srg
# negocio_id    WcdNwJ1DVcHz_8tzuphweg
# texto                           None
# fecha            2018-01-16 22:12:53
# num_likes                          0
# Name: 581548, dtype: object
#
# index                         856381
# usuario_id    pQ7cqiX9Ocs9Rk9yBDguRQ
# negocio_id    uuaH1UNcqcV-alT6nh42WA
# texto                           None
# fecha            2018-05-29 02:25:07
# num_likes                          0
# Name: 856381, dtype: object
#
# index                         961436
# usuario_id    wHKGTsPrB_DX4Fur2GGLJQ
# negocio_id    PS5ghm09F2km76m4sQNJAw
# texto                           None
# fecha            2015-01-10 19:53:16
# num_likes                          0
# Name: 961436, dtype: object

# %% [markdown]
# Tal y como habíamos encontrado, se trata de cuatro instancias que tienen el campo de texto del consejo vacío, ya que no tiene sentido tener un consejo sin el texto, decidimos eliminar estas instancias del dataframe.

# %%
import numpy as np

# Tomamos las filas en las que hay nulos para eliminarlas 
filas, _ = np.where(df_consejos.isnull().values == True)

for fila in filas:
    df_consejos = df_consejos.drop(fila, axis=0)
df_consejos
# Out:
#            index              usuario_id              negocio_id  \
# 0              0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1              1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2              2  jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3              3  FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4              4  LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...          ...                     ...                     ...
# 1223089  1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                      texto  \
# 0        Great for watching games, ufc, and whatever el...
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...
# 2        Good chips and salsa. Loud at times. Good serv...
# 3        The setting and decoration here is amazing. Co...
# 4        Molly is definately taking a picture with Sant...
# ...                                                    ...
# 1223089                Very good class, great instructor!!
# 1223090                                     Excellent food
# 1223091     Jess is the best bartender!! Go check her out!
# 1223092  Excellent food and AMAZING service by Anneliese!!
# 1223093                                         Funnnnn!!!
#
#                        fecha  num_likes
# 0        2014-03-27 03:51:24          0
# 1        2013-05-25 06:00:56          0
# 2        2011-12-26 01:46:17          0
# 3        2014-03-23 21:32:49          0
# 4        2012-10-06 00:19:27          0
# ...                      ...        ...
# 1223089  2018-08-05 20:58:09          0
# 1223090  2018-08-15 18:05:22          0
# 1223091  2018-10-02 03:34:58          0
# 1223092  2018-10-13 16:57:50          0
# 1223093  2018-11-10 03:17:18          0
#
# [1223090 rows x 6 columns]

# %% [markdown]
# ### Comprobación sintáctica de la fecha
#
# Comprobamos si la fecha es correcta sintácticamente utilizando una expresión regular. No se imprime ninguna fecha incorrecta, por lo que todas están bien.

# %%
import re
pattern = re.compile("[0-9][0-9][0-9][0-9][-][0-1][0-9][-][0-3][0-9]\s[0-2][0-9][:][0-5][0-9][:][0-5][0-9]")


def preprocesa(x):
    if(pattern.match(x) == None):
        print("date not matching: " + str(x))
        return True
    return False

df_consejos['fecha'].apply(lambda x: preprocesa(x))
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1223089    False
# 1223090    False
# 1223091    False
# 1223092    False
# 1223093    False
# Name: fecha, Length: 1223090, dtype: bool

# %% [markdown]
# ### Transformación inicial
#
# Una vez que hemos pasado la cadena de texto del JSON a dataframe y hemos eliminado algunos valores nulos, vamos a cambiar el formato de la fecha para que sea más manejable. En primer lugar, eliminamos el atributo index ya que no aporta ninguna información a las instancias del dataframe.
#
# De todos los elementos que podemos quedarnos de la fecha, decidimos quedarnos con el día, el mes, el año, la hora y el minuto, ya que puede ser que posteriormente nos sean útiles. El atributo que puede llegar a ser más controversial es el minuto puesto que se puede considerar que es hilar demasiado fino. Sin embargo, lo vemos necesario para casos en los que por ejemplo queramos analizar consejos muy cercanos entre sí.

# %%
# Eliminamos la columna índice que no aporta información
df_consejos = df_consejos.drop("index", axis=1)
df_consejos
# Out:
#                      usuario_id              negocio_id  \
# 0        UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1        Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2        jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3        FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4        LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...                         ...                     ...
# 1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                      texto  \
# 0        Great for watching games, ufc, and whatever el...
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...
# 2        Good chips and salsa. Loud at times. Good serv...
# 3        The setting and decoration here is amazing. Co...
# 4        Molly is definately taking a picture with Sant...
# ...                                                    ...
# 1223089                Very good class, great instructor!!
# 1223090                                     Excellent food
# 1223091     Jess is the best bartender!! Go check her out!
# 1223092  Excellent food and AMAZING service by Anneliese!!
# 1223093                                         Funnnnn!!!
#
#                        fecha  num_likes
# 0        2014-03-27 03:51:24          0
# 1        2013-05-25 06:00:56          0
# 2        2011-12-26 01:46:17          0
# 3        2014-03-23 21:32:49          0
# 4        2012-10-06 00:19:27          0
# ...                      ...        ...
# 1223089  2018-08-05 20:58:09          0
# 1223090  2018-08-15 18:05:22          0
# 1223091  2018-10-02 03:34:58          0
# 1223092  2018-10-13 16:57:50          0
# 1223093  2018-11-10 03:17:18          0
#
# [1223090 rows x 5 columns]

# %%
# Dividimos la fecha en año, mes , dia, hora y minuto
df_consejos['anyo'] = pd.DatetimeIndex(df_consejos['fecha']).year
df_consejos['mes'] = pd.DatetimeIndex(df_consejos['fecha']).month
df_consejos['dia'] = pd.DatetimeIndex(df_consejos['fecha']).day
df_consejos['hora'] = pd.DatetimeIndex(df_consejos['fecha']).hour
df_consejos['minuto'] = pd.DatetimeIndex(df_consejos['fecha']).minute

# Eliminamos el atributo fecha
df_consejos = df_consejos.drop("fecha", axis=1)
df_consejos
# Out:
#                      usuario_id              negocio_id  \
# 0        UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1        Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2        jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3        FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4        LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...                         ...                     ...
# 1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                      texto  num_likes  anyo  \
# 0        Great for watching games, ufc, and whatever el...          0  2014
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...          0  2013
# 2        Good chips and salsa. Loud at times. Good serv...          0  2011
# 3        The setting and decoration here is amazing. Co...          0  2014
# 4        Molly is definately taking a picture with Sant...          0  2012
# ...                                                    ...        ...   ...
# 1223089                Very good class, great instructor!!          0  2018
# 1223090                                     Excellent food          0  2018
# 1223091     Jess is the best bartender!! Go check her out!          0  2018
# 1223092  Excellent food and AMAZING service by Anneliese!!          0  2018
# 1223093                                         Funnnnn!!!          0  2018
#
#          mes  dia  hora  minuto
# 0          3   27     3      51
# 1          5   25     6       0
# 2         12   26     1      46
# 3          3   23    21      32
# 4         10    6     0      19
# ...      ...  ...   ...     ...
# 1223089    8    5    20      58
# 1223090    8   15    18       5
# 1223091   10    2     3      34
# 1223092   10   13    16      57
# 1223093   11   10     3      17
#
# [1223090 rows x 9 columns]

# %% [markdown]
# ### Análisis descriptivo
#
# Inicialmente, lanzamos un describe para conocer cómo se distribuyen los datos y posibles incoherencias en los mismos, como número de likes negativos... etc.

# %%
# Lo ponemos de esta forma para quitar la notación científica
df_consejos.describe().apply(lambda s: s.apply(lambda x: format(x, 'g')))
# Out:
#          num_likes         anyo          mes          dia         hora  \
# count  1.22309e+06  1.22309e+06  1.22309e+06  1.22309e+06  1.22309e+06
# mean     0.0164738      2014.08      6.37506      15.7498      12.0047
# std        0.14564      2.29733       3.2916      8.80876      8.43059
# min              0         2009            1            1            0
# 25%              0         2012            4            8            3
# 50%              0         2014            6           16           15
# 75%              0         2016            9           23           20
# max             15         2018           12           31           23
#
#             minuto
# count  1.22309e+06
# mean       29.5622
# std        17.3066
# min              0
# 25%             15
# 50%             30
# 75%             45
# max             59
