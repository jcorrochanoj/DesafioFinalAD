# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as skl
import scipy as sp
import seaborn as sns
from sklearn.linear_model import LogisticRegression as lr
from sklearn.naive_bayes import GaussianNB as gnb
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.model_selection import train_test_split as ttsplit
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from statsmodels.stats.outliers_influence import variance_inflation_factor as viff

# %%
url = "datos_negocios.csv"
dfNegocios = pd.read_csv(url)
print(len(dfNegocios.columns))
dictt={}
i,j = np.where(dfNegocios.isnull().values == True)

x = zip(i,j)
for i in list(set(j)):
    dictt[i]=list(dfNegocios.columns)[i]
print(dictt)


for element in x:
    print (dfNegocios.iloc[element[0]][dictt[element[1]]])
# Out:
# 14
# {2: 'direccion', 3: 'ciudad', 5: 'codigo_postal', 11: 'atributos', 12: 'categorias', 13: 'horas'}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %% [markdown]
# Null en los atributos de la direccion del negocio, los atributos y las horas de apertura.
#
# Luego se puede encontrar que hay negocios cerrados de los que se dispone el horario de apertura y negocios abiertos de los que no se dispone del horario

# %%
dfNegocios["direccion"] = dfNegocios["direccion"].fillna("Sin direccion")
dfNegocios["codigo_postal"] = dfNegocios["codigo_postal"].fillna("Sin codigo_postal")
dfNegocios["ciudad"] = dfNegocios["ciudad"].fillna("Sin ciudad")
dfNegocios["atributos"] = dfNegocios["atributos"].fillna("Sin atributos")
dfNegocios["categorias"] = dfNegocios["categorias"].fillna("Sin categorias")
dfNegocios["horas"] = dfNegocios["horas"].fillna("Sin horas")
i,j = np.where(dfNegocios.isnull().values == True)
print(len(i))
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-608c6f6da124> in <module>
#       9 for i in range(int(dfNegocios.shape[0])):
#      10     for j in list(dfNegocios.columns):
# ---> 11         if(dfNegocios.iloc[i][j]==None):
#      12             print(i,j)
#
# c:\users\crist\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\users\crist\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2157             self._validate_integer(key, axis)
#    2158
# ...

# %%
del(dfNegocios)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-eb35318eae72> in <module>
# ----> 1 del(dfNegocios)
#
# NameError: name 'dfNegocios' is not defined

# %%
print(dfNegocios.head(5))
print (dfNegocios.corr())
sns.FacetGrid(datasetNegocios).map(plt.scatter,"puntuacion","num_revisiones")
# Out:
#                negocio_id                           nombre  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                         direccion       ciudad estado codigo_postal  \
# 0     2818 E Camino Acequia Drive      Phoenix     AZ         85016
# 1            30 Eglinton Avenue W  Mississauga     ON       L5R 3E7
# 2       10110 Johnston Rd, Ste 15    Charlotte     NC         28210
# 3   15655 W Roosevelt St, Ste 237     Goodyear     AZ         85338
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte     NC         28217
#
#      latitud    longitud  puntuacion  num_revisiones  abierto  \
# 0  33.522143 -112.018481         3.0               5        0
# 1  43.605499  -79.652289         2.5             128        1
# ...

# %%
¿Cual es el mejor negocio en funcion de ciudad/estado?
# Out:
# Object `estado` not found.
